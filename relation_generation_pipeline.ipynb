# %% [markdown]
# ## general import and functions

# %%
from pathlib import Path
import pickle as pkl
from collections import defaultdict, Counter
from itertools import permutations, combinations
from functools import reduce
import numpy as np
import os

# %%
def pkl_save(data, file):
    with open(file, "wb") as f:
        pkl.dump(data, f)
        
def pkl_load(file):
    with open(file, "rb") as f:
        data = pkl.load(f)
    return data

def load_text(ifn):
    with open(ifn, "r") as f:
        txt = f.read()
    return txt

# %%
import sys
sys.path.append("/home/zehao.yu/workspace/py3/SDoH/NLPpreprocessing-master/")

# %%
from annotation2BIO import pre_processing, read_annotation_brat, generate_BIO

# %%
MIMICIII_PATTERN = "\[\*\*|\*\*\]"

# %%
def parse_brat_ner(brat_data):
	# assert re.match("^T[0-9]+\t[A-Za-z]+ [0-9]+ [0-9]+\t\.+$", brat_data), "invalid brat format for {}".format(brat_data)
	info = brat_data.split("\t")
	idx = info[0]
	text = info[2]
	tse = info[1]
	if ";" in tse:
		ii = tse.split(" ")
		return [idx, ii[0], " ".join(ii[1:-1]), ii[-1], text]
	else:
		tag, s, e = tse.split(" ")
		return [idx, tag, int(s), int(e), text]


def parse_brat_rel(brat_data):
	# assert re.match("^R[0-9]+\t[A-Za-z]+-[A-Za-z]+ Arg1:T[0-9]+ Arg2:T[0-9]+$", brat_data), "invalid brat format for {}".format(brat_data)
	info = brat_data.split("\t")
	idx = info[0]
	tag, arg1, arg2 = info[1].split(" ")
	arg1 = arg1.split(":")[-1]
	arg2 = arg2.split(":")[-1]
	return [idx, tag, arg1, arg2]


def read_brat(file_name):
	ners = []
	rels = []

	with open(file_name, "r") as f:
		cont = f.read().strip()
	
	if not cont:
		return ners, rels

	# process ner and relation
	for each in cont.split("\n"):
		if each.startswith("T"):
			ners.append(parse_brat_ner(each))
		elif each.startswith("R"):
			rels.append(parse_brat_rel(each))
		# elif each.startswith("#"):
		# 	continue
		else:
			continue
			# raise RuntimeError('invalid brat data: {}'.format(each))
	return ners, rels

# %% [markdown]
# ## relation generation functions

# %%
def get_all_rel_types(root, valid_comb):
    root = Path(root)
    rtt = []
    for ann_fn in root.glob("*.ann"):
#         _, rels = read_brat(ann_fn)
        _, _, rels = read_annotation_brat(ann_fn)
        #('Strength-Drug', 'T3', 'T2')
        for rel in rels:
#             rtype = rel[1]
            rtype = rel[0]
            if tuple(rtype.split("-")) not in valid_comb:
                continue
            rtt.append(rtype)
    rs, rc = set(rtt), Counter(rtt).most_common()
    r2i = {NEG_REL: '0'}
    for idx, rt in enumerate(rs):
        r2i[rt] = str(idx + 1)
    i2r = {v: k for k, v in r2i.items()}
    return r2i, i2r, rc

# %%
def create_entity_to_sent_mapping(nnsents, entities, idx2e):
    loc_ens = []
    
    ll = len(nnsents)
    mapping = defaultdict(list)
    for idx, each in enumerate(entities):
        en_label = idx2e[idx]
        en_s = each[2][0]
        en_e = each[2][1]
        new_en = []
        
        i = 0
        while i < ll and nnsents[i][1][0] < en_s:
            i += 1
        s_s = nnsents[i][1][0]
        s_e = nnsents[i][1][1]

        if en_s == s_s:
            mapping[en_label].append(i)

            while i < ll and s_e < en_e:
                i += 1
                s_e = nnsents[i][1][1]
            if s_e == en_e:
                 mapping[en_label].append(i)
            else:
                mapping[en_label].append(i)
                print("last index not match ", each)
        else:
            mapping[en_label].append(i)
            print("first index not match ", each)

            while i < ll and s_e < en_e:
                i += 1
                s_e = nnsents[i][1][1]
            if s_e == en_e:
                 mapping[en_label].append(i)
            else:
                mapping[en_label].append(i)
                print("last index not match ", each)
    return mapping

def get_permutated_relation_pairs(eid2idx):
    all_pairs = []
    all_ids = [k for k, v in eid2idx.items()]
    for e1, e2 in permutations(all_ids, 2):
        all_pairs.append((e1, e2))
    return all_pairs

# %%
"""
procedure:

1. preprocess text into sentences
2. find each entity associated sentence idx
3. generate entity pairs as relation candidates
4. extract eneity associated sentences, locate entities in pair and insert special tags
5. save generated data

result output:

1. keep pos predicted relations
2. using map files to locate relation associated entities
3. output as brat
"""
def validate_rels(rels, valid):
    nrels = []
    for rel in rels:
        rtype = rel[0]
        if tuple(rtype) not in valid:
            print("invalid: ", rel)
            continue
        nrels.append(rel)
    return nrels


def check_tags(s1, s2):
    assert EN1_START in s1 and EN1_END in s1, f"tag error: {s1}"
    assert EN2_START in s2 and EN2_END in s2, f"tag error: {s2}"


def format_relen(en, rloc, nsents):
    if rloc == 1:
        spec1, spec2 = EN1_START, EN1_END
    else:
        spec1, spec2 = EN2_START, EN2_END
    sn1, tn1 = en[0][3]
    sn2, tn2 = en[-1][3]
    target_sent = nsents[sn1]
    target_sent = [each[0] for each in target_sent]
    ors =  " ".join(target_sent)
    
    if sn1 != sn2:
#         print("[!!!Warning] The entity is not in the same sentence\n", en)
        tt = nsents[sn2]
        tt = [each[0] for each in tt]
        target_sent.insert(tn1, spec1)
        tt.insert(tn2+1, spec2)
        target_sent = target_sent + tt
#         print(target_sent)
    else:
        target_sent.insert(tn1, spec1)
        target_sent.insert(tn2+2, spec2)
    
    fs = " ".join(target_sent)
    
    return sn1, sn2, fs, ors


def gene_true_relations(rels, mappings, ens, e2i, nnsents, nsents, valid_comb, fid=None):
    true_pairs = set()
    pos_samples = []
    
    for rel in rels:
        rel_type = rel[0]
        enid1, enid2 = rel[1:]
        """
        [['100', (15443, 15446), (16473, 16476), (231, 4), 'B-Strength'], 
        ['mg', (15447, 15449), (16477, 16479), (231, 5), 'I-Strength']] 
        [['Metoprolol', (15422, 15432), (16452, 16462), (231, 2), 'B-Drug'], 
        ['Succinate', (15433, 15442), (16463, 16472), (231, 3), 'I-Drug']]
        """
#         enbs1, enbe1 = mappings[enid1]
#         en1 = nnsents[enbs1: enbe1+1]
#         si1, fs1, ors1 = format_relen(en1, 1, nsents)
#         enbs2, enbe2 = mappings[enid2]
#         en2 = nnsents[enbs2: enbe2+1]
#         si2, fs2, ors2 = format_relen(en2, 2, nsents)
#         sent_diff = abs(si1 - si2)
        
        
        enbs1, enbe1 = mappings[enid1]
        en1 = nnsents[enbs1: enbe1+1]
        si1, sii1, fs1, ors1 = format_relen(en1, 1, nsents)
        enbs2, enbe2 = mappings[enid2]
        en2 = nnsents[enbs2: enbe2+1]
        si2, sii2, fs2, ors2 = format_relen(en2, 2, nsents)
        sent_diff = abs(si1 - si2)
        
        en1t = en1[0][-1].split("-")[-1]
        en2t = en2[0][-1].split("-")[-1]
        
#         print(abs(si1 - si2), abs(sii1 - sii2), abs(sii1 - si2), abs(si1 - sii2))
        
        true_pairs.add((enid1, enid2))
        
        if (en1t, en2t) not in valid_comb:
            continue
        
        if sent_diff <= CUTOFF:
            check_tags(fs1, fs2)
            assert (en1t, en2t) in valid_comb, f"{en1t} {en2t}"
            if fid:
                pos_samples.append((sent_diff, rel_type, fs1, fs2, en1t, en2t, enid1, enid2, fid))
#                 pos_samples.append((sent_diff, "pos", fs1, fs2, en1t, en2t, enid1, enid2, fid))
            else:
                pos_samples.append((sent_diff, rel_type, fs1, fs2, en1t, en2t, enid1, enid2))
#                 pos_samples.append((sent_diff, "pos", fs1, fs2, en1t, en2t, enid1, enid2))
#         print(sent_diff, rel_type, fs1, fs2, ors1, ors2)
    
    return pos_samples, true_pairs
        

def gene_neg_relation(perm_pairs, true_pairs, mappings, ens, e2i, nnsents, nsents, valid_comb, fid=None):
    neg_samples = []
    for each in perm_pairs:
        enid1, enid2 = each
        
        # not in true relation
        if (enid1, enid2) in true_pairs:
            continue
        
        enc1 = ens[e2i[enid1]]
        enc2 = ens[e2i[enid2]]
    
        #('Metoprolol succinate', 'Drug', (14660, 14680))
        
        enbs1, enbe1 = mappings[enid1]
        en1 = nnsents[enbs1: enbe1+1]
        si1, sii1, fs1, ors1 = format_relen(en1, 1, nsents)
        enbs2, enbe2 = mappings[enid2]
        en2 = nnsents[enbs2: enbe2+1]
        si2, sii2, fs2, ors2 = format_relen(en2, 2, nsents)
        sent_diff = abs(si1 - si2)
        
        en1t = en1[0][-1].split("-")[-1]
        en2t = en2[0][-1].split("-")[-1]
        
#         print((enc1[1], enc2[1]), (en1t, en2t))
        
        if (en1t, en2t) not in valid_comb:
            continue
        
        if sent_diff <= CUTOFF:
            check_tags(fs1, fs2)
            assert (en1t, en2t) in valid_comb, f"{en1t} {en2t}"
            if fid:
                neg_samples.append((sent_diff, NEG_REL, fs1, fs2, en1t, en2t, enid1, enid2, fid))
            else:
                neg_samples.append((sent_diff, NEG_REL, fs1, fs2, en1t, en2t, enid1, enid2))
    
    return neg_samples

    
def create_training_samples(file_path, valids=None, valid_comb=None):
    fids = []
    root = Path(file_path)
    
    dpos = defaultdict(list)
    dneg = defaultdict(list)
    
    for txt_fn in root.glob("*.txt"):
        fids.append(txt_fn.stem)
        ann_fn = root / (txt_fn.stem+".ann")

        # load text
        txt = load_text(txt_fn)
        pre_txt, sents = pre_processing(txt_fn, deid_pattern=MIMICIII_PATTERN)
#         pre_txt = pre_txt.split("\n")
        e2i, ens, rels = read_annotation_brat(ann_fn)
#         ens, rels = read_brat(ann_fn)
        i2e = {v: k for k, v in e2i.items()}
        
#         rels = validate_rels(rels, n2c2_valid_comb)
        
        nsents, sent_bound = generate_BIO(sents, ens, file_id="", no_overlap=False, record_pos=True)
#         print(nsents)
        total_len = len(nsents)
        nnsents = [w for sent in nsents for w in sent]
        mappings = create_entity_to_sent_mapping(nnsents, ens, i2e)

        pos_samples, true_pairs = gene_true_relations(
            rels, mappings, ens, e2i, nnsents, nsents, valid_comb, fid=txt_fn.stem)
        perm_pairs = get_permutated_relation_pairs(e2i)
        neg_samples = gene_neg_relation(
            perm_pairs, true_pairs, mappings, ens, e2i, nnsents, nsents, valid_comb, fid=txt_fn.stem)
        
        for pos_sample in pos_samples:
            dpos[pos_sample[0]].append(pos_sample)
        for neg_sample in neg_samples:
            dneg[neg_sample[0]].append(neg_sample)
#         break
        
    return dpos, dneg


def create_test_samples(file_path, valids=None, valid_comb=None):
    #create a separate mapping file
    rel_mappings = []
    #
    fids = []
    root = Path(file_path)
    preds = defaultdict(list)
    
    g_idx = 0
    
    for txt_fn in root.glob("*.txt"):
        fids.append(txt_fn.stem)
        ann_fn = root / (txt_fn.stem + ".ann")

        # load text
        txt = load_text(txt_fn)
        pre_txt, sents = pre_processing(txt_fn, deid_pattern=MIMICIII_PATTERN)
        e2i, ens, _ = read_annotation_brat(ann_fn)
        i2e = {v: k for k, v in e2i.items()}
        
        nsents, sent_bound = generate_BIO(sents, ens, file_id="", no_overlap=False, record_pos=True)
        total_len = len(nsents)
        nnsents = [w for sent in nsents for w in sent]
        mappings = create_entity_to_sent_mapping(nnsents, ens, i2e)
        
        perm_pairs = get_permutated_relation_pairs(e2i)
        pred = gene_neg_relation(perm_pairs, set(), mappings, ens, e2i, nnsents, nsents, valid_comb, fid=txt_fn.stem)
        for idx, pred_s in enumerate(pred):
            preds[pred_s[0]].append(pred_s)
#             rel_mappings.append((g_idx, *pred_s[-3:]))
#             g_idx += 1
            
    return preds #rel_mappings

# %%
"""
Output strategy:

1. by cross-distance
- no cross distance; all in one
- by cross distance; all in unique
- by partial cross distance; within-sentence vs. cross sentence

2. relation format
- [CLS] S1 [SEP] S2 [SEP]
- [CLS] S1 S2 [SEP]

We only handle (1) in data generation here, (2) will be handled by the data_utils
"""
def to_tsv(data, fn):
    header = "\t".join([str(i+1) for i in range(len(data[0]))])
    with open(fn, "w") as f:
        f.write(f"{header}\n")
        for each in data:
            d = "\t".join([str(e) for e in each])
            f.write(f"{d}\n")


def to_5_cv(data, ofd):
    if not os.path.isdir(ofd):
        os.mkdir(ofd)
    
    np.random.seed(13)
    np.random.shuffle(data)
    
    dfs = np.array_split(data, 5)
    a = [0,1,2,3,4]
    for each in combinations(a, 4):
        b = list(set(a) - set(each))[0]
        n = dfs[b]
        m = []
        for k in each:
            m.extend(dfs[k])
        if not os.path.isdir(os.path.join(ofd, f"sample{b}")):
            os.mkdir(os.path.join(ofd, f"sample{b}"))
        
        to_tsv(m, os.path.join(ofd, f"sample{b}", "train.tsv"))
        to_tsv(n, os.path.join(ofd, f"sample{b}", "dev.tsv"))


def all_in_one(*dd, dn="2018n2c2", do_train=True):
    data = []
    for d in dd:
        for k, v in d.items():
            for each in v:
#                 data.append(each[1:])
                data.append(each)
    
    output_path = f"./data/{dn}_aio_th{CUTOFF}"
    p = Path(output_path)
    p.mkdir(parents=True, exist_ok=True)
    
    if do_train:
        to_tsv(data, p/"train.tsv")
#         to_5_cv(data, p.as_posix())
    else:
        to_tsv(data, p/"test.tsv")
    

def all_in_unique(*dd, dn="2018n2c2", do_train=True):
    for idx in range(CUTOFF+1):
        data = []
        for d in dd:
            for k, v in d.items():
                for each in v:
                    if k == idx:
                        data.append(each[1:])
        
        output_path = f"./data/{dn}_aiu_th{CUTOFF}"
        p = Path(output_path) / f"cutoff_{idx}"
        p.mkdir(parents=True, exist_ok=True)
        if do_train:
            to_tsv(data, p/"train.tsv")
#             to_5_cv(data, p.as_posix())
        else:
            to_tsv(data, p/"test.tsv")

            
def partial_unique(*dd, dn="2018n2c2", do_train=True):
    within = []
    cross = []
    
    for d in dd:
        for k, v in d.items():
            for each in v:
                if k == 0:
                    within.append(each[1:])
                else:
                    cross.append(each[1:])
    
    output_path = f"./data/{dn}_pu_th{CUTOFF}"
    p = Path(output_path)
    p1 = p / "within"
    p2 = p / "cross"
    p1.mkdir(parents=True, exist_ok=True)
    p2.mkdir(parents=True, exist_ok=True)
    
    if do_train:
        to_tsv(within, p1/"train.tsv")
#         to_5_cv(within, p1.as_posix())
        to_tsv(cross, p2/"train.tsv")
#         to_5_cv(cross, p2.as_posix())
    else:
        to_tsv(within, p1/"test.tsv")
        to_tsv(cross, p2/"test.tsv")

# %%
# create ann for test purpose
def extract_only_entity(input_path, output_path):
    pi = Path(input_path)
    po = Path(output_path)
    po.mkdir(exist_ok=True, parents=True)
    for fid in pi.glob("*.ann"):
        ofn = po / fid.name
        with open(fid, "r") as f1, open(ofn, "w") as f2:
            for line in f1.readlines():
                if line.startswith("T"):
                    f2.write(line)

# %%
# general pre-defined special tags
EN1_START = "[s1]"
EN1_END = "[e1]"
EN2_START = "[s2]"
EN2_END = "[e2]"
NEG_REL = "NonRel"
CUTOFF = 1

# %%
def _flat(dd):
    c = 0
    for k, v in dd.items():
        c += len(v)
    return c

# %%
train_dev_root ='/home/zehao.yu/workspace/py3/dr_ann/data/used/train_set'
test_root = '/home/zehao.yu/workspace/py3/dr_ann/data/used/test_set'

# %%
dr_valid = {
 'located', 'laterality-lesion', 'severity-lesion'
}

dr_valid_comb_en = {
    ('lesion', 'eye_part'), ('laterality', 'lesion'), ('severity', 'lesion')
}

# %%
d = {"nc":defaultdict(list), "dr": defaultdict(list)}

for i in range(1, 5, 1):
    CUTOFF=i
    dpos, dneg = create_training_samples(train_dev_root,dr_valid,dr_valid_comb_en)
    preds = create_test_samples(test_root,dr_valid,dr_valid_comb_en)
    d['nc'][CUTOFF].append((_flat(dpos), _flat(dneg), _flat(preds)))

    
for i in range(1, 5, 1):
    CUTOFF=i
    dpos, dneg = create_training_samples(train_dev_root,dr_valid,dr_valid_comb_en)
    all_in_one(dpos, dneg, dn="dr_relation", do_train=True)
    partial_unique(dpos, dneg, dn="dr_relation", do_train=True)
    all_in_unique(dpos, dneg, dn="dr_relation", do_train=True)
    
    preds = create_test_samples(test_root,dr_valid,dr_valid_comb_en)
    all_in_one(preds, dn="dr_relation", do_train=False)
    partial_unique(preds, dn="dr_relation", do_train=False)
    all_in_unique(preds, dn="dr_relation", do_train=False)
    d['dr'][CUTOFF].append((_flat(dpos), _flat(dneg), _flat(preds)))
# Out:
# 2021-06-15 16:43:19,241 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:19,242 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:19,242 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_9152.txt ...
# 2021-06-15 16:43:19,318 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:19,318 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:19,319 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_863.txt ...
# 2021-06-15 16:43:19,370 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:19,371 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:19,371 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_4550.txt ...
# 2021-06-15 16:43:19,426 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:19,427 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:19,427 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/2748168_note_9227.txt ...
# last index not match  ('MA', 'lesion', (799, 801))
# last index not match  ('MA', 'lesion', (889, 891))
# 2021-06-15 16:43:19,480 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:19,481 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:19,482 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/1458921_note_3276.txt ...
# 2021-06-15 16:43:19,546 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:19,547 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:19,548 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_6884.txt ...
# 2021-06-15 16:43:19,601 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:19,602 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:19,603 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/910329_note_1460.txt ...
# 2021-06-15 16:43:19,654 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:19,655 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:19,656 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/2559086_note_8081.txt ...
# 2021-06-15 16:43:19,708 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:19,709 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:19,710 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/2260561_note_6253.txt ...
# 2021-06-15 16:43:19,780 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:19,781 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:19,782 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_6174.txt ...
# 2021-06-15 16:43:19,834 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:19,835 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:19,836 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/2698404_note_9114.txt ...
# 2021-06-15 16:43:19,890 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:19,891 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:19,891 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_3955.txt ...
# 2021-06-15 16:43:19,946 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:19,947 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:19,948 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_1085.txt ...
# 2021-06-15 16:43:20,002 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:20,002 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:20,003 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_5103.txt ...
# 2021-06-15 16:43:20,055 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:20,056 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:20,057 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_9115.txt ...
# 2021-06-15 16:43:20,110 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:20,111 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:20,111 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_7661.txt ...
# 2021-06-15 16:43:20,177 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:20,178 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:20,179 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_2433.txt ...
# 2021-06-15 16:43:20,235 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:20,236 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:20,236 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_93.txt ...
# 2021-06-15 16:43:20,289 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:20,290 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:20,290 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_8911.txt ...
# 2021-06-15 16:43:20,343 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:20,344 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:20,344 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/1871760_note_4792.txt ...
# 2021-06-15 16:43:20,408 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:20,409 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:20,409 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_928.txt ...
# 2021-06-15 16:43:20,461 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:20,462 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:20,462 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_6908.txt ...
# 2021-06-15 16:43:20,531 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:20,532 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:20,532 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/202930_note_459.txt ...
# 2021-06-15 16:43:20,591 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:20,592 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:20,593 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_8234.txt ...
# 2021-06-15 16:43:20,648 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:20,649 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:20,649 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/460233_note_1091.txt ...
# 2021-06-15 16:43:20,708 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:20,709 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:20,709 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_2372.txt ...
# 2021-06-15 16:43:20,776 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:20,777 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:20,778 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/2453695_note_6919.txt ...
# 2021-06-15 16:43:20,846 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:20,847 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:20,847 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_9110.txt ...
# 2021-06-15 16:43:20,900 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:20,901 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:20,901 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_6799.txt ...
# 2021-06-15 16:43:20,954 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:20,954 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:20,955 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_5880.txt ...
# 2021-06-15 16:43:21,008 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:21,009 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:21,010 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/39541_note_166.txt ...
# 2021-06-15 16:43:21,064 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:21,065 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:21,066 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_2321.txt ...
# 2021-06-15 16:43:21,131 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:21,132 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:21,132 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_1128.txt ...
# 2021-06-15 16:43:21,201 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:21,201 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:21,202 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_1245.txt ...
# 2021-06-15 16:43:21,253 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:21,254 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:21,255 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/994046_note_1743.txt ...
# 2021-06-15 16:43:21,307 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:21,308 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:21,308 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/1162635_note_2414.txt ...
# 2021-06-15 16:43:21,366 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:21,367 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:21,368 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/936952_note_1603.txt ...
# 2021-06-15 16:43:21,448 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:21,449 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:21,449 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_4360.txt ...
# 2021-06-15 16:43:21,501 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:21,502 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:21,502 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_7667.txt ...
# 2021-06-15 16:43:21,574 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:21,575 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:21,576 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_1727.txt ...
# 2021-06-15 16:43:21,627 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:21,628 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:21,628 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_4073.txt ...
# 2021-06-15 16:43:21,679 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:21,680 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:21,681 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_3728.txt ...
# 2021-06-15 16:43:21,732 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:21,733 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:21,734 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_1242.txt ...
# 2021-06-15 16:43:21,785 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:21,786 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:21,786 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/1150871_note_2304.txt ...
# 2021-06-15 16:43:21,838 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:21,838 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:21,839 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_1942.txt ...
# 2021-06-15 16:43:21,896 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:21,897 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:21,898 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/1795334_note_4352.txt ...
# 2021-06-15 16:43:21,950 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:21,951 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:21,952 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/929667_note_1559.txt ...
# 2021-06-15 16:43:22,004 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:22,005 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:22,006 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_408.txt ...
# 2021-06-15 16:43:22,059 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:22,060 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:22,060 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_5937.txt ...
# 2021-06-15 16:43:22,112 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:22,113 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:22,114 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_1830.txt ...
# 2021-06-15 16:43:22,166 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:22,167 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:22,168 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_1069.txt ...
# last index not match  ('MA', 'lesion', (1338, 1340))
# 2021-06-15 16:43:22,222 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:22,223 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:22,224 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/2660331_note_8739.txt ...
# 2021-06-15 16:43:22,287 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:22,288 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:22,289 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_8583.txt ...
# 2021-06-15 16:43:22,341 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:22,342 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:22,343 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/2585415_note_8320.txt ...
# 2021-06-15 16:43:22,397 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:22,398 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:22,398 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_5696.txt ...
# 2021-06-15 16:43:22,455 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:22,456 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:22,457 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/2493413_note_7698.txt ...
# 2021-06-15 16:43:22,509 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:22,510 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:22,511 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_2320.txt ...
# 2021-06-15 16:43:22,563 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:22,564 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:22,564 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/1158336_note_2399.txt ...
# 2021-06-15 16:43:22,630 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:22,631 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:22,632 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/844034_note_1211.txt ...
# 2021-06-15 16:43:22,692 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:22,693 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:22,693 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_9206.txt ...
# 2021-06-15 16:43:22,745 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:22,746 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:22,746 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/2476700_note_7181.txt ...
# 2021-06-15 16:43:22,798 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:22,799 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:22,799 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_1249.txt ...
# 2021-06-15 16:43:22,850 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:22,851 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:22,851 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/269536_note_700.txt ...
# 2021-06-15 16:43:22,905 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:22,906 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:22,906 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_2063.txt ...
# 2021-06-15 16:43:22,968 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:22,969 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:22,970 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_416.txt ...
# 2021-06-15 16:43:23,023 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:23,024 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:23,024 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/2192394_note_6089.txt ...
# 2021-06-15 16:43:23,078 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:23,079 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:23,079 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_6092.txt ...
# 2021-06-15 16:43:23,133 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:23,134 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:23,134 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/2060252_note_5874.txt ...
# 2021-06-15 16:43:23,191 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:23,191 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:23,192 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/1968890_note_5506.txt ...
# 2021-06-15 16:43:23,244 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:23,245 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:23,246 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_1081.txt ...
# 2021-06-15 16:43:23,296 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:23,297 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:23,298 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_2908.txt ...
# 2021-06-15 16:43:23,352 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:23,352 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:23,353 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/1647323_note_3946.txt ...
# 2021-06-15 16:43:23,405 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:23,406 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:23,406 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/1047007_note_1791.txt ...
# 2021-06-15 16:43:23,458 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:23,459 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:23,459 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_7785.txt ...
# 2021-06-15 16:43:23,511 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:23,512 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:23,513 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_1732.txt ...
# 2021-06-15 16:43:23,564 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:23,565 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:23,566 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_322.txt ...
# 2021-06-15 16:43:23,618 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:23,619 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:23,619 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_5171.txt ...
# 2021-06-15 16:43:23,681 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:23,682 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:23,682 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_3006.txt ...
# 2021-06-15 16:43:23,734 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:23,735 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:23,736 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_8115.txt ...
# 2021-06-15 16:43:23,787 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:23,788 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:23,788 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_1783.txt ...
# 2021-06-15 16:43:23,843 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:23,844 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:23,844 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/217884_note_474.txt ...
# 2021-06-15 16:43:23,917 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:23,918 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:23,919 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_8007.txt ...
# 2021-06-15 16:43:23,979 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:23,980 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:23,980 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_5983.txt ...
# 2021-06-15 16:43:24,034 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:24,035 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:24,035 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_1363.txt ...
# 2021-06-15 16:43:24,052 WARNING ('OU  ', 'laterality', (2935, 2939)) offset is overlapped with previous entity; current tok not overlap
# 2021-06-15 16:43:24,104 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:24,105 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:24,106 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_2235.txt ...
# 2021-06-15 16:43:24,206 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:24,207 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:24,207 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_7563.txt ...
# last index not match  ('OU  ', 'laterality', (2935, 2939))
# 2021-06-15 16:43:24,278 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:24,279 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:24,280 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_8096.txt ...
# 2021-06-15 16:43:24,332 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:24,333 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:24,333 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_8502.txt ...
# 2021-06-15 16:43:24,389 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:24,390 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:24,390 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_6125.txt ...
# 2021-06-15 16:43:24,441 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:24,442 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:24,443 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_6511.txt ...
# 2021-06-15 16:43:24,495 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:24,496 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:24,496 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_2297.txt ...
# 2021-06-15 16:43:24,547 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:24,548 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:24,548 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_9103.txt ...
# 2021-06-15 16:43:24,601 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:24,602 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:24,602 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_7939.txt ...
# 2021-06-15 16:43:24,656 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:24,657 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:24,658 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/2109779_note_5917.txt ...
# 2021-06-15 16:43:24,709 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:24,710 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:24,711 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/1649489_note_3986.txt ...
# 2021-06-15 16:43:24,765 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:24,766 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:24,767 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_7745.txt ...
# 2021-06-15 16:43:24,824 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:24,825 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:24,825 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_8850.txt ...
# 2021-06-15 16:43:24,886 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:24,887 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:24,887 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_3171.txt ...
# 2021-06-15 16:43:24,938 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:24,939 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:24,940 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/2298176_note_6522.txt ...
# 2021-06-15 16:43:24,991 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:24,992 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:24,992 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_3218.txt ...
# 2021-06-15 16:43:25,047 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:25,048 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:25,048 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_3180.txt ...
# 2021-06-15 16:43:25,099 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:25,100 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:25,101 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_466.txt ...
# 2021-06-15 16:43:25,152 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:25,153 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:25,154 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_5925.txt ...
# 2021-06-15 16:43:25,205 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:25,206 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:25,206 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/2452845_note_6850.txt ...
# 2021-06-15 16:43:25,268 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:25,268 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:25,269 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/2118556_note_5964.txt ...
# 2021-06-15 16:43:25,321 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:25,322 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:25,322 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_3719.txt ...
# 2021-06-15 16:43:25,373 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:25,374 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:25,374 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_2415.txt ...
# 2021-06-15 16:43:25,432 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:25,433 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:25,433 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/2485245_note_7318.txt ...
# 2021-06-15 16:43:25,485 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:25,485 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:25,486 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_8106.txt ...
# 2021-06-15 16:43:25,547 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:25,548 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:25,549 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_8904.txt ...
# 2021-06-15 16:43:25,608 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:25,609 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:25,609 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/1492846_note_3723.txt ...
# 2021-06-15 16:43:25,661 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:25,662 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:25,663 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_7750.txt ...
# 2021-06-15 16:43:25,721 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:25,722 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:25,723 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/2525474_note_7919.txt ...
# 2021-06-15 16:43:25,786 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:25,787 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:25,787 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_933.txt ...
# 2021-06-15 16:43:25,839 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:25,840 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:25,841 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_7589.txt ...
# 2021-06-15 16:43:25,894 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:25,895 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:25,896 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/392314_note_1008.txt ...
# 2021-06-15 16:43:25,952 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:25,953 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:25,953 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_7515.txt ...
# 2021-06-15 16:43:26,006 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:26,006 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:26,007 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_9154.txt ...
# 2021-06-15 16:43:26,067 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:26,068 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:26,069 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_2248.txt ...
# 2021-06-15 16:43:26,087 WARNING ('Right  ', 'laterality', (1346, 1353)) offset is overlapped with previous entity; current tok not overlap
# 2021-06-15 16:43:26,088 WARNING ('Left  ', 'laterality', (2351, 2357)) offset is overlapped with previous entity; current tok not overlap
# 2021-06-15 16:43:26,152 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:26,153 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:26,153 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_2850.txt ...
# 2021-06-15 16:43:26,213 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:26,214 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:26,214 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_7872.txt ...
# 2021-06-15 16:43:26,284 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:26,285 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:26,285 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/1816965_note_4518.txt ...
# last index not match  ('Right  ', 'laterality', (1346, 1353))
# last index not match  ('Left  ', 'laterality', (2351, 2357))
# 2021-06-15 16:43:26,339 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:26,340 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:26,341 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_2109.txt ...
# 2021-06-15 16:43:26,407 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:26,408 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:26,409 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_4201.txt ...
# 2021-06-15 16:43:26,469 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:26,469 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:26,470 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_8903.txt ...
# 2021-06-15 16:43:26,521 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:26,522 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:26,522 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/916985_note_1493.txt ...
# 2021-06-15 16:43:26,574 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:26,575 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:26,575 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/1810666_note_4397.txt ...
# 2021-06-15 16:43:26,672 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:26,673 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:26,674 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_5975.txt ...
# 2021-06-15 16:43:26,732 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:26,733 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:26,733 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_2446.txt ...
# 2021-06-15 16:43:26,784 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:26,785 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:26,786 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_4453.txt ...
# 2021-06-15 16:43:26,847 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:26,848 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:26,849 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/1952828_note_5361.txt ...
# 2021-06-15 16:43:26,907 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:26,908 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:26,909 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_9228.txt ...
# 2021-06-15 16:43:26,974 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:26,975 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:26,975 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/2183623_note_6078.txt ...
# 2021-06-15 16:43:27,027 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:27,028 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:27,029 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/2057802_note_5836.txt ...
# 2021-06-15 16:43:27,080 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:27,081 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:27,082 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/298406_note_809.txt ...
# 2021-06-15 16:43:27,136 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:27,137 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:27,138 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/2369330_note_6618.txt ...
# 2021-06-15 16:43:27,204 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:27,205 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:27,205 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_3992.txt ...
# 2021-06-15 16:43:27,263 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:27,264 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:27,264 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_6192.txt ...
# 2021-06-15 16:43:27,315 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:27,316 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:27,317 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_4017.txt ...
# 2021-06-15 16:43:27,369 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:27,370 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:27,370 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/174109_note_438.txt ...
# 2021-06-15 16:43:27,423 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:27,424 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:27,425 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_469.txt ...
# 2021-06-15 16:43:27,476 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:27,477 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:27,478 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_8675.txt ...
# 2021-06-15 16:43:27,531 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:27,532 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:27,533 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_209.txt ...
# 2021-06-15 16:43:27,593 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:27,594 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:27,595 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_6133.txt ...
# 2021-06-15 16:43:27,645 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:27,646 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:27,647 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_1574.txt ...
# 2021-06-15 16:43:27,698 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:27,699 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:27,700 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/157996_note_418.txt ...
# 2021-06-15 16:43:27,751 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:27,752 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:27,752 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_4008.txt ...
# 2021-06-15 16:43:27,807 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:27,808 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:27,808 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_2200.txt ...
# 2021-06-15 16:43:27,860 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:27,861 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:27,862 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_9136.txt ...
# 2021-06-15 16:43:27,914 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:27,915 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:27,915 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/1717357_note_4074.txt ...
# 2021-06-15 16:43:27,967 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:27,967 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:27,968 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_3128.txt ...
# 2021-06-15 16:43:28,020 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:28,021 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:28,021 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_2085.txt ...
# 2021-06-15 16:43:28,076 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:28,077 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:28,077 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_8139.txt ...
# 2021-06-15 16:43:28,095 WARNING ('Right  ', 'laterality', (1213, 1220)) offset is overlapped with previous entity; current tok not overlap
# 2021-06-15 16:43:28,147 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:28,148 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:28,149 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_1533.txt ...
# 2021-06-15 16:43:28,201 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:28,202 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:28,202 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_1135.txt ...
# 2021-06-15 16:43:28,258 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:28,258 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:28,259 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/2237210_note_6158.txt ...
# last index not match  ('Right  ', 'laterality', (1213, 1220))
# 2021-06-15 16:43:28,311 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:28,312 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:28,313 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_6159.txt ...
# 2021-06-15 16:43:28,365 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:28,366 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:28,366 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_171.txt ...
# 2021-06-15 16:43:28,431 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:28,432 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:28,433 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_1962.txt ...
# 2021-06-15 16:43:28,449 WARNING ('severe\xa0', 'severity', (1734, 1741)) offset is overlapped with previous entity; current tok not overlap
# 2021-06-15 16:43:28,449 WARNING ('OD\xa0', 'laterality', (1987, 1990)) offset is overlapped with previous entity; current tok not overlap
# 2021-06-15 16:43:28,450 WARNING ('OS\xa0', 'laterality', (2032, 2035)) offset is overlapped with previous entity; current tok not overlap
# 2021-06-15 16:43:28,501 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:28,502 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:28,503 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/1741070_note_4310.txt ...
# 2021-06-15 16:43:28,558 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:28,559 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:28,559 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_830.txt ...
# 2021-06-15 16:43:28,611 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:28,612 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:28,613 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_7702.txt ...
# last index not match  ('severe\xa0', 'severity', (1734, 1741))
# last index not match  ('OD\xa0', 'laterality', (1987, 1990))
# last index not match  ('OS\xa0', 'laterality', (2032, 2035))
# 2021-06-15 16:43:28,675 INFO sentence boundary detection class initiated.
# 2021-06-15 16:43:28,676 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:43:28,676 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/train_set/note_7927.txt ...
# 2021-06-15 16:43:28,679 WARNING '8.1 per' cannot be parsed by current rule.
# ...
# 2021-06-15 16:47:30,543 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:30,544 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:30,544 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/257077_note_501.txt ...
# 2021-06-15 16:47:30,618 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:30,619 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:30,620 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/2485245_note_7318.txt ...
# 2021-06-15 16:47:30,680 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:30,681 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:30,682 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/note_3194.txt ...
# 2021-06-15 16:47:30,737 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:30,738 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:30,739 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/2654416_note_8704.txt ...
# 2021-06-15 16:47:30,803 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:30,804 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:30,805 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/note_2442.txt ...
# 2021-06-15 16:47:30,806 WARNING '7.2 ' cannot be parsed by current rule.
# 2021-06-15 16:47:30,864 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:30,865 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:30,866 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/note_7563.txt ...
# 2021-06-15 16:47:30,953 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:30,954 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:30,955 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/note_5975.txt ...
# 2021-06-15 16:47:31,009 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:31,010 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:31,011 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/2183623_note_6078.txt ...
# 2021-06-15 16:47:31,065 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:31,066 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:31,066 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/note_1245.txt ...
# 2021-06-15 16:47:31,119 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:31,120 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:31,120 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/2447977_note_6711.txt ...
# 2021-06-15 16:47:31,178 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:31,178 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:31,179 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/note_6133.txt ...
# 2021-06-15 16:47:31,239 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:31,240 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:31,240 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/1458921_note_3276.txt ...
# 2021-06-15 16:47:31,312 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:31,313 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:31,313 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/note_7667.txt ...
# 2021-06-15 16:47:31,370 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:31,371 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:31,371 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/note_2162.txt ...
# 2021-06-15 16:47:31,440 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:31,441 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:31,441 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/note_1533.txt ...
# 2021-06-15 16:47:31,511 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:31,512 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:31,512 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/note_8850.txt ...
# 2021-06-15 16:47:31,568 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:31,569 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:31,569 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/note_5884.txt ...
# 2021-06-15 16:47:31,626 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:31,627 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:31,627 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/note_8321.txt ...
# 2021-06-15 16:47:31,699 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:31,700 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:31,700 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/note_6192.txt ...
# 2021-06-15 16:47:31,755 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:31,756 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:31,756 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/39541_note_166.txt ...
# 2021-06-15 16:47:31,812 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:31,813 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:31,814 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/note_8432.txt ...
# 2021-06-15 16:47:31,879 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:31,880 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:31,880 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/note_2415.txt ...
# 2021-06-15 16:47:31,941 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:31,942 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:31,942 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/note_3797.txt ...
# 2021-06-15 16:47:31,996 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:31,997 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:31,998 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/1952828_note_5361.txt ...
# 2021-06-15 16:47:32,053 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:32,054 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:32,054 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/note_4416.txt ...
# 2021-06-15 16:47:32,127 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:32,128 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:32,128 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/note_2433.txt ...
# 2021-06-15 16:47:32,187 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:32,188 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:32,188 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/2748168_note_9227.txt ...
# 2021-06-15 16:47:32,243 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:32,244 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:32,244 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/460233_note_1091.txt ...
# 2021-06-15 16:47:32,305 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:32,306 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:32,307 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/1158336_note_2399.txt ...
# 2021-06-15 16:47:32,382 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:32,383 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:32,384 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/note_5983.txt ...
# 2021-06-15 16:47:32,438 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:32,439 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:32,440 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/1342474_note_3109.txt ...
# 2021-06-15 16:47:32,494 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:32,495 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:32,495 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/217884_note_474.txt ...
# 2021-06-15 16:47:32,565 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:32,566 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:32,566 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/2484779_note_7312.txt ...
# 2021-06-15 16:47:32,621 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:32,622 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:32,622 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/note_9103.txt ...
# 2021-06-15 16:47:32,678 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:32,679 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:32,679 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/2453695_note_6919.txt ...
# 2021-06-15 16:47:32,749 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:32,750 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:32,751 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/note_2248.txt ...
# 2021-06-15 16:47:32,775 WARNING ('Right  ', 'laterality', (1346, 1353)) offset is overlapped with previous entity; current tok not overlap
# 2021-06-15 16:47:32,776 WARNING ('Left  ', 'laterality', (2351, 2357)) offset is overlapped with previous entity; current tok not overlap
# 2021-06-15 16:47:32,842 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:32,843 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:32,843 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/1741070_note_4310.txt ...
# 2021-06-15 16:47:32,907 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:32,908 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:32,909 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/note_4009.txt ...
# 2021-06-15 16:47:32,964 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:32,965 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:32,966 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/note_4017.txt ...
# last index not match  ('Right  ', 'laterality', (1346, 1353))
# last index not match  ('Left  ', 'laterality', (2351, 2357))
# 2021-06-15 16:47:33,038 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:33,039 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:33,039 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/note_2444.txt ...
# 2021-06-15 16:47:33,041 WARNING '7.2 ' cannot be parsed by current rule.
# 2021-06-15 16:47:33,099 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:33,100 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:33,100 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/1424866_note_3176.txt ...
# 2021-06-15 16:47:33,155 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:33,156 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:33,157 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/1936668_note_5255.txt ...
# 2021-06-15 16:47:33,215 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:33,216 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:33,216 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/note_5742.txt ...
# 2021-06-15 16:47:33,297 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:33,298 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:33,298 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/1795334_note_4352.txt ...
# 2021-06-15 16:47:33,353 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:33,354 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:33,355 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/note_1128.txt ...
# 2021-06-15 16:47:33,426 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:33,427 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:33,427 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/note_980.txt ...
# 2021-06-15 16:47:33,480 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:33,481 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:33,482 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/note_1962.txt ...
# 2021-06-15 16:47:33,493 WARNING ('severe\xa0', 'severity', (1734, 1741)) offset is overlapped with previous entity; current tok not overlap
# 2021-06-15 16:47:33,493 WARNING ('OD\xa0', 'laterality', (1987, 1990)) offset is overlapped with previous entity; current tok not overlap
# 2021-06-15 16:47:33,494 WARNING ('OS\xa0', 'laterality', (2032, 2035)) offset is overlapped with previous entity; current tok not overlap
# 2021-06-15 16:47:33,547 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:33,548 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:33,549 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/note_467.txt ...
# 2021-06-15 16:47:33,604 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:33,604 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:33,605 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/1162635_note_2414.txt ...
# 2021-06-15 16:47:33,667 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:33,668 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:33,668 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/note_3128.txt ...
# last index not match  ('severe\xa0', 'severity', (1734, 1741))
# last index not match  ('OD\xa0', 'laterality', (1987, 1990))
# last index not match  ('OS\xa0', 'laterality', (2032, 2035))
# last index not match  ('MA', 'lesion', (450, 452))
# 2021-06-15 16:47:33,724 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:33,725 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:33,726 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/2476700_note_7181.txt ...
# 2021-06-15 16:47:33,780 INFO sentence boundary detection class initiated.
# 2021-06-15 16:47:33,781 INFO word level tokenization with replace_number set to False
# 2021-06-15 16:47:33,782 INFO current processing /home/zehao.yu/workspace/py3/dr_ann/data/used/test_set/note_3956.txt ...

# %%
dpos[0]
# Out:
# [(0,
#   'laterality-lesion',
#   'Proliferative diabetic retinopathy of [s1] right eye [e1] with macular edema determined by examination associated with type 2 diabetes mellitus E11 . 3511 250.50 362.07 362.02 Treatment Hx : IVA OS 3 / 6 / 18 PRP OD ( unknown date ) Intravitreal injection ( unknown # and date ) NS in both eyes .',
#   '[s2] Proliferative diabetic retinopathy [e2] of right eye with macular edema determined by examination associated with type 2 diabetes mellitus E11 . 3511 250.50 362.07 362.02 Treatment Hx : IVA OS 3 / 6 / 18 PRP OD ( unknown date ) Intravitreal injection ( unknown # and date ) NS in both eyes .',
#   'laterality',
#   'lesion',
#   'T12',
#   'T1',
#   'note_9152'),
#  (0,
#   'laterality-lesion',
#   'Proliferative diabetic retinopathy of [s1] right eye [e1] with macular edema determined by examination associated with type 2 diabetes mellitus E11 . 3511 250.50 362.07 362.02 Treatment Hx : IVA OS 3 / 6 / 18 PRP OD ( unknown date ) Intravitreal injection ( unknown # and date ) NS in both eyes .',
#   'Proliferative diabetic retinopathy of right eye with [s2] macular edema [e2] determined by examination associated with type 2 diabetes mellitus E11 . 3511 250.50 362.07 362.02 Treatment Hx : IVA OS 3 / 6 / 18 PRP OD ( unknown date ) Intravitreal injection ( unknown # and date ) NS in both eyes .',
#   'laterality',
#   'lesion',
#   'T12',
#   'T2',
#   'note_9152'),
#  (0,
#   'laterality-lesion',
#   'Hx of PDR [s1] OD [e1] , Severe NPDR OS OD - Vitreous hemorrhage OD - In setting of long - standing insulin - dependent T 2 DM - Recent rise in A 1 C from 7.9 ( 1 year ago ) to 10.2 ( in the last 120 days ) - VA 20 / 25 , IOP 19 - Vit heme mostly resolved , no tears / detachment - Inadequate PRP OS - Severe NPDR with macular edema OS - DBH and MAs in posterior pole - VA 20 / 25 - Venous beading in multiple quadrants , IRMA , cluster of MAs temporally - Would hold off on injection at this time due to good VA and will stabilize OD first Discussed options with patient .',
#   'Hx of [s2] PDR [e2] OD , Severe NPDR OS OD - Vitreous hemorrhage OD - In setting of long - standing insulin - dependent T 2 DM - Recent rise in A 1 C from 7.9 ( 1 year ago ) to 10.2 ( in the last 120 days ) - VA 20 / 25 , IOP 19 - Vit heme mostly resolved , no tears / detachment - Inadequate PRP OS - Severe NPDR with macular edema OS - DBH and MAs in posterior pole - VA 20 / 25 - Venous beading in multiple quadrants , IRMA , cluster of MAs temporally - Would hold off on injection at this time due to good VA and will stabilize OD first Discussed options with patient .',
#   'laterality',
#   'lesion',
#   'T13',
#   'T3',
#   'note_9152'),
#  (0,
#   'severity-lesion',
#   'Hx of PDR OD , [s1] Severe [e1] NPDR OS OD - Vitreous hemorrhage OD - In setting of long - standing insulin - dependent T 2 DM - Recent rise in A 1 C from 7.9 ( 1 year ago ) to 10.2 ( in the last 120 days ) - VA 20 / 25 , IOP 19 - Vit heme mostly resolved , no tears / detachment - Inadequate PRP OS - Severe NPDR with macular edema OS - DBH and MAs in posterior pole - VA 20 / 25 - Venous beading in multiple quadrants , IRMA , cluster of MAs temporally - Would hold off on injection at this time due to good VA and will stabilize OD first Discussed options with patient .',
#   'Hx of PDR OD , Severe [s2] NPDR [e2] OS OD - Vitreous hemorrhage OD - In setting of long - standing insulin - dependent T 2 DM - Recent rise in A 1 C from 7.9 ( 1 year ago ) to 10.2 ( in the last 120 days ) - VA 20 / 25 , IOP 19 - Vit heme mostly resolved , no tears / detachment - Inadequate PRP OS - Severe NPDR with macular edema OS - DBH and MAs in posterior pole - VA 20 / 25 - Venous beading in multiple quadrants , IRMA , cluster of MAs temporally - Would hold off on injection at this time due to good VA and will stabilize OD first Discussed options with patient .',
#   'severity',
#   'lesion',
#   'T14',
#   'T4',
#   'note_9152'),
#  (0,
#   'laterality-lesion',
#   'Hx of PDR OD , Severe NPDR [s1] OS [e1] OD - Vitreous hemorrhage OD - In setting of long - standing insulin - dependent T 2 DM - Recent rise in A 1 C from 7.9 ( 1 year ago ) to 10.2 ( in the last 120 days ) - VA 20 / 25 , IOP 19 - Vit heme mostly resolved , no tears / detachment - Inadequate PRP OS - Severe NPDR with macular edema OS - DBH and MAs in posterior pole - VA 20 / 25 - Venous beading in multiple quadrants , IRMA , cluster of MAs temporally - Would hold off on injection at this time due to good VA and will stabilize OD first Discussed options with patient .',
#   'Hx of PDR OD , Severe [s2] NPDR [e2] OS OD - Vitreous hemorrhage OD - In setting of long - standing insulin - dependent T 2 DM - Recent rise in A 1 C from 7.9 ( 1 year ago ) to 10.2 ( in the last 120 days ) - VA 20 / 25 , IOP 19 - Vit heme mostly resolved , no tears / detachment - Inadequate PRP OS - Severe NPDR with macular edema OS - DBH and MAs in posterior pole - VA 20 / 25 - Venous beading in multiple quadrants , IRMA , cluster of MAs temporally - Would hold off on injection at this time due to good VA and will stabilize OD first Discussed options with patient .',
#   'laterality',
#   'lesion',
#   'T15',
#   'T4',
#   'note_9152'),
#  (0,
#   'laterality-lesion',
#   'Hx of PDR OD , Severe NPDR OS [s1] OD [e1] - Vitreous hemorrhage OD - In setting of long - standing insulin - dependent T 2 DM - Recent rise in A 1 C from 7.9 ( 1 year ago ) to 10.2 ( in the last 120 days ) - VA 20 / 25 , IOP 19 - Vit heme mostly resolved , no tears / detachment - Inadequate PRP OS - Severe NPDR with macular edema OS - DBH and MAs in posterior pole - VA 20 / 25 - Venous beading in multiple quadrants , IRMA , cluster of MAs temporally - Would hold off on injection at this time due to good VA and will stabilize OD first Discussed options with patient .',
#   'Hx of PDR OD , Severe NPDR OS OD - [s2] Vitreous hemorrhage [e2] OD - In setting of long - standing insulin - dependent T 2 DM - Recent rise in A 1 C from 7.9 ( 1 year ago ) to 10.2 ( in the last 120 days ) - VA 20 / 25 , IOP 19 - Vit heme mostly resolved , no tears / detachment - Inadequate PRP OS - Severe NPDR with macular edema OS - DBH and MAs in posterior pole - VA 20 / 25 - Venous beading in multiple quadrants , IRMA , cluster of MAs temporally - Would hold off on injection at this time due to good VA and will stabilize OD first Discussed options with patient .',
#   'laterality',
#   'lesion',
#   'T22',
#   'T5',
#   'note_9152'),
#  (0,
#   'laterality-lesion',
#   'Hx of PDR OD , Severe NPDR OS OD - Vitreous hemorrhage [s1] OD [e1] - In setting of long - standing insulin - dependent T 2 DM - Recent rise in A 1 C from 7.9 ( 1 year ago ) to 10.2 ( in the last 120 days ) - VA 20 / 25 , IOP 19 - Vit heme mostly resolved , no tears / detachment - Inadequate PRP OS - Severe NPDR with macular edema OS - DBH and MAs in posterior pole - VA 20 / 25 - Venous beading in multiple quadrants , IRMA , cluster of MAs temporally - Would hold off on injection at this time due to good VA and will stabilize OD first Discussed options with patient .',
#   'Hx of PDR OD , Severe NPDR OS OD - Vitreous hemorrhage OD - In setting of long - standing insulin - dependent T 2 DM - Recent rise in A 1 C from 7.9 ( 1 year ago ) to 10.2 ( in the last 120 days ) - VA 20 / 25 , IOP 19 - [s2] Vit heme [e2] mostly resolved , no tears / detachment - Inadequate PRP OS - Severe NPDR with macular edema OS - DBH and MAs in posterior pole - VA 20 / 25 - Venous beading in multiple quadrants , IRMA , cluster of MAs temporally - Would hold off on injection at this time due to good VA and will stabilize OD first Discussed options with patient .',
#   'laterality',
#   'lesion',
#   'T16',
#   'T17',
#   'note_9152'),
#  (0,
#   'laterality-lesion',
#   'Hx of PDR OD , Severe NPDR OS OD - Vitreous hemorrhage OD - In setting of long - standing insulin - dependent T 2 DM - Recent rise in A 1 C from 7.9 ( 1 year ago ) to 10.2 ( in the last 120 days ) - VA 20 / 25 , IOP 19 - Vit heme mostly resolved , no tears / detachment - Inadequate PRP [s1] OS [e1] - Severe NPDR with macular edema OS - DBH and MAs in posterior pole - VA 20 / 25 - Venous beading in multiple quadrants , IRMA , cluster of MAs temporally - Would hold off on injection at this time due to good VA and will stabilize OD first Discussed options with patient .',
#   'Hx of PDR OD , Severe NPDR OS OD - Vitreous hemorrhage OD - In setting of long - standing insulin - dependent T 2 DM - Recent rise in A 1 C from 7.9 ( 1 year ago ) to 10.2 ( in the last 120 days ) - VA 20 / 25 , IOP 19 - Vit heme mostly resolved , no tears / detachment - Inadequate PRP OS - Severe [s2] NPDR [e2] with macular edema OS - DBH and MAs in posterior pole - VA 20 / 25 - Venous beading in multiple quadrants , IRMA , cluster of MAs temporally - Would hold off on injection at this time due to good VA and will stabilize OD first Discussed options with patient .',
#   'laterality',
#   'lesion',
#   'T18',
#   'T6',
#   'note_9152'),
#  (0,
#   'severity-lesion',
#   'Hx of PDR OD , Severe NPDR OS OD - Vitreous hemorrhage OD - In setting of long - standing insulin - dependent T 2 DM - Recent rise in A 1 C from 7.9 ( 1 year ago ) to 10.2 ( in the last 120 days ) - VA 20 / 25 , IOP 19 - Vit heme mostly resolved , no tears / detachment - Inadequate PRP OS - [s1] Severe [e1] NPDR with macular edema OS - DBH and MAs in posterior pole - VA 20 / 25 - Venous beading in multiple quadrants , IRMA , cluster of MAs temporally - Would hold off on injection at this time due to good VA and will stabilize OD first Discussed options with patient .',
#   'Hx of PDR OD , Severe NPDR OS OD - Vitreous hemorrhage OD - In setting of long - standing insulin - dependent T 2 DM - Recent rise in A 1 C from 7.9 ( 1 year ago ) to 10.2 ( in the last 120 days ) - VA 20 / 25 , IOP 19 - Vit heme mostly resolved , no tears / detachment - Inadequate PRP OS - Severe [s2] NPDR [e2] with macular edema OS - DBH and MAs in posterior pole - VA 20 / 25 - Venous beading in multiple quadrants , IRMA , cluster of MAs temporally - Would hold off on injection at this time due to good VA and will stabilize OD first Discussed options with patient .',
#   'severity',
#   'lesion',
#   'T19',
#   'T6',
#   'note_9152'),
#  (0,
#   'laterality-lesion',
#   'Hx of PDR OD , Severe NPDR OS OD - Vitreous hemorrhage OD - In setting of long - standing insulin - dependent T 2 DM - Recent rise in A 1 C from 7.9 ( 1 year ago ) to 10.2 ( in the last 120 days ) - VA 20 / 25 , IOP 19 - Vit heme mostly resolved , no tears / detachment - Inadequate PRP [s1] OS [e1] - Severe NPDR with macular edema OS - DBH and MAs in posterior pole - VA 20 / 25 - Venous beading in multiple quadrants , IRMA , cluster of MAs temporally - Would hold off on injection at this time due to good VA and will stabilize OD first Discussed options with patient .',
#   'Hx of PDR OD , Severe NPDR OS OD - Vitreous hemorrhage OD - In setting of long - standing insulin - dependent T 2 DM - Recent rise in A 1 C from 7.9 ( 1 year ago ) to 10.2 ( in the last 120 days ) - VA 20 / 25 , IOP 19 - Vit heme mostly resolved , no tears / detachment - Inadequate PRP OS - Severe NPDR with [s2] macular edema [e2] OS - DBH and MAs in posterior pole - VA 20 / 25 - Venous beading in multiple quadrants , IRMA , cluster of MAs temporally - Would hold off on injection at this time due to good VA and will stabilize OD first Discussed options with patient .',
#   'laterality',
#   'lesion',
#   'T18',
#   'T7',
#   'note_9152'),
#  (0,
#   'laterality-lesion',
#   'Hx of PDR OD , Severe NPDR OS OD - Vitreous hemorrhage OD - In setting of long - standing insulin - dependent T 2 DM - Recent rise in A 1 C from 7.9 ( 1 year ago ) to 10.2 ( in the last 120 days ) - VA 20 / 25 , IOP 19 - Vit heme mostly resolved , no tears / detachment - Inadequate PRP OS - Severe NPDR with macular edema [s1] OS [e1] - DBH and MAs in posterior pole - VA 20 / 25 - Venous beading in multiple quadrants , IRMA , cluster of MAs temporally - Would hold off on injection at this time due to good VA and will stabilize OD first Discussed options with patient .',
#   'Hx of PDR OD , Severe NPDR OS OD - Vitreous hemorrhage OD - In setting of long - standing insulin - dependent T 2 DM - Recent rise in A 1 C from 7.9 ( 1 year ago ) to 10.2 ( in the last 120 days ) - VA 20 / 25 , IOP 19 - Vit heme mostly resolved , no tears / detachment - Inadequate PRP OS - Severe NPDR with macular edema OS - [s2] DBH [e2] and MAs in posterior pole - VA 20 / 25 - Venous beading in multiple quadrants , IRMA , cluster of MAs temporally - Would hold off on injection at this time due to good VA and will stabilize OD first Discussed options with patient .',
#   'laterality',
#   'lesion',
#   'T20',
#   'T8',
#   'note_9152'),
#  (0,
#   'laterality-lesion',
#   'Hx of PDR OD , Severe NPDR OS OD - Vitreous hemorrhage OD - In setting of long - standing insulin - dependent T 2 DM - Recent rise in A 1 C from 7.9 ( 1 year ago ) to 10.2 ( in the last 120 days ) - VA 20 / 25 , IOP 19 - Vit heme mostly resolved , no tears / detachment - Inadequate PRP OS - Severe NPDR with macular edema [s1] OS [e1] - DBH and MAs in posterior pole - VA 20 / 25 - Venous beading in multiple quadrants , IRMA , cluster of MAs temporally - Would hold off on injection at this time due to good VA and will stabilize OD first Discussed options with patient .',
#   'Hx of PDR OD , Severe NPDR OS OD - Vitreous hemorrhage OD - In setting of long - standing insulin - dependent T 2 DM - Recent rise in A 1 C from 7.9 ( 1 year ago ) to 10.2 ( in the last 120 days ) - VA 20 / 25 , IOP 19 - Vit heme mostly resolved , no tears / detachment - Inadequate PRP OS - Severe NPDR with macular edema OS - DBH and [s2] MAs [e2] in posterior pole - VA 20 / 25 - Venous beading in multiple quadrants , IRMA , cluster of MAs temporally - Would hold off on injection at this time due to good VA and will stabilize OD first Discussed options with patient .',
#   'laterality',
#   'lesion',
#   'T20',
#   'T9',
#   'note_9152'),
#  (0,
#   'laterality-lesion',
#   'Hx of PDR OD , Severe NPDR OS OD - Vitreous hemorrhage OD - In setting of long - standing insulin - dependent T 2 DM - Recent rise in A 1 C from 7.9 ( 1 year ago ) to 10.2 ( in the last 120 days ) - VA 20 / 25 , IOP 19 - Vit heme mostly resolved , no tears / detachment - Inadequate PRP OS - Severe NPDR with macular edema [s1] OS [e1] - DBH and MAs in posterior pole - VA 20 / 25 - Venous beading in multiple quadrants , IRMA , cluster of MAs temporally - Would hold off on injection at this time due to good VA and will stabilize OD first Discussed options with patient .',
#   'Hx of PDR OD , Severe NPDR OS OD - Vitreous hemorrhage OD - In setting of long - standing insulin - dependent T 2 DM - Recent rise in A 1 C from 7.9 ( 1 year ago ) to 10.2 ( in the last 120 days ) - VA 20 / 25 , IOP 19 - Vit heme mostly resolved , no tears / detachment - Inadequate PRP OS - Severe NPDR with macular edema OS - DBH and MAs in posterior pole - VA 20 / 25 - [s2] Venous beading [e2] in multiple quadrants , IRMA , cluster of MAs temporally - Would hold off on injection at this time due to good VA and will stabilize OD first Discussed options with patient .',
#   'laterality',
#   'lesion',
#   'T20',
#   'T21',
#   'note_9152'),
#  (0,
#   'laterality-lesion',
#   'Hx of PDR OD , Severe NPDR OS OD - Vitreous hemorrhage OD - In setting of long - standing insulin - dependent T 2 DM - Recent rise in A 1 C from 7.9 ( 1 year ago ) to 10.2 ( in the last 120 days ) - VA 20 / 25 , IOP 19 - Vit heme mostly resolved , no tears / detachment - Inadequate PRP OS - Severe NPDR with macular edema [s1] OS [e1] - DBH and MAs in posterior pole - VA 20 / 25 - Venous beading in multiple quadrants , IRMA , cluster of MAs temporally - Would hold off on injection at this time due to good VA and will stabilize OD first Discussed options with patient .',
#   'Hx of PDR OD , Severe NPDR OS OD - Vitreous hemorrhage OD - In setting of long - standing insulin - dependent T 2 DM - Recent rise in A 1 C from 7.9 ( 1 year ago ) to 10.2 ( in the last 120 days ) - VA 20 / 25 , IOP 19 - Vit heme mostly resolved , no tears / detachment - Inadequate PRP OS - Severe NPDR with macular edema OS - DBH and MAs in posterior pole - VA 20 / 25 - Venous beading in multiple quadrants , [s2] IRMA [e2] , cluster of MAs temporally - Would hold off on injection at this time due to good VA and will stabilize OD first Discussed options with patient .',
#   'laterality',
#   'lesion',
#   'T20',
#   'T10',
#   'note_9152'),
#  (0,
#   'laterality-lesion',
#   'Hx of PDR OD , Severe NPDR OS OD - Vitreous hemorrhage OD - In setting of long - standing insulin - dependent T 2 DM - Recent rise in A 1 C from 7.9 ( 1 year ago ) to 10.2 ( in the last 120 days ) - VA 20 / 25 , IOP 19 - Vit heme mostly resolved , no tears / detachment - Inadequate PRP OS - Severe NPDR with macular edema [s1] OS [e1] - DBH and MAs in posterior pole - VA 20 / 25 - Venous beading in multiple quadrants , IRMA , cluster of MAs temporally - Would hold off on injection at this time due to good VA and will stabilize OD first Discussed options with patient .',
#   'Hx of PDR OD , Severe NPDR OS OD - Vitreous hemorrhage OD - In setting of long - standing insulin - dependent T 2 DM - Recent rise in A 1 C from 7.9 ( 1 year ago ) to 10.2 ( in the last 120 days ) - VA 20 / 25 , IOP 19 - Vit heme mostly resolved , no tears / detachment - Inadequate PRP OS - Severe NPDR with macular edema OS - DBH and MAs in posterior pole - VA 20 / 25 - Venous beading in multiple quadrants , IRMA , cluster of [s2] MAs [e2] temporally - Would hold off on injection at this time due to good VA and will stabilize OD first Discussed options with patient .',
#   'laterality',
#   'lesion',
#   'T20',
#   'T11',
#   'note_9152'),
#  (0,
#   'laterality-lesion',
#   "Ocular Med ' s : Combigan ( 2 , 2 ) Ocular History : ( Bilateral ) CNVM s / p multiple IVL OU INJECTION HISTORY : Date ODOSMedications 03 / 29 / 11 XXIVL 04 / 18 / 11 XXIVL 05 / 16 / 11 XXIVL 06 / 22 / 11 XXIVL 07 / 26 / 11 XXIVL 08 / 26 / 11 X X IVL Review of Systems : Heart problems : no complaints Respiratory problems : no complaints General problems : no complaints ENT problems : no complaints Gastrointestinal problems : no complaints Urinary problems : no complaints Objective : Base Ophthalmology Exam Visual Acuity Right Left Dist cc 20 / 30 20 / 200 Method : Snellen - Linear Correction : Glasses Tonometry Right Left Pressure 13 13 Method : Applanation Time : 11 : 12 AM Wearing Rx Sphere Cylinder Axis Right - 0.50 + 0.75 035 Left Plano Sphere Manifest Refraction ( Retinoscopy ) Sphere Cylinder Axis Dist Right Plano + 0.75 050 Left + 0.50 + 0.75 125 Manifest Refraction # 2 Sphere Cylinder Axis Dist Right + 0.25 + 1.00 145 20 / 25 - Left + 0.50 + 0.75 130 NI Dilation Both eyes : 1.0 % Mydriacyl , 2.5 % Phenylephrine @ 11 : 12 AM Pupils Pupils Right PERRL Left PERRL Visual Fields Right Left Result Full Full Extraocular Movement Right Left Result Full Full Main Ophthalmology Exam External Exam Right Left External Normal Normal Slit Lamp Exam Right Left Lids / Lashes Blepharitis Blepharitis Conjunctiva / Sclera Injection Injection Cornea Lasik Scars Lasik Scars Anterior Chamber Deep and quiet Deep and quiet Iris Round and reactive Round and reactive Lens 1 + Nuclear sclerosis 1 + Nuclear sclerosis Vitreous pvd pvd Neuro / Psych Oriented x 3 : Yes Mood / Affect : Normal No notes on file Other testing : OCT : [s1] OD [e1] : + scar , decreased srf OS : erm , scar , no srf , + thickening Assessment and Plan : EXUDATIVE AGE - RELATED MACULAR DEGENERATION ( 362.52 ) OU Subretinal / intraretinal fluid present Plan intravitreal Lucentis today .",
#   "Ocular Med ' s : Combigan ( 2 , 2 ) Ocular History : ( Bilateral ) CNVM s / p multiple IVL OU INJECTION HISTORY : Date ODOSMedications 03 / 29 / 11 XXIVL 04 / 18 / 11 XXIVL 05 / 16 / 11 XXIVL 06 / 22 / 11 XXIVL 07 / 26 / 11 XXIVL 08 / 26 / 11 X X IVL Review of Systems : Heart problems : no complaints Respiratory problems : no complaints General problems : no complaints ENT problems : no complaints Gastrointestinal problems : no complaints Urinary problems : no complaints Objective : Base Ophthalmology Exam Visual Acuity Right Left Dist cc 20 / 30 20 / 200 Method : Snellen - Linear Correction : Glasses Tonometry Right Left Pressure 13 13 Method : Applanation Time : 11 : 12 AM Wearing Rx Sphere Cylinder Axis Right - 0.50 + 0.75 035 Left Plano Sphere Manifest Refraction ( Retinoscopy ) Sphere Cylinder Axis Dist Right Plano + 0.75 050 Left + 0.50 + 0.75 125 Manifest Refraction # 2 Sphere Cylinder Axis Dist Right + 0.25 + 1.00 145 20 / 25 - Left + 0.50 + 0.75 130 NI Dilation Both eyes : 1.0 % Mydriacyl , 2.5 % Phenylephrine @ 11 : 12 AM Pupils Pupils Right PERRL Left PERRL Visual Fields Right Left Result Full Full Extraocular Movement Right Left Result Full Full Main Ophthalmology Exam External Exam Right Left External Normal Normal Slit Lamp Exam Right Left Lids / Lashes Blepharitis Blepharitis Conjunctiva / Sclera Injection Injection Cornea Lasik Scars Lasik Scars Anterior Chamber Deep and quiet Deep and quiet Iris Round and reactive Round and reactive Lens 1 + Nuclear sclerosis 1 + Nuclear sclerosis Vitreous pvd pvd Neuro / Psych Oriented x 3 : Yes Mood / Affect : Normal No notes on file Other testing : OCT : OD : + scar , decreased [s2] srf [e2] OS : erm , scar , no srf , + thickening Assessment and Plan : EXUDATIVE AGE - RELATED MACULAR DEGENERATION ( 362.52 ) OU Subretinal / intraretinal fluid present Plan intravitreal Lucentis today .",
#   'laterality',
#   'lesion',
#   'T5',
#   'T1',
#   'note_4550'),
#  (0,
#   'laterality-lesion',
#   "Ocular Med ' s : Combigan ( 2 , 2 ) Ocular History : ( Bilateral ) CNVM s / p multiple IVL OU INJECTION HISTORY : Date ODOSMedications 03 / 29 / 11 XXIVL 04 / 18 / 11 XXIVL 05 / 16 / 11 XXIVL 06 / 22 / 11 XXIVL 07 / 26 / 11 XXIVL 08 / 26 / 11 X X IVL Review of Systems : Heart problems : no complaints Respiratory problems : no complaints General problems : no complaints ENT problems : no complaints Gastrointestinal problems : no complaints Urinary problems : no complaints Objective : Base Ophthalmology Exam Visual Acuity Right Left Dist cc 20 / 30 20 / 200 Method : Snellen - Linear Correction : Glasses Tonometry Right Left Pressure 13 13 Method : Applanation Time : 11 : 12 AM Wearing Rx Sphere Cylinder Axis Right - 0.50 + 0.75 035 Left Plano Sphere Manifest Refraction ( Retinoscopy ) Sphere Cylinder Axis Dist Right Plano + 0.75 050 Left + 0.50 + 0.75 125 Manifest Refraction # 2 Sphere Cylinder Axis Dist Right + 0.25 + 1.00 145 20 / 25 - Left + 0.50 + 0.75 130 NI Dilation Both eyes : 1.0 % Mydriacyl , 2.5 % Phenylephrine @ 11 : 12 AM Pupils Pupils Right PERRL Left PERRL Visual Fields Right Left Result Full Full Extraocular Movement Right Left Result Full Full Main Ophthalmology Exam External Exam Right Left External Normal Normal Slit Lamp Exam Right Left Lids / Lashes Blepharitis Blepharitis Conjunctiva / Sclera Injection Injection Cornea Lasik Scars Lasik Scars Anterior Chamber Deep and quiet Deep and quiet Iris Round and reactive Round and reactive Lens 1 + Nuclear sclerosis 1 + Nuclear sclerosis Vitreous pvd pvd Neuro / Psych Oriented x 3 : Yes Mood / Affect : Normal No notes on file Other testing : OCT : OD : + scar , decreased srf [s1] OS [e1] : erm , scar , no srf , + thickening Assessment and Plan : EXUDATIVE AGE - RELATED MACULAR DEGENERATION ( 362.52 ) OU Subretinal / intraretinal fluid present Plan intravitreal Lucentis today .",
#   "Ocular Med ' s : Combigan ( 2 , 2 ) Ocular History : ( Bilateral ) CNVM s / p multiple IVL OU INJECTION HISTORY : Date ODOSMedications 03 / 29 / 11 XXIVL 04 / 18 / 11 XXIVL 05 / 16 / 11 XXIVL 06 / 22 / 11 XXIVL 07 / 26 / 11 XXIVL 08 / 26 / 11 X X IVL Review of Systems : Heart problems : no complaints Respiratory problems : no complaints General problems : no complaints ENT problems : no complaints Gastrointestinal problems : no complaints Urinary problems : no complaints Objective : Base Ophthalmology Exam Visual Acuity Right Left Dist cc 20 / 30 20 / 200 Method : Snellen - Linear Correction : Glasses Tonometry Right Left Pressure 13 13 Method : Applanation Time : 11 : 12 AM Wearing Rx Sphere Cylinder Axis Right - 0.50 + 0.75 035 Left Plano Sphere Manifest Refraction ( Retinoscopy ) Sphere Cylinder Axis Dist Right Plano + 0.75 050 Left + 0.50 + 0.75 125 Manifest Refraction # 2 Sphere Cylinder Axis Dist Right + 0.25 + 1.00 145 20 / 25 - Left + 0.50 + 0.75 130 NI Dilation Both eyes : 1.0 % Mydriacyl , 2.5 % Phenylephrine @ 11 : 12 AM Pupils Pupils Right PERRL Left PERRL Visual Fields Right Left Result Full Full Extraocular Movement Right Left Result Full Full Main Ophthalmology Exam External Exam Right Left External Normal Normal Slit Lamp Exam Right Left Lids / Lashes Blepharitis Blepharitis Conjunctiva / Sclera Injection Injection Cornea Lasik Scars Lasik Scars Anterior Chamber Deep and quiet Deep and quiet Iris Round and reactive Round and reactive Lens 1 + Nuclear sclerosis 1 + Nuclear sclerosis Vitreous pvd pvd Neuro / Psych Oriented x 3 : Yes Mood / Affect : Normal No notes on file Other testing : OCT : OD : + scar , decreased srf OS : erm , scar , no [s2] srf [e2] , + thickening Assessment and Plan : EXUDATIVE AGE - RELATED MACULAR DEGENERATION ( 362.52 ) OU Subretinal / intraretinal fluid present Plan intravitreal Lucentis today .",
#   'laterality',
#   'lesion',
#   'T4',
#   'T2',
#   'note_4550'),
#  (0,
#   'laterality-lesion',
#   'POW # ID [s1] OD [e1] from PPV for VH , vitritis , TRD from secondary complications .',
#   'POW # ID OD from PPV for [s2] VH [e2] , vitritis , TRD from secondary complications .',
#   'laterality',
#   'lesion',
#   'T4',
#   'T1',
#   '2748168_note_9227'),
#  (0,
#   'laterality-lesion',
#   'Hx of previous exudative RD [s1] OU [e1] .',
#   'Hx of previous [s2] exudative [e2] RD OU .',
#   'laterality',
#   'lesion',
#   'T5',
#   'T2',
#   '2748168_note_9227'),
#  (0,
#   'severity-lesion',
#   'Hx of [s1] previous [e1] exudative RD OU .',
#   'Hx of previous [s2] exudative [e2] RD OU .',
#   'severity',
#   'lesion',
#   'T6',
#   'T2',
#   '2748168_note_9227'),
#  (0,
#   'laterality-lesion',
#   '[s1] OS [e1] - VH , vitritis .',
#   'OS - [s2] VH [e2] , vitritis .',
#   'laterality',
#   'lesion',
#   'T7',
#   'T3',
#   '2748168_note_9227'),
#  (0,
#   'laterality-lesion',
#   "Cystoid macular edema of [s1] left eye [e1] H35 . 352 362.53 Injection into Tenon ' s Capsule - OS - Left Eye CANCELED : Fluorescein Angiography - OS - Left Eye 2 .",
#   "[s2] Cystoid macular edema [e2] of left eye H35 . 352 362.53 Injection into Tenon ' s Capsule - OS - Left Eye CANCELED : Fluorescein Angiography - OS - Left Eye 2 .",
#   'laterality',
#   'lesion',
#   'T3',
#   'T1',
#   '910329_note_1460'),
#  (0,
#   'severity-lesion',
#   'Allergies : Allergies Allergen Reactions • Metformin Diarrhea ROS Positive for : Endocrine ( DM ) , Cardiovascular ( HTN ) , Eyes ( glaucoma ) Negative for : Constitutional , Gastrointestinal , Neurological , Skin , Genitourinary , Musculoskeletal , HENT , Respiratory , Psychiatric , Allergic / Imm , Heme / Lymph Objective : Base Eye Exam Visual Acuity Right Left Dist sc 20 / 150 20 / 30 - 2 Dist ph sc NI Method : Snellen - Linear Tonometry Right Left Pressure 38 17 Method : icare Time : 1 : 38 PM Tonometry # 2 Right Left Pressure 36 Method : Applanation Time : 1 : 41 PM Tonometry # 3 Right Left Pressure 35 16 Method : Applanation ( kane ) Time : 3 : 06 PM Pachymetry Right Left Thickness 690 626 Date : DATE Pupils Pupils Light React APD Right PERRL irreg 1 - Left PERRL 3 2 - Visual Fields Right Left Restrictions Partial superior temporal , inferior temporal , superior nasal , inferior nasal deficiencies Extraocular Movement Right Left Result Full Full Neuro / Psych Oriented x 3 : Yes Mood / Affect : Normal Dilation Both eyes : 1.0 % Mydriacyl @ 2 : 02 PM Slit Lamp and Fundus Exam External Exam Right Left External Normal Normal Slit Lamp Exam Right Left Lids / Lashes Dermatochalasis - upper lid , Ptosis Ptosis , Dermatochalasis - upper lid Conjunctiva / Sclera Superior nasal conjunctival sutures intact , seidel - Subconjunctival hemorrhage , Injection Cornea mild corneal edema , Punctate epithelial erosions Punctate epithelial erosions Anterior Chamber Deep and quiet Deep and quiet Iris irregular reactive pupil , few vessels visible , patent pi Round and reactive , no NVI Lens Posterior chamber intraocular lens Posterior chamber intraocular lens Vitreous PVD clear Fundus Exam Right Left Disc Normal , no NVD Normal , no NVD C / D Ratio 0.4 0.2 Macula flat , [s1] few [e1] DBH ERM with wrinkling , few intraretinal heme Vessels attenuation attenuation Periphery PRP scars , flat few dbh PRP scars , flat few dbh No annotated images are attached to the encounter .',
#   'Allergies : Allergies Allergen Reactions • Metformin Diarrhea ROS Positive for : Endocrine ( DM ) , Cardiovascular ( HTN ) , Eyes ( glaucoma ) Negative for : Constitutional , Gastrointestinal , Neurological , Skin , Genitourinary , Musculoskeletal , HENT , Respiratory , Psychiatric , Allergic / Imm , Heme / Lymph Objective : Base Eye Exam Visual Acuity Right Left Dist sc 20 / 150 20 / 30 - 2 Dist ph sc NI Method : Snellen - Linear Tonometry Right Left Pressure 38 17 Method : icare Time : 1 : 38 PM Tonometry # 2 Right Left Pressure 36 Method : Applanation Time : 1 : 41 PM Tonometry # 3 Right Left Pressure 35 16 Method : Applanation ( kane ) Time : 3 : 06 PM Pachymetry Right Left Thickness 690 626 Date : DATE Pupils Pupils Light React APD Right PERRL irreg 1 - Left PERRL 3 2 - Visual Fields Right Left Restrictions Partial superior temporal , inferior temporal , superior nasal , inferior nasal deficiencies Extraocular Movement Right Left Result Full Full Neuro / Psych Oriented x 3 : Yes Mood / Affect : Normal Dilation Both eyes : 1.0 % Mydriacyl @ 2 : 02 PM Slit Lamp and Fundus Exam External Exam Right Left External Normal Normal Slit Lamp Exam Right Left Lids / Lashes Dermatochalasis - upper lid , Ptosis Ptosis , Dermatochalasis - upper lid Conjunctiva / Sclera Superior nasal conjunctival sutures intact , seidel - Subconjunctival hemorrhage , Injection Cornea mild corneal edema , Punctate epithelial erosions Punctate epithelial erosions Anterior Chamber Deep and quiet Deep and quiet Iris irregular reactive pupil , few vessels visible , patent pi Round and reactive , no NVI Lens Posterior chamber intraocular lens Posterior chamber intraocular lens Vitreous PVD clear Fundus Exam Right Left Disc Normal , no NVD Normal , no NVD C / D Ratio 0.4 0.2 Macula flat , few [s2] DBH [e2] ERM with wrinkling , few intraretinal heme Vessels attenuation attenuation Periphery PRP scars , flat few dbh PRP scars , flat few dbh No annotated images are attached to the encounter .',
#   'severity',
#   'lesion',
#   'T12',
#   'T3',
#   '2260561_note_6253'),
#  (0,
#   'severity-lesion',
#   'Allergies : Allergies Allergen Reactions • Metformin Diarrhea ROS Positive for : Endocrine ( DM ) , Cardiovascular ( HTN ) , Eyes ( glaucoma ) Negative for : Constitutional , Gastrointestinal , Neurological , Skin , Genitourinary , Musculoskeletal , HENT , Respiratory , Psychiatric , Allergic / Imm , Heme / Lymph Objective : Base Eye Exam Visual Acuity Right Left Dist sc 20 / 150 20 / 30 - 2 Dist ph sc NI Method : Snellen - Linear Tonometry Right Left Pressure 38 17 Method : icare Time : 1 : 38 PM Tonometry # 2 Right Left Pressure 36 Method : Applanation Time : 1 : 41 PM Tonometry # 3 Right Left Pressure 35 16 Method : Applanation ( kane ) Time : 3 : 06 PM Pachymetry Right Left Thickness 690 626 Date : DATE Pupils Pupils Light React APD Right PERRL irreg 1 - Left PERRL 3 2 - Visual Fields Right Left Restrictions Partial superior temporal , inferior temporal , superior nasal , inferior nasal deficiencies Extraocular Movement Right Left Result Full Full Neuro / Psych Oriented x 3 : Yes Mood / Affect : Normal Dilation Both eyes : 1.0 % Mydriacyl @ 2 : 02 PM Slit Lamp and Fundus Exam External Exam Right Left External Normal Normal Slit Lamp Exam Right Left Lids / Lashes Dermatochalasis - upper lid , Ptosis Ptosis , Dermatochalasis - upper lid Conjunctiva / Sclera Superior nasal conjunctival sutures intact , seidel - Subconjunctival hemorrhage , Injection Cornea mild corneal edema , Punctate epithelial erosions Punctate epithelial erosions Anterior Chamber Deep and quiet Deep and quiet Iris irregular reactive pupil , few vessels visible , patent pi Round and reactive , no NVI Lens Posterior chamber intraocular lens Posterior chamber intraocular lens Vitreous PVD clear Fundus Exam Right Left Disc Normal , no NVD Normal , no NVD C / D Ratio 0.4 0.2 Macula flat , few DBH ERM with wrinkling , [s1] few [e1] intraretinal heme Vessels attenuation attenuation Periphery PRP scars , flat few dbh PRP scars , flat few dbh No annotated images are attached to the encounter .',
#   'Allergies : Allergies Allergen Reactions • Metformin Diarrhea ROS Positive for : Endocrine ( DM ) , Cardiovascular ( HTN ) , Eyes ( glaucoma ) Negative for : Constitutional , Gastrointestinal , Neurological , Skin , Genitourinary , Musculoskeletal , HENT , Respiratory , Psychiatric , Allergic / Imm , Heme / Lymph Objective : Base Eye Exam Visual Acuity Right Left Dist sc 20 / 150 20 / 30 - 2 Dist ph sc NI Method : Snellen - Linear Tonometry Right Left Pressure 38 17 Method : icare Time : 1 : 38 PM Tonometry # 2 Right Left Pressure 36 Method : Applanation Time : 1 : 41 PM Tonometry # 3 Right Left Pressure 35 16 Method : Applanation ( kane ) Time : 3 : 06 PM Pachymetry Right Left Thickness 690 626 Date : DATE Pupils Pupils Light React APD Right PERRL irreg 1 - Left PERRL 3 2 - Visual Fields Right Left Restrictions Partial superior temporal , inferior temporal , superior nasal , inferior nasal deficiencies Extraocular Movement Right Left Result Full Full Neuro / Psych Oriented x 3 : Yes Mood / Affect : Normal Dilation Both eyes : 1.0 % Mydriacyl @ 2 : 02 PM Slit Lamp and Fundus Exam External Exam Right Left External Normal Normal Slit Lamp Exam Right Left Lids / Lashes Dermatochalasis - upper lid , Ptosis Ptosis , Dermatochalasis - upper lid Conjunctiva / Sclera Superior nasal conjunctival sutures intact , seidel - Subconjunctival hemorrhage , Injection Cornea mild corneal edema , Punctate epithelial erosions Punctate epithelial erosions Anterior Chamber Deep and quiet Deep and quiet Iris irregular reactive pupil , few vessels visible , patent pi Round and reactive , no NVI Lens Posterior chamber intraocular lens Posterior chamber intraocular lens Vitreous PVD clear Fundus Exam Right Left Disc Normal , no NVD Normal , no NVD C / D Ratio 0.4 0.2 Macula flat , few DBH ERM with wrinkling , few [s2] intraretinal heme [e2] Vessels attenuation attenuation Periphery PRP scars , flat few dbh PRP scars , flat few dbh No annotated images are attached to the encounter .',
#   'severity',
#   'lesion',
#   'T13',
#   'T6',
#   '2260561_note_6253'),
#  (0,
#   'severity-lesion',
#   'Allergies : Allergies Allergen Reactions • Metformin Diarrhea ROS Positive for : Endocrine ( DM ) , Cardiovascular ( HTN ) , Eyes ( glaucoma ) Negative for : Constitutional , Gastrointestinal , Neurological , Skin , Genitourinary , Musculoskeletal , HENT , Respiratory , Psychiatric , Allergic / Imm , Heme / Lymph Objective : Base Eye Exam Visual Acuity Right Left Dist sc 20 / 150 20 / 30 - 2 Dist ph sc NI Method : Snellen - Linear Tonometry Right Left Pressure 38 17 Method : icare Time : 1 : 38 PM Tonometry # 2 Right Left Pressure 36 Method : Applanation Time : 1 : 41 PM Tonometry # 3 Right Left Pressure 35 16 Method : Applanation ( kane ) Time : 3 : 06 PM Pachymetry Right Left Thickness 690 626 Date : DATE Pupils Pupils Light React APD Right PERRL irreg 1 - Left PERRL 3 2 - Visual Fields Right Left Restrictions Partial superior temporal , inferior temporal , superior nasal , inferior nasal deficiencies Extraocular Movement Right Left Result Full Full Neuro / Psych Oriented x 3 : Yes Mood / Affect : Normal Dilation Both eyes : 1.0 % Mydriacyl @ 2 : 02 PM Slit Lamp and Fundus Exam External Exam Right Left External Normal Normal Slit Lamp Exam Right Left Lids / Lashes Dermatochalasis - upper lid , Ptosis Ptosis , Dermatochalasis - upper lid Conjunctiva / Sclera Superior nasal conjunctival sutures intact , seidel - Subconjunctival hemorrhage , Injection Cornea mild corneal edema , Punctate epithelial erosions Punctate epithelial erosions Anterior Chamber Deep and quiet Deep and quiet Iris irregular reactive pupil , few vessels visible , patent pi Round and reactive , no NVI Lens Posterior chamber intraocular lens Posterior chamber intraocular lens Vitreous PVD clear Fundus Exam Right Left Disc Normal , no NVD Normal , no NVD C / D Ratio 0.4 0.2 Macula flat , few DBH ERM with wrinkling , few intraretinal heme Vessels attenuation attenuation Periphery PRP scars , flat [s1] few [e1] dbh PRP scars , flat few dbh No annotated images are attached to the encounter .',
#   'Allergies : Allergies Allergen Reactions • Metformin Diarrhea ROS Positive for : Endocrine ( DM ) , Cardiovascular ( HTN ) , Eyes ( glaucoma ) Negative for : Constitutional , Gastrointestinal , Neurological , Skin , Genitourinary , Musculoskeletal , HENT , Respiratory , Psychiatric , Allergic / Imm , Heme / Lymph Objective : Base Eye Exam Visual Acuity Right Left Dist sc 20 / 150 20 / 30 - 2 Dist ph sc NI Method : Snellen - Linear Tonometry Right Left Pressure 38 17 Method : icare Time : 1 : 38 PM Tonometry # 2 Right Left Pressure 36 Method : Applanation Time : 1 : 41 PM Tonometry # 3 Right Left Pressure 35 16 Method : Applanation ( kane ) Time : 3 : 06 PM Pachymetry Right Left Thickness 690 626 Date : DATE Pupils Pupils Light React APD Right PERRL irreg 1 - Left PERRL 3 2 - Visual Fields Right Left Restrictions Partial superior temporal , inferior temporal , superior nasal , inferior nasal deficiencies Extraocular Movement Right Left Result Full Full Neuro / Psych Oriented x 3 : Yes Mood / Affect : Normal Dilation Both eyes : 1.0 % Mydriacyl @ 2 : 02 PM Slit Lamp and Fundus Exam External Exam Right Left External Normal Normal Slit Lamp Exam Right Left Lids / Lashes Dermatochalasis - upper lid , Ptosis Ptosis , Dermatochalasis - upper lid Conjunctiva / Sclera Superior nasal conjunctival sutures intact , seidel - Subconjunctival hemorrhage , Injection Cornea mild corneal edema , Punctate epithelial erosions Punctate epithelial erosions Anterior Chamber Deep and quiet Deep and quiet Iris irregular reactive pupil , few vessels visible , patent pi Round and reactive , no NVI Lens Posterior chamber intraocular lens Posterior chamber intraocular lens Vitreous PVD clear Fundus Exam Right Left Disc Normal , no NVD Normal , no NVD C / D Ratio 0.4 0.2 Macula flat , few DBH ERM with wrinkling , few intraretinal heme Vessels attenuation attenuation Periphery PRP scars , flat few [s2] dbh [e2] PRP scars , flat few dbh No annotated images are attached to the encounter .',
#   'severity',
#   'lesion',
#   'T14',
#   'T4',
#   '2260561_note_6253'),
#  (0,
#   'severity-lesion',
#   'Allergies : Allergies Allergen Reactions • Metformin Diarrhea ROS Positive for : Endocrine ( DM ) , Cardiovascular ( HTN ) , Eyes ( glaucoma ) Negative for : Constitutional , Gastrointestinal , Neurological , Skin , Genitourinary , Musculoskeletal , HENT , Respiratory , Psychiatric , Allergic / Imm , Heme / Lymph Objective : Base Eye Exam Visual Acuity Right Left Dist sc 20 / 150 20 / 30 - 2 Dist ph sc NI Method : Snellen - Linear Tonometry Right Left Pressure 38 17 Method : icare Time : 1 : 38 PM Tonometry # 2 Right Left Pressure 36 Method : Applanation Time : 1 : 41 PM Tonometry # 3 Right Left Pressure 35 16 Method : Applanation ( kane ) Time : 3 : 06 PM Pachymetry Right Left Thickness 690 626 Date : DATE Pupils Pupils Light React APD Right PERRL irreg 1 - Left PERRL 3 2 - Visual Fields Right Left Restrictions Partial superior temporal , inferior temporal , superior nasal , inferior nasal deficiencies Extraocular Movement Right Left Result Full Full Neuro / Psych Oriented x 3 : Yes Mood / Affect : Normal Dilation Both eyes : 1.0 % Mydriacyl @ 2 : 02 PM Slit Lamp and Fundus Exam External Exam Right Left External Normal Normal Slit Lamp Exam Right Left Lids / Lashes Dermatochalasis - upper lid , Ptosis Ptosis , Dermatochalasis - upper lid Conjunctiva / Sclera Superior nasal conjunctival sutures intact , seidel - Subconjunctival hemorrhage , Injection Cornea mild corneal edema , Punctate epithelial erosions Punctate epithelial erosions Anterior Chamber Deep and quiet Deep and quiet Iris irregular reactive pupil , few vessels visible , patent pi Round and reactive , no NVI Lens Posterior chamber intraocular lens Posterior chamber intraocular lens Vitreous PVD clear Fundus Exam Right Left Disc Normal , no NVD Normal , no NVD C / D Ratio 0.4 0.2 Macula flat , few DBH ERM with wrinkling , few intraretinal heme Vessels attenuation attenuation Periphery PRP scars , flat few dbh PRP scars , flat [s1] few [e1] dbh No annotated images are attached to the encounter .',
#   'Allergies : Allergies Allergen Reactions • Metformin Diarrhea ROS Positive for : Endocrine ( DM ) , Cardiovascular ( HTN ) , Eyes ( glaucoma ) Negative for : Constitutional , Gastrointestinal , Neurological , Skin , Genitourinary , Musculoskeletal , HENT , Respiratory , Psychiatric , Allergic / Imm , Heme / Lymph Objective : Base Eye Exam Visual Acuity Right Left Dist sc 20 / 150 20 / 30 - 2 Dist ph sc NI Method : Snellen - Linear Tonometry Right Left Pressure 38 17 Method : icare Time : 1 : 38 PM Tonometry # 2 Right Left Pressure 36 Method : Applanation Time : 1 : 41 PM Tonometry # 3 Right Left Pressure 35 16 Method : Applanation ( kane ) Time : 3 : 06 PM Pachymetry Right Left Thickness 690 626 Date : DATE Pupils Pupils Light React APD Right PERRL irreg 1 - Left PERRL 3 2 - Visual Fields Right Left Restrictions Partial superior temporal , inferior temporal , superior nasal , inferior nasal deficiencies Extraocular Movement Right Left Result Full Full Neuro / Psych Oriented x 3 : Yes Mood / Affect : Normal Dilation Both eyes : 1.0 % Mydriacyl @ 2 : 02 PM Slit Lamp and Fundus Exam External Exam Right Left External Normal Normal Slit Lamp Exam Right Left Lids / Lashes Dermatochalasis - upper lid , Ptosis Ptosis , Dermatochalasis - upper lid Conjunctiva / Sclera Superior nasal conjunctival sutures intact , seidel - Subconjunctival hemorrhage , Injection Cornea mild corneal edema , Punctate epithelial erosions Punctate epithelial erosions Anterior Chamber Deep and quiet Deep and quiet Iris irregular reactive pupil , few vessels visible , patent pi Round and reactive , no NVI Lens Posterior chamber intraocular lens Posterior chamber intraocular lens Vitreous PVD clear Fundus Exam Right Left Disc Normal , no NVD Normal , no NVD C / D Ratio 0.4 0.2 Macula flat , few DBH ERM with wrinkling , few intraretinal heme Vessels attenuation attenuation Periphery PRP scars , flat few dbh PRP scars , flat few [s2] dbh [e2] No annotated images are attached to the encounter .',
#   'severity',
#   'lesion',
#   'T15',
#   'T5',
#   '2260561_note_6253'),
#  (0,
#   'laterality-lesion',
#   "Proliferative diabetic retinopathy , type 2 , without macular edema 250.50 Neovascular glaucoma [s1] OD [e1] s / p recent Ahmed explant DATE for tube / plate erosion with CCT 690 IOP OD in mid upper 30 ' s on 4 meds plus diamox tabs 500 mg BID Needs repeat tube for good IOP control Risks , benefits , and alternatives of glaucoma drainage device with patch graft were discussed with the patient .",
#   "Proliferative diabetic retinopathy , type 2 , without [s2] macular edema [e2] 250.50 Neovascular glaucoma OD s / p recent Ahmed explant DATE for tube / plate erosion with CCT 690 IOP OD in mid upper 30 ' s on 4 meds plus diamox tabs 500 mg BID Needs repeat tube for good IOP control Risks , benefits , and alternatives of glaucoma drainage device with patch graft were discussed with the patient .",
#   'laterality',
#   'lesion',
#   'T16',
#   'T2',
#   '2260561_note_6253'),
#  (0,
#   'laterality-lesion',
#   "Proliferative diabetic retinopathy , type 2 , without macular edema 250.50 Neovascular glaucoma [s1] OD [e1] s / p recent Ahmed explant DATE for tube / plate erosion with CCT 690 IOP OD in mid upper 30 ' s on 4 meds plus diamox tabs 500 mg BID Needs repeat tube for good IOP control Risks , benefits , and alternatives of glaucoma drainage device with patch graft were discussed with the patient .",
#   "[s2] Proliferative diabetic retinopathy [e2] , type 2 , without macular edema 250.50 Neovascular glaucoma OD s / p recent Ahmed explant DATE for tube / plate erosion with CCT 690 IOP OD in mid upper 30 ' s on 4 meds plus diamox tabs 500 mg BID Needs repeat tube for good IOP control Risks , benefits , and alternatives of glaucoma drainage device with patch graft were discussed with the patient .",
#   'laterality',
#   'lesion',
#   'T16',
#   'T1',
#   '2260561_note_6253'),
#  (0,
#   'laterality-lesion',
#   'PVD ( posterior vitreous detachment ) , [s1] left eye [e1] - Left Eye H43 . 812 379.21 - Dilated fundus examination with diffuse commotio retinae and intraretinal hemorrhages .',
#   'PVD ( posterior vitreous detachment ) , left eye - Left Eye H43 . 812 379.21 - Dilated fundus examination with diffuse commotio retinae and [s2] intraretinal hemorrhages [e2] .',
#   'laterality',
#   'lesion',
#   'T2',
#   'T1',
#   'note_6174'),
#  (0,
#   'laterality-lesion',
#   'Branch retinal vein occlusion with macular edema of [s1] left eye [e1] H34 . 8320 362.36 OCT , Posterior Segment - OU - Both Eyes 362.83 OPH - OS Intravitreal Injection , Pharmacologic Agent Treatment Hx : IVL OS - DATE ( today ) IVL OS - DATE IVA OS - DATE IVA OS - DATE 1 ) BRVO with ME - heme in NFL clearing .',
#   'Branch retinal vein occlusion with [s2] macular edema [e2] of left eye H34 . 8320 362.36 OCT , Posterior Segment - OU - Both Eyes 362.83 OPH - OS Intravitreal Injection , Pharmacologic Agent Treatment Hx : IVL OS - DATE ( today ) IVL OS - DATE IVA OS - DATE IVA OS - DATE 1 ) BRVO with ME - heme in NFL clearing .',
#   'laterality',
#   'lesion',
#   'T4',
#   'T1',
#   '2698404_note_9114'),
#  (0,
#   'laterality-lesion',
#   'OCT , Retina - OU - Both Eyes OD : microcystic change only [s1] OS [e1] : CSME nasally Assessment and Plan : ICD - 10 - CM ICD - 9 - CM 1 .',
#   'OCT , Retina - OU - Both Eyes OD : microcystic change only OS : [s2] CSME [e2] nasally Assessment and Plan : ICD - 10 - CM ICD - 9 - CM 1 .',
#   'laterality',
#   'lesion',
#   'T1',
#   'T2',
#   'note_1085'),
#  (0,
#   'laterality-lesion',
#   'Nonproliferative diabetic retinopathy of [s1] right eye [e1] , with macular edema , with moderate nonproliferative retinopathy E11 . 3311 250.50 OCT , Retina - OU - Both Eyes 362.07 Appt req Internal Medicine 362.05 2 .',
#   '[s2] Nonproliferative diabetic retinopathy [e2] of right eye , with macular edema , with moderate nonproliferative retinopathy E11 . 3311 250.50 OCT , Retina - OU - Both Eyes 362.07 Appt req Internal Medicine 362.05 2 .',
#   'laterality',
#   'lesion',
#   'T4',
#   'T3',
#   'note_1085'),
#  (0,
#   'laterality-lesion',
#   'Nonproliferative diabetic retinopathy of [s1] right eye [e1] , with macular edema , with moderate nonproliferative retinopathy E11 . 3311 250.50 OCT , Retina - OU - Both Eyes 362.07 Appt req Internal Medicine 362.05 2 .',
#   'Nonproliferative diabetic retinopathy of right eye , with [s2] macular edema [e2] , with moderate nonproliferative retinopathy E11 . 3311 250.50 OCT , Retina - OU - Both Eyes 362.07 Appt req Internal Medicine 362.05 2 .',
#   'laterality',
#   'lesion',
#   'T4',
#   'T5',
#   'note_1085'),
#  (0,
#   'laterality-lesion',
#   'Nonproliferative diabetic retinopathy of right eye , with macular edema , with moderate nonproliferative retinopathy E11 . 3311 250.50 OCT , Retina - [s1] OU [e1] - Both Eyes 362.07 Appt req Internal Medicine 362.05 2 .',
#   'Nonproliferative diabetic retinopathy of right eye , with macular edema , with moderate [s2] nonproliferative retinopathy [e2] E11 . 3311 250.50 OCT , Retina - OU - Both Eyes 362.07 Appt req Internal Medicine 362.05 2 .',
#   'laterality',
#   'lesion',
#   'T15',
#   'T7',
#   'note_1085'),
#  (0,
#   'severity-lesion',
# ...
#   'laterality',
#   'lesion',
#   'T25',
#   'T9',
#   'note_2162'),
#  (0,
#   'laterality-lesion',
#   'Proliferative diabetic retinopathy of both eyes associated with type 2 diabetes mellitus , unspecified proliferative retinopathy type E11 . 3593 250.50 OPH - OD Intravitreal Injection , Pharmacologic Agent 362.02 OPH - OU Fluorescein Angiography CANCELED : Pan Retinal Photocoagulation - OD - Right Eye Treatment Hx : IVA OD 6 / 15 / 17 ( today ) DM 2 x 24 years on no meds Lab Results Component Value Date HGBA1C 9.7 ( H ) 06 / 09 / 2017 1 ) DM - Active Proliferative Diabetic retinopathy OU [s1] OD [e1] with high risk PDR with NVD / NVE / NVI / NVA .',
#   'Proliferative diabetic retinopathy of both eyes associated with type 2 diabetes mellitus , unspecified proliferative retinopathy type E11 . 3593 250.50 OPH - OD Intravitreal Injection , Pharmacologic Agent 362.02 OPH - OU Fluorescein Angiography CANCELED : Pan Retinal Photocoagulation - OD - Right Eye Treatment Hx : IVA OD 6 / 15 / 17 ( today ) DM 2 x 24 years on no meds Lab Results Component Value Date HGBA1C 9.7 ( H ) 06 / 09 / 2017 1 ) DM - Active Proliferative Diabetic retinopathy OU OD with high risk PDR with [s2] NVD [e2] / NVE / NVI / NVA .',
#   'laterality',
#   'lesion',
#   'T25',
#   'T10',
#   'note_2162'),
#  (0,
#   'laterality-lesion',
#   'Proliferative diabetic retinopathy of both eyes associated with type 2 diabetes mellitus , unspecified proliferative retinopathy type E11 . 3593 250.50 OPH - OD Intravitreal Injection , Pharmacologic Agent 362.02 OPH - OU Fluorescein Angiography CANCELED : Pan Retinal Photocoagulation - OD - Right Eye Treatment Hx : IVA OD 6 / 15 / 17 ( today ) DM 2 x 24 years on no meds Lab Results Component Value Date HGBA1C 9.7 ( H ) 06 / 09 / 2017 1 ) DM - Active Proliferative Diabetic retinopathy OU [s1] OD [e1] with high risk PDR with NVD / NVE / NVI / NVA .',
#   'Proliferative diabetic retinopathy of both eyes associated with type 2 diabetes mellitus , unspecified proliferative retinopathy type E11 . 3593 250.50 OPH - OD Intravitreal Injection , Pharmacologic Agent 362.02 OPH - OU Fluorescein Angiography CANCELED : Pan Retinal Photocoagulation - OD - Right Eye Treatment Hx : IVA OD 6 / 15 / 17 ( today ) DM 2 x 24 years on no meds Lab Results Component Value Date HGBA1C 9.7 ( H ) 06 / 09 / 2017 1 ) DM - Active Proliferative Diabetic retinopathy OU OD with high risk PDR with NVD / [s2] NVE [e2] / NVI / NVA .',
#   'laterality',
#   'lesion',
#   'T25',
#   'T11',
#   'note_2162'),
#  (0,
#   'laterality-lesion',
#   'Proliferative diabetic retinopathy of both eyes associated with type 2 diabetes mellitus , unspecified proliferative retinopathy type E11 . 3593 250.50 OPH - OD Intravitreal Injection , Pharmacologic Agent 362.02 OPH - OU Fluorescein Angiography CANCELED : Pan Retinal Photocoagulation - OD - Right Eye Treatment Hx : IVA OD 6 / 15 / 17 ( today ) DM 2 x 24 years on no meds Lab Results Component Value Date HGBA1C 9.7 ( H ) 06 / 09 / 2017 1 ) DM - Active Proliferative Diabetic retinopathy OU [s1] OD [e1] with high risk PDR with NVD / NVE / NVI / NVA .',
#   'Proliferative diabetic retinopathy of both eyes associated with type 2 diabetes mellitus , unspecified proliferative retinopathy type E11 . 3593 250.50 OPH - OD Intravitreal Injection , Pharmacologic Agent 362.02 OPH - OU Fluorescein Angiography CANCELED : Pan Retinal Photocoagulation - OD - Right Eye Treatment Hx : IVA OD 6 / 15 / 17 ( today ) DM 2 x 24 years on no meds Lab Results Component Value Date HGBA1C 9.7 ( H ) 06 / 09 / 2017 1 ) DM - Active Proliferative Diabetic retinopathy OU OD with high risk PDR with NVD / NVE / NVI / [s2] NVA [e2] .',
#   'laterality',
#   'lesion',
#   'T25',
#   'T13',
#   'note_2162'),
#  (0,
#   'laterality-lesion',
#   'Proliferative diabetic retinopathy of both eyes associated with type 2 diabetes mellitus , unspecified proliferative retinopathy type E11 . 3593 250.50 OPH - OD Intravitreal Injection , Pharmacologic Agent 362.02 OPH - OU Fluorescein Angiography CANCELED : Pan Retinal Photocoagulation - OD - Right Eye Treatment Hx : IVA OD 6 / 15 / 17 ( today ) DM 2 x 24 years on no meds Lab Results Component Value Date HGBA1C 9.7 ( H ) 06 / 09 / 2017 1 ) DM - Active Proliferative Diabetic retinopathy OU [s1] OD [e1] with high risk PDR with NVD / NVE / NVI / NVA .',
#   'Proliferative diabetic retinopathy of both eyes associated with type 2 diabetes mellitus , unspecified proliferative retinopathy type E11 . 3593 250.50 OPH - OD Intravitreal Injection , Pharmacologic Agent 362.02 OPH - OU Fluorescein Angiography CANCELED : Pan Retinal Photocoagulation - OD - Right Eye Treatment Hx : IVA OD 6 / 15 / 17 ( today ) DM 2 x 24 years on no meds Lab Results Component Value Date HGBA1C 9.7 ( H ) 06 / 09 / 2017 1 ) DM - Active Proliferative Diabetic retinopathy OU OD with high risk PDR with NVD / NVE / [s2] NVI [e2] / NVA .',
#   'laterality',
#   'lesion',
#   'T25',
#   'T12',
#   'note_2162'),
#  (0,
#   'laterality-lesion',
#   '[s1] OS [e1] + NVD / NVE / NVI / NVA .',
#   'OS + [s2] NVD [e2] / NVE / NVI / NVA .',
#   'laterality',
#   'lesion',
#   'T26',
#   'T14',
#   'note_2162'),
#  (0,
#   'laterality-lesion',
#   '[s1] OS [e1] + NVD / NVE / NVI / NVA .',
#   'OS + NVD / [s2] NVE [e2] / NVI / NVA .',
#   'laterality',
#   'lesion',
#   'T26',
#   'T15',
#   'note_2162'),
#  (0,
#   'laterality-lesion',
#   '[s1] OS [e1] + NVD / NVE / NVI / NVA .',
#   'OS + NVD / NVE / [s2] NVI [e2] / NVA .',
#   'laterality',
#   'lesion',
#   'T26',
#   'T16',
#   'note_2162'),
#  (0,
#   'laterality-lesion',
#   '[s1] OS [e1] + NVD / NVE / NVI / NVA .',
#   'OS + NVD / NVE / NVI / [s2] NVA [e2] .',
#   'laterality',
#   'lesion',
#   'T26',
#   'T17',
#   'note_2162'),
#  (0,
#   'laterality-lesion',
#   'Mac OCT OU : OD : disruption of all retinal layers , loss of foveal contour , no IRF / SRF [s1] OS [e1] : blunted foveal contour , no IRF / SRF RTC in 1 week OCT , Posterior Segment - OU - Both Eyes OD : disruption of all retinal layers , loss of foveal contour , no IRF / SRF OS : blunted foveal contour , no IRF / SRF NAME , MD participated in the care of this patient .',
#   'Mac OCT OU : OD : disruption of all retinal layers , loss of foveal contour , no IRF / SRF OS : blunted foveal contour , no [s2] IRF [e2] / SRF RTC in 1 week OCT , Posterior Segment - OU - Both Eyes OD : disruption of all retinal layers , loss of foveal contour , no IRF / SRF OS : blunted foveal contour , no IRF / SRF NAME , MD participated in the care of this patient .',
#   'laterality',
#   'lesion',
#   'T10',
#   'T3',
#   '2487716_note_7588'),
#  (0,
#   'laterality-lesion',
#   'Mac OCT OU : OD : disruption of all retinal layers , loss of foveal contour , no IRF / SRF [s1] OS [e1] : blunted foveal contour , no IRF / SRF RTC in 1 week OCT , Posterior Segment - OU - Both Eyes OD : disruption of all retinal layers , loss of foveal contour , no IRF / SRF OS : blunted foveal contour , no IRF / SRF NAME , MD participated in the care of this patient .',
#   'Mac OCT OU : OD : disruption of all retinal layers , loss of foveal contour , no IRF / SRF OS : blunted foveal contour , no IRF / [s2] SRF [e2] RTC in 1 week OCT , Posterior Segment - OU - Both Eyes OD : disruption of all retinal layers , loss of foveal contour , no IRF / SRF OS : blunted foveal contour , no IRF / SRF NAME , MD participated in the care of this patient .',
#   'laterality',
#   'lesion',
#   'T10',
#   'T4',
#   '2487716_note_7588'),
#  (0,
#   'laterality-lesion',
#   'Mac OCT OU : [s1] OD [e1] : disruption of all retinal layers , loss of foveal contour , no IRF / SRF OS : blunted foveal contour , no IRF / SRF RTC in 1 week OCT , Posterior Segment - OU - Both Eyes OD : disruption of all retinal layers , loss of foveal contour , no IRF / SRF OS : blunted foveal contour , no IRF / SRF NAME , MD participated in the care of this patient .',
#   'Mac OCT OU : OD : disruption of all retinal layers , loss of foveal contour , no [s2] IRF [e2] / SRF OS : blunted foveal contour , no IRF / SRF RTC in 1 week OCT , Posterior Segment - OU - Both Eyes OD : disruption of all retinal layers , loss of foveal contour , no IRF / SRF OS : blunted foveal contour , no IRF / SRF NAME , MD participated in the care of this patient .',
#   'laterality',
#   'lesion',
#   'T9',
#   'T1',
#   '2487716_note_7588'),
#  (0,
#   'laterality-lesion',
#   'Mac OCT OU : [s1] OD [e1] : disruption of all retinal layers , loss of foveal contour , no IRF / SRF OS : blunted foveal contour , no IRF / SRF RTC in 1 week OCT , Posterior Segment - OU - Both Eyes OD : disruption of all retinal layers , loss of foveal contour , no IRF / SRF OS : blunted foveal contour , no IRF / SRF NAME , MD participated in the care of this patient .',
#   'Mac OCT OU : OD : disruption of all retinal layers , loss of foveal contour , no IRF / [s2] SRF [e2] OS : blunted foveal contour , no IRF / SRF RTC in 1 week OCT , Posterior Segment - OU - Both Eyes OD : disruption of all retinal layers , loss of foveal contour , no IRF / SRF OS : blunted foveal contour , no IRF / SRF NAME , MD participated in the care of this patient .',
#   'laterality',
#   'lesion',
#   'T9',
#   'T2',
#   '2487716_note_7588'),
#  (0,
#   'laterality-lesion',
#   'Mac OCT OU : OD : disruption of all retinal layers , loss of foveal contour , no IRF / SRF OS : blunted foveal contour , no IRF / SRF RTC in 1 week OCT , Posterior Segment - OU - Both Eyes [s1] OD [e1] : disruption of all retinal layers , loss of foveal contour , no IRF / SRF OS : blunted foveal contour , no IRF / SRF NAME , MD participated in the care of this patient .',
#   'Mac OCT OU : OD : disruption of all retinal layers , loss of foveal contour , no IRF / SRF OS : blunted foveal contour , no IRF / SRF RTC in 1 week OCT , Posterior Segment - OU - Both Eyes OD : disruption of all retinal layers , loss of foveal contour , no [s2] IRF [e2] / SRF OS : blunted foveal contour , no IRF / SRF NAME , MD participated in the care of this patient .',
#   'laterality',
#   'lesion',
#   'T11',
#   'T5',
#   '2487716_note_7588'),
#  (0,
#   'laterality-lesion',
#   'Mac OCT OU : OD : disruption of all retinal layers , loss of foveal contour , no IRF / SRF OS : blunted foveal contour , no IRF / SRF RTC in 1 week OCT , Posterior Segment - OU - Both Eyes [s1] OD [e1] : disruption of all retinal layers , loss of foveal contour , no IRF / SRF OS : blunted foveal contour , no IRF / SRF NAME , MD participated in the care of this patient .',
#   'Mac OCT OU : OD : disruption of all retinal layers , loss of foveal contour , no IRF / SRF OS : blunted foveal contour , no IRF / SRF RTC in 1 week OCT , Posterior Segment - OU - Both Eyes OD : disruption of all retinal layers , loss of foveal contour , no IRF / [s2] SRF [e2] OS : blunted foveal contour , no IRF / SRF NAME , MD participated in the care of this patient .',
#   'laterality',
#   'lesion',
#   'T11',
#   'T6',
#   '2487716_note_7588'),
#  (0,
#   'laterality-lesion',
#   'Mac OCT OU : OD : disruption of all retinal layers , loss of foveal contour , no IRF / SRF OS : blunted foveal contour , no IRF / SRF RTC in 1 week OCT , Posterior Segment - OU - Both Eyes OD : disruption of all retinal layers , loss of foveal contour , no IRF / SRF [s1] OS [e1] : blunted foveal contour , no IRF / SRF NAME , MD participated in the care of this patient .',
#   'Mac OCT OU : OD : disruption of all retinal layers , loss of foveal contour , no IRF / SRF OS : blunted foveal contour , no IRF / SRF RTC in 1 week OCT , Posterior Segment - OU - Both Eyes OD : disruption of all retinal layers , loss of foveal contour , no IRF / SRF OS : blunted foveal contour , no [s2] IRF [e2] / SRF NAME , MD participated in the care of this patient .',
#   'laterality',
#   'lesion',
#   'T12',
#   'T7',
#   '2487716_note_7588'),
#  (0,
#   'laterality-lesion',
#   'Mac OCT OU : OD : disruption of all retinal layers , loss of foveal contour , no IRF / SRF OS : blunted foveal contour , no IRF / SRF RTC in 1 week OCT , Posterior Segment - OU - Both Eyes OD : disruption of all retinal layers , loss of foveal contour , no IRF / SRF [s1] OS [e1] : blunted foveal contour , no IRF / SRF NAME , MD participated in the care of this patient .',
#   'Mac OCT OU : OD : disruption of all retinal layers , loss of foveal contour , no IRF / SRF OS : blunted foveal contour , no IRF / SRF RTC in 1 week OCT , Posterior Segment - OU - Both Eyes OD : disruption of all retinal layers , loss of foveal contour , no IRF / SRF OS : blunted foveal contour , no IRF / [s2] SRF [e2] NAME , MD participated in the care of this patient .',
#   'laterality',
#   'lesion',
#   'T12',
#   'T8',
#   '2487716_note_7588'),
#  (0,
#   'laterality-lesion',
#   '2 ) Choroidal Nevus [s1] OD [e1] - - Flat , no OP , SRF , stable in appearnance .',
#   '2 ) Choroidal Nevus OD - - Flat , no OP , [s2] SRF [e2] , stable in appearnance .',
#   'laterality',
#   'lesion',
#   'T2',
#   'T1',
#   '1409243_note_3135'),
#  (0,
#   'laterality-lesion',
#   'Treatment history IVFA ( today ) : Quiecsent PDR [s1] OU [e1] Dense PRP OU IVE OD : 8 / 2016 9 / 2016 10 / 2016 1 / 2017 5 / 2017 IVE OS : 2 / 2017 5 / 2017 1 ) IDDM - hx of PDR OU , CSME OU - sent for eval of worsening retinopathy with history of dense PRP , consider targeted PRP OU - poor control per pt , last A 1 c 8.5 - dense PRP of periphery and macula OD > OS - Mac OCT , no IRF / SRF OD , mild IRF nasally OS - IVFA with temporal ischemia , no NV .',
#   'Treatment history IVFA ( today ) : Quiecsent [s2] PDR [e2] OU Dense PRP OU IVE OD : 8 / 2016 9 / 2016 10 / 2016 1 / 2017 5 / 2017 IVE OS : 2 / 2017 5 / 2017 1 ) IDDM - hx of PDR OU , CSME OU - sent for eval of worsening retinopathy with history of dense PRP , consider targeted PRP OU - poor control per pt , last A 1 c 8.5 - dense PRP of periphery and macula OD > OS - Mac OCT , no IRF / SRF OD , mild IRF nasally OS - IVFA with temporal ischemia , no NV .',
#   'laterality',
#   'lesion',
#   'T1',
#   'T2',
#   'note_8913'),
#  (0,
#   'laterality-lesion',
#   'Treatment history IVFA ( today ) : Quiecsent PDR OU Dense PRP OU IVE OD : 8 / 2016 9 / 2016 10 / 2016 1 / 2017 5 / 2017 IVE OS : 2 / 2017 5 / 2017 1 ) IDDM - hx of PDR OU , CSME [s1] OU [e1] - sent for eval of worsening retinopathy with history of dense PRP , consider targeted PRP OU - poor control per pt , last A 1 c 8.5 - dense PRP of periphery and macula OD > OS - Mac OCT , no IRF / SRF OD , mild IRF nasally OS - IVFA with temporal ischemia , no NV .',
#   'Treatment history IVFA ( today ) : Quiecsent PDR OU Dense PRP OU IVE OD : 8 / 2016 9 / 2016 10 / 2016 1 / 2017 5 / 2017 IVE OS : 2 / 2017 5 / 2017 1 ) IDDM - hx of PDR OU , [s2] CSME [e2] OU - sent for eval of worsening retinopathy with history of dense PRP , consider targeted PRP OU - poor control per pt , last A 1 c 8.5 - dense PRP of periphery and macula OD > OS - Mac OCT , no IRF / SRF OD , mild IRF nasally OS - IVFA with temporal ischemia , no NV .',
#   'laterality',
#   'lesion',
#   'T9',
#   'T4',
#   'note_8913'),
#  (0,
#   'laterality-lesion',
#   'Treatment history IVFA ( today ) : Quiecsent PDR OU Dense PRP OU IVE OD : 8 / 2016 9 / 2016 10 / 2016 1 / 2017 5 / 2017 IVE OS : 2 / 2017 5 / 2017 1 ) IDDM - hx of PDR [s1] OU [e1] , CSME OU - sent for eval of worsening retinopathy with history of dense PRP , consider targeted PRP OU - poor control per pt , last A 1 c 8.5 - dense PRP of periphery and macula OD > OS - Mac OCT , no IRF / SRF OD , mild IRF nasally OS - IVFA with temporal ischemia , no NV .',
#   'Treatment history IVFA ( today ) : Quiecsent PDR OU Dense PRP OU IVE OD : 8 / 2016 9 / 2016 10 / 2016 1 / 2017 5 / 2017 IVE OS : 2 / 2017 5 / 2017 1 ) IDDM - hx of [s2] PDR [e2] OU , CSME OU - sent for eval of worsening retinopathy with history of dense PRP , consider targeted PRP OU - poor control per pt , last A 1 c 8.5 - dense PRP of periphery and macula OD > OS - Mac OCT , no IRF / SRF OD , mild IRF nasally OS - IVFA with temporal ischemia , no NV .',
#   'laterality',
#   'lesion',
#   'T8',
#   'T3',
#   'note_8913'),
#  ...]

# %%
"""
prev:
n2c2: aio_th1 108147 71016
umass: aio_th1 102752 16035
"""

"""
binary:
{'nc': defaultdict(list,
             {1: [(34790, 69403, 69395)],
              2: [(35239, 122103, 103058)],
              3: [(35401, 172013, 135066)],
              4: [(35489, 220521, 165704)]}),
 'um': defaultdict(list,
             {1: [(21254, 75850, 15410)],
              2: [(21926, 100578, 19320)],
              3: [(22184, 122651, 22789)],
              4: [(22316, 144038, 26150)]})}

class:
{'nc': defaultdict(list,
             {1: [(34790, 69403, 69395)],
              2: [(35239, 122103, 103058)],
              3: [(35401, 172013, 135066)],
              4: [(35489, 220521, 165704)]}),
 'um': defaultdict(list,
             {1: [(21254, 75850, 15410)],
              2: [(21926, 100578, 19320)],
              3: [(22184, 122651, 22789)],
              4: [(22316, 144038, 26150)]})}

"""

# %% [markdown]
# ## n2c2

# %%
n2c2_training = "/Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/"
n2c2_test = "/Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/"
n2c2_entity_only = "/Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test_only_entity"

# %%
n2c2_valid = {'Route-Drug', 'Reason-Drug', 'ADE-Drug', 'Frequency-Drug',
              'Strength-Drug', 'Dosage-Drug', 'Drug-Drug', 'Form-Drug', 'Duration-Drug',
              'Not-Rel'}

n2c2_valid_comb = {
    ('ADE', 'Drug'), ('Reason', 'Drug'),
    ('Strength', 'Drug'), ('Route', 'Drug'), 
    ('Frequency', 'Drug'), ('Dosage', 'Drug'),
    ('Form', 'Drug'), ('Duration', 'Drug')
}

# %%
entp2rel = {
    ('ADE', 'Drug'):'ADE-Drug', 
    ('Reason', 'Drug'):'Reason-Drug',
    ('Strength', 'Drug'):'Strength-Drug', 
    ('Route', 'Drug'):'Route-Drug', 
    ('Frequency', 'Drug'):'Frequency-Drug', 
    ('Dosage', 'Drug'):'Dosage-Drug',
    ('Form', 'Drug'):'Form-Drug', 
    ('Duration', 'Drug'):'Duration-Drug'
}

entp2rel, entp2rel[('ADE', 'Drug')]
# Out:
# ({('ADE', 'Drug'): 'ADE-Drug',
#   ('Reason', 'Drug'): 'Reason-Drug',
#   ('Strength', 'Drug'): 'Strength-Drug',
#   ('Route', 'Drug'): 'Route-Drug',
#   ('Frequency', 'Drug'): 'Frequency-Drug',
#   ('Dosage', 'Drug'): 'Dosage-Drug',
#   ('Form', 'Drug'): 'Form-Drug',
#   ('Duration', 'Drug'): 'Duration-Drug'},
#  'ADE-Drug')

# %%
pkl_save(entp2rel, "../data/2018n2c2_relation_processed/binary/2018n2c2_mapping.pkl")

# %%
extract_only_entity(n2c2_test, n2c2_entity_only)

# %% [markdown]
# ### training

# %%
CUTOFF = 1

# %%
rel2idx, idx2rel, rel_cnts = get_all_rel_types(n2c2_training, n2c2_valid_comb)
rel2idx, idx2rel, rel_cnts, reduce(lambda x, y: x + y, [e[1] for e in rel_cnts])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-b4cababba357> in <module>
# ----> 1 rel2idx, idx2rel, rel_cnts = get_all_rel_types(n2c2_training, n2c2_valid_comb)
#       2 rel2idx, idx2rel, rel_cnts, reduce(lambda x, y: x + y, [e[1] for e in rel_cnts])
#
# NameError: name 'get_all_rel_types' is not defined

# %%
dpos, dneg = create_training_samples(n2c2_training, n2c2_valid, n2c2_valid_comb)
# Out:
# 2021-05-01 11:23:45,431 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:45,431 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:45,432 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/110727.txt ...
# 2021-05-01 11:23:45,478 INFO qSunday
# 2021-05-01 11:23:45,479 WARNING 'qSunday' => 'q' 'Sunday'
# 2021-05-01 11:23:45,488 INFO MSContin
# 2021-05-01 11:23:45,489 WARNING 'MSContin' => 'MS' 'Contin'
# 2021-05-01 11:23:45,526 WARNING ('3', 'Dosage', (12227, 12228)) offset is overlapped with previous entity; current tok not overlap
# first index not match  ('3', 'Dosage', (12227, 12228))
# last index not match  ('3', 'Dosage', (12227, 12228))
# 2021-05-01 11:23:46,676 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:46,676 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:46,677 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/101372.txt ...
# 2021-05-01 11:23:46,697 INFO AnGap
# 2021-05-01 11:23:46,697 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:23:46,698 INFO AlkPhos
# 2021-05-01 11:23:46,698 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:23:46,699 INFO TotBili
# 2021-05-01 11:23:46,699 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:23:47,132 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:47,133 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:47,133 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/106384.txt ...
# 2021-05-01 11:23:47,155 INFO LDLcalc
# 2021-05-01 11:23:47,156 WARNING 'LDLcalc' => 'LD' 'Lcalc'
# 2021-05-01 11:23:47,162 INFO NameIs
# 2021-05-01 11:23:47,162 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:23:47,378 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:47,379 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:47,379 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/107139.txt ...
# last index not match  ('b.i.d', 'Frequency', (8199, 8204))
# last index not match  ('b.i.d', 'Frequency', (8300, 8305))
# 2021-05-01 11:23:47,464 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:47,465 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:47,465 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/110445.txt ...
# 2021-05-01 11:23:47,495 WARNING ('[**Doctor First Name **]', 'Drug', (5177, 5201)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:23:47,577 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:47,578 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:47,578 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/115267.txt ...
# 2021-05-01 11:23:47,606 INFO AnGap
# 2021-05-01 11:23:47,607 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:23:47,608 INFO AlkPhos
# 2021-05-01 11:23:47,608 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:23:47,609 INFO TotBili
# 2021-05-01 11:23:47,609 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:23:47,610 INFO AlkPhos
# 2021-05-01 11:23:47,610 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:23:47,611 INFO TotBili
# 2021-05-01 11:23:47,611 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:23:47,612 INFO AnGap
# 2021-05-01 11:23:47,613 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:23:47,622 INFO BiPap
# 2021-05-01 11:23:47,623 WARNING 'BiPap' => 'Bi' 'Pap'
# 2021-05-01 11:23:47,666 WARNING ('red rash on arms and face', 'Reason', (13358, 13383)) offset is overlapped with previous entity; current tok not overlap
# first index not match  ('[**Doctor First Name **]', 'Drug', (5177, 5201))
# last index not match  ('[**Doctor First Name **]', 'Drug', (5177, 5201))
# 2021-05-01 11:23:48,069 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:48,070 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:48,070 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/175593.txt ...
# 2021-05-01 11:23:48,094 INFO NameIs
# 2021-05-01 11:23:48,095 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:23:48,197 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:48,198 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:48,198 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/159079.txt ...
# 2021-05-01 11:23:48,216 INFO AnGap
# 2021-05-01 11:23:48,217 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:23:48,217 INFO AlkPhos
# 2021-05-01 11:23:48,217 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:23:48,218 INFO TotBili
# 2021-05-01 11:23:48,218 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:23:48,222 INFO AnGap
# 2021-05-01 11:23:48,223 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:23:48,529 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:48,530 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:48,530 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/103377.txt ...
# 2021-05-01 11:23:48,558 INFO IIIa
# 2021-05-01 11:23:48,559 WARNING 'IIIa' => 'II' 'Ia'
# 2021-05-01 11:23:48,562 INFO IIIa
# 2021-05-01 11:23:48,563 WARNING 'IIIa' => 'II' 'Ia'
# 2021-05-01 11:23:48,598 INFO NameIs
# 2021-05-01 11:23:48,598 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:23:48,599 INFO NameIs
# 2021-05-01 11:23:48,599 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:23:48,600 INFO NameIs
# 2021-05-01 11:23:48,600 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:23:48,830 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:48,830 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:48,831 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/120237.txt ...
# 2021-05-01 11:23:48,979 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:48,980 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:48,980 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/192877.txt ...
# 2021-05-01 11:23:49,006 INFO NameIs
# 2021-05-01 11:23:49,007 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:23:49,207 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:49,207 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:49,208 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/108949.txt ...
# 2021-05-01 11:23:49,272 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:49,273 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:49,273 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/113824.txt ...
# 2021-05-01 11:23:49,299 INFO AnGap
# 2021-05-01 11:23:49,299 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:23:49,300 INFO AlkPhos
# 2021-05-01 11:23:49,300 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:23:49,301 INFO TotBili
# 2021-05-01 11:23:49,301 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:23:49,302 INFO UricAcd
# 2021-05-01 11:23:49,302 WARNING 'UricAcd' => 'Uric' 'Acd'
# 2021-05-01 11:23:49,308 INFO AnGap
# 2021-05-01 11:23:49,308 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:23:49,309 INFO AlkPhos
# 2021-05-01 11:23:49,309 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:23:49,310 INFO TotBili
# 2021-05-01 11:23:49,310 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:23:49,321 INFO NameIs
# 2021-05-01 11:23:49,321 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:23:49,370 WARNING ('hypotension', 'Reason', (9882, 9893)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:23:49,371 WARNING ('XL', 'Form', (13185, 13187)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:23:49,558 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:49,559 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:49,559 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/109667.txt ...
# 2021-05-01 11:23:49,764 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:49,765 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:49,765 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/114144.txt ...
# 2021-05-01 11:23:49,797 INFO AnGap
# 2021-05-01 11:23:49,797 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:23:49,798 INFO AlkPhos
# 2021-05-01 11:23:49,798 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:23:49,799 INFO TotBili
# 2021-05-01 11:23:49,799 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:23:49,800 INFO AlkPhos
# 2021-05-01 11:23:49,800 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:23:49,801 INFO TotBili
# 2021-05-01 11:23:49,801 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:23:49,802 INFO LDLcalc
# 2021-05-01 11:23:49,802 WARNING 'LDLcalc' => 'LD' 'Lcalc'
# 2021-05-01 11:23:49,804 INFO AnGap
# 2021-05-01 11:23:49,805 WARNING 'AnGap' => 'An' 'Gap'
# first index not match  ('O2', 'Drug', (3232, 3234))
# 2021-05-01 11:23:50,127 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:50,128 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:50,128 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/125206.txt ...
# 2021-05-01 11:23:50,162 INFO TotProt
# 2021-05-01 11:23:50,162 WARNING 'TotProt' => 'Tot' 'Prot'
# 2021-05-01 11:23:50,163 INFO TotProt
# 2021-05-01 11:23:50,164 WARNING 'TotProt' => 'Tot' 'Prot'
# 2021-05-01 11:23:50,165 INFO TotProt
# 2021-05-01 11:23:50,165 WARNING 'TotProt' => 'Tot' 'Prot'
# 2021-05-01 11:23:50,166 INFO AnGap
# 2021-05-01 11:23:50,167 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:23:50,167 INFO AlkPhos
# 2021-05-01 11:23:50,168 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:23:50,168 INFO TotBili
# 2021-05-01 11:23:50,169 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:23:50,229 WARNING ('prn', 'Frequency', (18194, 18197)) offset is overlapped with previous entity; current tok not overlap
# first index not match  ('prn', 'Frequency', (18194, 18197))
# last index not match  ('prn', 'Frequency', (18194, 18197))
# 2021-05-01 11:23:51,190 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:51,191 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:51,191 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/114965.txt ...
# 2021-05-01 11:23:51,242 WARNING ('constipation', 'Reason', (10028, 10040)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:23:51,327 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:51,328 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:51,328 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/114959.txt ...
# 2021-05-01 11:23:51,347 INFO ReClosure
# 2021-05-01 11:23:51,348 WARNING 'ReClosure' => 'Re' 'Closure'
# 2021-05-01 11:23:51,358 INFO AnGap
# 2021-05-01 11:23:51,359 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:23:51,360 INFO AnGap
# 2021-05-01 11:23:51,360 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:23:51,361 INFO AnGap
# 2021-05-01 11:23:51,361 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:23:51,362 INFO AnGap
# 2021-05-01 11:23:51,362 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:23:51,363 INFO AnGap
# 2021-05-01 11:23:51,364 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:23:51,364 INFO AnGap
# 2021-05-01 11:23:51,365 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:23:51,365 INFO AnGap
# 2021-05-01 11:23:51,366 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:23:51,366 INFO NotDone
# 2021-05-01 11:23:51,367 WARNING 'NotDone' => 'Not' 'Done'
# 2021-05-01 11:23:51,368 INFO NotDone
# 2021-05-01 11:23:51,368 WARNING 'NotDone' => 'Not' 'Done'
# 2021-05-01 11:23:51,384 INFO phosLo
# 2021-05-01 11:23:51,384 WARNING 'phosLo' => 'phos' 'Lo'
# 2021-05-01 11:23:51,920 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:51,920 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:51,921 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/134445.txt ...
# 2021-05-01 11:23:51,947 WARNING ('delirious', 'Reason', (3166, 3175)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:23:51,948 WARNING ('t.i.d. and p.r.n', 'Frequency', (3413, 3429)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:23:52,029 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:52,029 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:52,030 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/107058.txt ...
# 2021-05-01 11:23:52,047 INFO AnGap
# 2021-05-01 11:23:52,048 WARNING 'AnGap' => 'An' 'Gap'
# last index not match  ('t.i.d. and p.r.n', 'Frequency', (3413, 3429))
# 2021-05-01 11:23:52,208 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:52,208 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:52,209 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/123475.txt ...
# 2021-05-01 11:23:52,256 WARNING ('delerium', 'ADE', (5608, 5616)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:23:52,426 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:52,426 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:52,427 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/176448.txt ...
# 2021-05-01 11:23:52,460 INFO AnGap
# 2021-05-01 11:23:52,461 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:23:52,461 INFO AlkPhos
# 2021-05-01 11:23:52,462 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:23:52,462 INFO TotBili
# 2021-05-01 11:23:52,463 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:23:52,465 INFO TotProt
# 2021-05-01 11:23:52,465 WARNING 'TotProt' => 'Tot' 'Prot'
# 2021-05-01 11:23:52,466 INFO TotProt
# 2021-05-01 11:23:52,466 WARNING 'TotProt' => 'Tot' 'Prot'
# 2021-05-01 11:23:52,661 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:52,662 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:52,662 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/110068.txt ...
# 2021-05-01 11:23:52,773 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:52,773 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:52,774 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/102136.txt ...
# 2021-05-01 11:23:52,792 INFO AnGap
# 2021-05-01 11:23:52,793 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:23:52,794 INFO AnGap
# 2021-05-01 11:23:52,794 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:23:52,795 INFO AnGap
# 2021-05-01 11:23:52,796 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:23:52,796 INFO AnGap
# 2021-05-01 11:23:52,797 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:23:52,798 INFO AlkPhos
# 2021-05-01 11:23:52,798 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:23:52,799 INFO TotBili
# 2021-05-01 11:23:52,799 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:23:52,800 INFO AlkPhos
# 2021-05-01 11:23:52,800 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:23:52,801 INFO TotBili
# 2021-05-01 11:23:52,801 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:23:52,802 INFO AlkPhos
# 2021-05-01 11:23:52,802 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:23:53,047 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:53,048 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:53,048 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/176106.txt ...
# 2021-05-01 11:23:53,113 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:53,113 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:53,114 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/130153.txt ...
# 2021-05-01 11:23:53,118 INFO BuSpar
# 2021-05-01 11:23:53,119 WARNING 'BuSpar' => 'Bu' 'Spar'
# 2021-05-01 11:23:53,120 INFO BuSpar
# 2021-05-01 11:23:53,120 WARNING 'BuSpar' => 'Bu' 'Spar'
# 2021-05-01 11:23:53,184 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:53,184 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:53,185 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/106026.txt ...
# 2021-05-01 11:23:53,293 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:53,294 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:53,294 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/102283.txt ...
# 2021-05-01 11:23:53,781 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:53,782 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:53,782 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/110863.txt ...
# 2021-05-01 11:23:53,802 INFO AnGap
# 2021-05-01 11:23:53,802 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:23:53,824 WARNING ('Odynophagia', 'Reason', (7495, 7506)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:23:53,824 WARNING ('pancytopenic', 'Reason', (7922, 7934)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:23:54,033 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:54,034 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:54,035 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/121467.txt ...
# 2021-05-01 11:23:54,053 INFO PERRLa
# 2021-05-01 11:23:54,053 WARNING 'PERRLa' => 'PERR' 'La'
# 2021-05-01 11:23:54,055 INFO PERRLa
# 2021-05-01 11:23:54,055 WARNING 'PERRLa' => 'PERR' 'La'
# 2021-05-01 11:23:54,057 INFO AnGap
# 2021-05-01 11:23:54,058 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:23:54,868 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:54,869 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:54,869 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/102296.txt ...
# 2021-05-01 11:23:54,910 WARNING ('RBCs', 'Drug', (1135, 1139)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:23:55,082 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:55,082 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:55,083 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/102527.txt ...
# 2021-05-01 11:23:55,103 INFO AnGap
# 2021-05-01 11:23:55,103 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:23:55,104 INFO AnGap
# 2021-05-01 11:23:55,104 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:23:55,105 INFO AnGap
# 2021-05-01 11:23:55,105 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:23:55,106 INFO AnGap
# 2021-05-01 11:23:55,106 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:23:55,107 INFO AnGap
# 2021-05-01 11:23:55,107 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:23:55,108 INFO AnGap
# 2021-05-01 11:23:55,109 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:23:55,109 INFO AnGap
# 2021-05-01 11:23:55,110 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:23:55,110 INFO AnGap
# 2021-05-01 11:23:55,111 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:23:55,114 INFO NSCLCa
# 2021-05-01 11:23:55,115 WARNING 'NSCLCa' => 'NSCL' 'Ca'
# 2021-05-01 11:23:55,120 INFO NameIs
# 2021-05-01 11:23:55,121 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:23:55,121 INFO NameIs
# 2021-05-01 11:23:55,121 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:23:55,122 INFO NameIs
# 2021-05-01 11:23:55,122 WARNING 'NameIs' => 'Name' 'Is'
# first index not match  ('RBCs', 'Drug', (1135, 1139))
# last index not match  ('RBCs', 'Drug', (1135, 1139))
# 2021-05-01 11:23:55,339 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:55,339 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:55,339 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/103639.txt ...
# 2021-05-01 11:23:55,348 INFO NameIs
# 2021-05-01 11:23:55,348 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:23:55,353 INFO AnGap
# 2021-05-01 11:23:55,353 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:23:55,354 INFO AlkPhos
# 2021-05-01 11:23:55,354 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:23:55,354 INFO TotBili
# 2021-05-01 11:23:55,355 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:23:55,483 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:55,484 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:55,484 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/147292.txt ...
# 2021-05-01 11:23:55,503 WARNING '40s.He' cannot be parsed by current rule.
# 2021-05-01 11:23:55,508 INFO AnGap
# 2021-05-01 11:23:55,509 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:23:55,510 INFO AnGap
# 2021-05-01 11:23:55,510 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:23:55,511 INFO AlkPhos
# 2021-05-01 11:23:55,511 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:23:55,512 INFO TotBili
# 2021-05-01 11:23:55,512 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:23:55,513 INFO FENa
# 2021-05-01 11:23:55,513 WARNING 'FENa' => 'FE' 'Na'
# 2021-05-01 11:23:55,526 INFO NameIs
# 2021-05-01 11:23:55,526 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:23:55,915 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:55,916 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:55,916 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/110335.txt ...
# 2021-05-01 11:23:56,509 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:56,510 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:56,510 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/106423.txt ...
# 2021-05-01 11:23:56,527 INFO AnGap
# 2021-05-01 11:23:56,528 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:23:56,529 INFO CastHy
# 2021-05-01 11:23:56,530 WARNING 'CastHy' => 'Cast' 'Hy'
# 2021-05-01 11:23:56,533 INFO DuoNeb
# 2021-05-01 11:23:56,533 WARNING 'DuoNeb' => 'Duo' 'Neb'
# 2021-05-01 11:23:56,534 INFO ProAir
# 2021-05-01 11:23:56,535 WARNING 'ProAir' => 'Pro' 'Air'
# 2021-05-01 11:23:56,536 INFO DuoNeb
# 2021-05-01 11:23:56,536 WARNING 'DuoNeb' => 'Duo' 'Neb'
# 2021-05-01 11:23:56,537 INFO DuoNeb
# 2021-05-01 11:23:56,537 WARNING 'DuoNeb' => 'Duo' 'Neb'
# 2021-05-01 11:23:56,539 INFO ProAir
# 2021-05-01 11:23:56,539 WARNING 'ProAir' => 'Pro' 'Air'
# 2021-05-01 11:23:56,912 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:56,912 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:56,912 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/149687.txt ...
# 2021-05-01 11:23:56,991 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:56,991 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:56,992 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/106621.txt ...
# 2021-05-01 11:23:57,029 INFO OxyContin
# 2021-05-01 11:23:57,030 WARNING 'OxyContin' => 'Oxy' 'Contin'
# 2021-05-01 11:23:57,058 WARNING ('allergic reaction', 'Reason', (1667, 1684)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:23:57,060 WARNING ('Mental status change', 'Reason', (8317, 8337)) offset is overlapped with previous entity; current tok not overlap
# last index not match  ('q12h', 'Frequency', (12858, 12862))
# last index not match  ('q12h', 'Frequency', (13017, 13021))
# 2021-05-01 11:23:57,526 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:57,527 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:57,527 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/113200.txt ...
# 2021-05-01 11:23:57,557 INFO NameIs
# 2021-05-01 11:23:57,557 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:23:57,876 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:57,877 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:57,877 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/197869.txt ...
# 2021-05-01 11:23:57,892 INFO AnGap
# 2021-05-01 11:23:57,893 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:23:57,901 INFO NameIs
# 2021-05-01 11:23:57,901 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:23:57,905 INFO NameIs
# 2021-05-01 11:23:57,905 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:23:58,067 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:58,067 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:58,068 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/105106.txt ...
# 2021-05-01 11:23:58,096 INFO BiPap
# 2021-05-01 11:23:58,097 WARNING 'BiPap' => 'Bi' 'Pap'
# 2021-05-01 11:23:58,098 INFO BiPap
# 2021-05-01 11:23:58,098 WARNING 'BiPap' => 'Bi' 'Pap'
# 2021-05-01 11:23:58,103 INFO AnGap
# 2021-05-01 11:23:58,104 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:23:58,104 INFO AlkPhos
# 2021-05-01 11:23:58,105 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:23:58,105 INFO TotBili
# 2021-05-01 11:23:58,106 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:23:58,106 INFO NotDone
# 2021-05-01 11:23:58,107 WARNING 'NotDone' => 'Not' 'Done'
# 2021-05-01 11:23:58,108 INFO freeCa
# 2021-05-01 11:23:58,109 WARNING 'freeCa' => 'free' 'Ca'
# 2021-05-01 11:23:58,109 INFO NotDone
# 2021-05-01 11:23:58,110 WARNING 'NotDone' => 'Not' 'Done'
# 2021-05-01 11:23:58,111 INFO NotDone
# 2021-05-01 11:23:58,111 WARNING 'NotDone' => 'Not' 'Done'
# 2021-05-01 11:23:58,112 INFO NotDone
# 2021-05-01 11:23:58,112 WARNING 'NotDone' => 'Not' 'Done'
# 2021-05-01 11:23:58,129 INFO BiPap
# 2021-05-01 11:23:58,129 WARNING 'BiPap' => 'Bi' 'Pap'
# 2021-05-01 11:23:58,130 INFO BiPap
# 2021-05-01 11:23:58,130 WARNING 'BiPap' => 'Bi' 'Pap'
# 2021-05-01 11:23:58,142 INFO NameIs
# 2021-05-01 11:23:58,142 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:23:58,143 INFO NameIs
# 2021-05-01 11:23:58,143 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:23:58,175 WARNING ('Junctional Bradycardia', 'Reason', (17789, 17811)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:23:58,795 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:58,796 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:58,796 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/114976.txt ...
# 2021-05-01 11:23:58,924 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:58,925 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:58,925 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/101566.txt ...
# 2021-05-01 11:23:58,940 INFO AnGap
# 2021-05-01 11:23:58,941 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:23:58,941 INFO AnGap
# 2021-05-01 11:23:58,942 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:23:58,943 INFO AlkPhos
# 2021-05-01 11:23:58,943 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:23:58,943 INFO TotBili
# 2021-05-01 11:23:58,944 WARNING 'TotBili' => 'Tot' 'Bili'
# last index not match  ('b.i.d', 'Frequency', (1185, 1190))
# last index not match  ('b.i.d', 'Frequency', (3242, 3247))
# 2021-05-01 11:23:59,032 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:59,032 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:59,033 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/102053.txt ...
# 2021-05-01 11:23:59,105 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:59,105 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:59,106 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/108754.txt ...
# 2021-05-01 11:23:59,129 INFO AnGap
# 2021-05-01 11:23:59,130 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:23:59,159 WARNING ('PRBC', 'Drug', (1508, 1512)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:23:59,161 WARNING ('2u', 'Dosage', (9534, 9536)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:23:59,162 ERROR ['uPRBC', (9535, 9540), (10066, 10071), (100, 47)]	('PRBC', 'Drug', (9536, 9540)) not matched by their offsets.
# first index not match  ('PRBC', 'Drug', (1508, 1512))
# last index not match  ('PRBC', 'Drug', (1508, 1512))
# last index not match  ('2u', 'Dosage', (9534, 9536))
# first index not match  ('PRBC', 'Drug', (9536, 9540))
# last index not match  ('PRBC', 'Drug', (9536, 9540))
# 2021-05-01 11:23:59,621 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:59,622 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:59,622 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/108032.txt ...
# 2021-05-01 11:23:59,633 INFO AnGap
# 2021-05-01 11:23:59,634 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:23:59,635 INFO AnGap
# 2021-05-01 11:23:59,635 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:23:59,636 INFO freeCa
# 2021-05-01 11:23:59,636 WARNING 'freeCa' => 'free' 'Ca'
# 2021-05-01 11:23:59,659 WARNING ('1 U', 'Dosage', (3560, 3563)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:23:59,660 ERROR ['UPRBC', (3562, 3567), (3711, 3716), (39, 15)]	('PRBC', 'Drug', (3563, 3567)) not matched by their offsets.
# 2021-05-01 11:23:59,743 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:59,744 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:59,744 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/168936.txt ...
# 2021-05-01 11:23:59,765 INFO AnGap
# 2021-05-01 11:23:59,766 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:23:59,766 INFO AlkPhos
# 2021-05-01 11:23:59,767 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:23:59,767 INFO TotBili
# 2021-05-01 11:23:59,767 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:23:59,768 INFO DirBili
# 2021-05-01 11:23:59,768 WARNING 'DirBili' => 'Dir' 'Bili'
# 2021-05-01 11:23:59,769 INFO IndBili
# 2021-05-01 11:23:59,769 WARNING 'IndBili' => 'Ind' 'Bili'
# last index not match  ('1 U', 'Dosage', (3560, 3563))
# first index not match  ('PRBC', 'Drug', (3563, 3567))
# last index not match  ('PRBC', 'Drug', (3563, 3567))
# 2021-05-01 11:23:59,988 INFO sentence boundary detection class initiated.
# 2021-05-01 11:23:59,988 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:23:59,989 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/195689.txt ...
# 2021-05-01 11:24:00,019 INFO AnGap
# 2021-05-01 11:24:00,020 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:24:00,030 INFO KwikPen
# 2021-05-01 11:24:00,030 WARNING 'KwikPen' => 'Kwik' 'Pen'
# 2021-05-01 11:24:00,031 INFO KwikPen
# 2021-05-01 11:24:00,031 WARNING 'KwikPen' => 'Kwik' 'Pen'
# 2021-05-01 11:24:00,240 INFO sentence boundary detection class initiated.
# 2021-05-01 11:24:00,240 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:24:00,241 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/116966.txt ...
# 2021-05-01 11:24:00,265 INFO NotDone
# 2021-05-01 11:24:00,266 WARNING 'NotDone' => 'Not' 'Done'
# 2021-05-01 11:24:00,270 INFO NotDone
# 2021-05-01 11:24:00,270 WARNING 'NotDone' => 'Not' 'Done'
# 2021-05-01 11:24:00,310 WARNING ('IDDM', 'Reason', (3573, 3577)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:24:00,312 WARNING ('[**Name (NI) 44405**]', 'Drug', (10915, 10936)) offset is overlapped with previous entity; current tok not overlap
# first index not match  ('[**Name (NI) 44405**]', 'Drug', (10915, 10936))
# last index not match  ('[**Name (NI) 44405**]', 'Drug', (10915, 10936))
# 2021-05-01 11:24:00,938 INFO sentence boundary detection class initiated.
# 2021-05-01 11:24:00,939 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:24:00,939 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/101215.txt ...
# 2021-05-01 11:24:00,952 INFO AnGap
# 2021-05-01 11:24:00,953 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:24:00,953 INFO AlkPhos
# 2021-05-01 11:24:00,954 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:24:00,954 INFO TotBili
# 2021-05-01 11:24:00,955 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:24:01,119 INFO sentence boundary detection class initiated.
# 2021-05-01 11:24:01,119 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:24:01,120 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/124917.txt ...
# 2021-05-01 11:24:01,138 INFO AlkPhos
# 2021-05-01 11:24:01,138 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:24:01,139 INFO TotBili
# 2021-05-01 11:24:01,139 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:24:01,163 WARNING ('otics', 'Drug', (6638, 6643)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:24:01,276 INFO sentence boundary detection class initiated.
# 2021-05-01 11:24:01,277 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:24:01,277 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/190444.txt ...
# 2021-05-01 11:24:01,305 INFO AnGap
# 2021-05-01 11:24:01,305 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:24:01,306 INFO AlkPhos
# 2021-05-01 11:24:01,306 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:24:01,307 INFO TotBili
# 2021-05-01 11:24:01,307 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:24:01,310 INFO AnGap
# 2021-05-01 11:24:01,310 WARNING 'AnGap' => 'An' 'Gap'
# first index not match  ('otics', 'Drug', (6638, 6643))
# last index not match  ('otics', 'Drug', (6638, 6643))
# 2021-05-01 11:24:02,067 INFO sentence boundary detection class initiated.
# 2021-05-01 11:24:02,068 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:24:02,068 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/182040.txt ...
# 2021-05-01 11:24:02,170 INFO sentence boundary detection class initiated.
# 2021-05-01 11:24:02,171 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:24:02,171 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/102668.txt ...
# 2021-05-01 11:24:02,205 WARNING '3.5x26mm' cannot be parsed by current rule.
# 2021-05-01 11:24:02,206 WARNING '3.5x12mm' cannot be parsed by current rule.
# 2021-05-01 11:24:02,222 INFO PatientFamily
# 2021-05-01 11:24:02,222 WARNING 'PatientFamily' => 'Patient' 'Family'
# 2021-05-01 11:24:02,248 WARNING ('DM', 'Reason', (17242, 17244)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:24:02,376 INFO sentence boundary detection class initiated.
# 2021-05-01 11:24:02,377 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:24:02,377 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/188551.txt ...
# 2021-05-01 11:24:02,390 INFO freeCa
# 2021-05-01 11:24:02,391 WARNING 'freeCa' => 'free' 'Ca'
# first index not match  ('DM', 'Reason', (17242, 17244))
# last index not match  ('DM', 'Reason', (17242, 17244))
# 2021-05-01 11:24:02,528 INFO sentence boundary detection class initiated.
# 2021-05-01 11:24:02,529 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:24:02,529 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/114585.txt ...
# 2021-05-01 11:24:02,559 INFO weekProvider
# 2021-05-01 11:24:02,560 WARNING 'weekProvider' => 'week' 'Provider'
# 2021-05-01 11:24:02,579 WARNING ('q8', 'Frequency', (8716, 8718)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:24:02,780 INFO sentence boundary detection class initiated.
# 2021-05-01 11:24:02,780 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:24:02,781 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/102456.txt ...
# last index not match  ('25', 'Strength', (8714, 8716))
# first index not match  ('q8', 'Frequency', (8716, 8718))
# last index not match  ('q8', 'Frequency', (8716, 8718))
# 2021-05-01 11:24:02,803 INFO AnGap
# 2021-05-01 11:24:02,803 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:24:02,804 INFO AnGap
# 2021-05-01 11:24:02,805 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:24:02,805 INFO AnGap
# 2021-05-01 11:24:02,806 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:24:02,807 INFO TotBili
# 2021-05-01 11:24:02,807 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:24:03,262 INFO sentence boundary detection class initiated.
# 2021-05-01 11:24:03,263 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:24:03,263 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/102324.txt ...
# 2021-05-01 11:24:03,294 INFO AnGap
# 2021-05-01 11:24:03,295 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:24:03,296 INFO LDLcalc
# 2021-05-01 11:24:03,297 WARNING 'LDLcalc' => 'LD' 'Lcalc'
# last index not match  ('D50', 'Drug', (1515, 1518))
# 2021-05-01 11:24:03,615 INFO sentence boundary detection class initiated.
# 2021-05-01 11:24:03,615 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:24:03,616 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/114220.txt ...
# 2021-05-01 11:24:03,647 INFO NotDone
# 2021-05-01 11:24:03,648 WARNING 'NotDone' => 'Not' 'Done'
# 2021-05-01 11:24:03,649 INFO NotDone
# 2021-05-01 11:24:03,649 WARNING 'NotDone' => 'Not' 'Done'
# 2021-05-01 11:24:03,655 INFO mmHgs
# 2021-05-01 11:24:03,655 WARNING 'mmHgs' => 'mm' 'Hgs'
# 2021-05-01 11:24:03,671 INFO NameIs
# 2021-05-01 11:24:03,672 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:24:04,204 INFO sentence boundary detection class initiated.
# 2021-05-01 11:24:04,204 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:24:04,205 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/189471.txt ...
# 2021-05-01 11:24:04,254 WARNING ('1', 'Dosage', (1447, 1448)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:24:04,480 INFO sentence boundary detection class initiated.
# 2021-05-01 11:24:04,480 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:24:04,481 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/153141.txt ...
# first index not match  ('1', 'Dosage', (1447, 1448))
# last index not match  ('1', 'Dosage', (1447, 1448))
# first index not match  ('7 days', 'Duration', (10752, 10758))
# 2021-05-01 11:24:04,868 INFO sentence boundary detection class initiated.
# 2021-05-01 11:24:04,868 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:24:04,869 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/118418.txt ...
# 2021-05-01 11:24:05,051 INFO sentence boundary detection class initiated.
# 2021-05-01 11:24:05,051 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:24:05,052 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/121514.txt ...
# 2021-05-01 11:24:05,075 INFO AnGap
# 2021-05-01 11:24:05,075 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:24:05,076 INFO AnGap
# 2021-05-01 11:24:05,076 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:24:05,081 INFO AnGap
# 2021-05-01 11:24:05,081 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:24:05,356 INFO sentence boundary detection class initiated.
# 2021-05-01 11:24:05,357 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:24:05,357 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/141586.txt ...
# 2021-05-01 11:24:05,381 INFO AnGap
# 2021-05-01 11:24:05,382 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:24:05,386 INFO NameIs
# 2021-05-01 11:24:05,387 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:24:05,389 INFO NameIs
# 2021-05-01 11:24:05,390 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:24:05,390 INFO NameIs
# 2021-05-01 11:24:05,390 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:24:05,413 WARNING ('Vitamin K', 'Drug', (1255, 1264)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:24:05,415 WARNING ('INR was >20', 'Reason', (7571, 7582)) offset is overlapped with previous entity; current tok not overlap
# last index not match  ('Vitamin K', 'Drug', (1255, 1264))
# 2021-05-01 11:24:05,696 INFO sentence boundary detection class initiated.
# 2021-05-01 11:24:05,697 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:24:05,697 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/160574.txt ...
# 2021-05-01 11:24:05,732 INFO AnGap
# 2021-05-01 11:24:05,732 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:24:05,733 INFO AnGap
# 2021-05-01 11:24:05,733 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:24:05,734 INFO AlkPhos
# 2021-05-01 11:24:05,734 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:24:05,735 INFO TotBili
# 2021-05-01 11:24:05,735 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:24:05,738 INFO RheuFac
# 2021-05-01 11:24:05,738 WARNING 'RheuFac' => 'Rheu' 'Fac'
# 2021-05-01 11:24:05,741 INFO TotProt
# 2021-05-01 11:24:05,741 WARNING 'TotProt' => 'Tot' 'Prot'
# 2021-05-01 11:24:05,763 INFO TIDac
# 2021-05-01 11:24:05,764 WARNING 'TIDac' => 'TI' 'Dac'
# 2021-05-01 11:24:05,772 INFO NameIs
# 2021-05-01 11:24:05,773 WARNING 'NameIs' => 'Name' 'Is'
# first index not match  ('ng-acting narcotics', 'Drug', (18169, 18188))
# 2021-05-01 11:24:06,740 INFO sentence boundary detection class initiated.
# 2021-05-01 11:24:06,741 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:24:06,741 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/191016.txt ...
# 2021-05-01 11:24:06,759 INFO HYDROmorphone
# 2021-05-01 11:24:06,759 WARNING 'HYDROmorphone' => 'HYDR' 'Omorphone'
# 2021-05-01 11:24:06,869 INFO sentence boundary detection class initiated.
# 2021-05-01 11:24:06,870 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:24:06,870 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/115464.txt ...
# 2021-05-01 11:24:06,880 INFO AnGap
# 2021-05-01 11:24:06,881 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:24:06,882 INFO AlkPhos
# 2021-05-01 11:24:06,882 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:24:06,883 INFO TotBili
# 2021-05-01 11:24:06,883 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:24:06,884 INFO AlkPhos
# 2021-05-01 11:24:06,884 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:24:06,885 INFO TotBili
# 2021-05-01 11:24:06,885 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:24:06,885 INFO DirBili
# 2021-05-01 11:24:06,886 WARNING 'DirBili' => 'Dir' 'Bili'
# 2021-05-01 11:24:06,886 INFO IndBili
# 2021-05-01 11:24:06,887 WARNING 'IndBili' => 'Ind' 'Bili'
# 2021-05-01 11:24:06,888 INFO AnGap
# 2021-05-01 11:24:06,888 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:24:06,889 INFO AnGap
# 2021-05-01 11:24:06,889 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:24:06,890 INFO AnGap
# 2021-05-01 11:24:06,890 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:24:06,891 INFO AnGap
# 2021-05-01 11:24:06,891 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:24:06,892 INFO AnGap
# 2021-05-01 11:24:06,892 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:24:06,893 INFO AnGap
# 2021-05-01 11:24:06,893 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:24:06,894 INFO AnGap
# 2021-05-01 11:24:06,895 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:24:06,895 INFO AlkPhos
# 2021-05-01 11:24:06,896 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:24:06,896 INFO TotBili
# 2021-05-01 11:24:06,897 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:24:06,897 INFO AlkPhos
# 2021-05-01 11:24:06,898 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:24:06,898 INFO TotBili
# 2021-05-01 11:24:06,898 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:24:06,899 INFO AlkPhos
# 2021-05-01 11:24:06,899 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:24:06,900 INFO TotBili
# 2021-05-01 11:24:06,900 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:24:06,901 INFO AlkPhos
# 2021-05-01 11:24:06,901 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:24:06,902 INFO TotBili
# 2021-05-01 11:24:06,902 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:24:06,907 INFO NameIs
# 2021-05-01 11:24:06,908 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:24:06,909 INFO NameIs
# 2021-05-01 11:24:06,909 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:24:06,910 INFO NameIs
# 2021-05-01 11:24:06,910 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:24:07,034 INFO sentence boundary detection class initiated.
# 2021-05-01 11:24:07,035 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:24:07,035 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/191162.txt ...
# 2021-05-01 11:24:07,058 INFO AnGap
# 2021-05-01 11:24:07,058 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:24:07,404 INFO sentence boundary detection class initiated.
# 2021-05-01 11:24:07,405 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:24:07,405 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/110326.txt ...
# 2021-05-01 11:24:07,427 INFO PmHx
# 2021-05-01 11:24:07,428 WARNING 'PmHx' => 'Pm' 'Hx'
# 2021-05-01 11:24:07,448 INFO NameIs
# 2021-05-01 11:24:07,448 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:24:07,452 INFO NameIs
# 2021-05-01 11:24:07,453 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:24:07,454 INFO NameIs
# 2021-05-01 11:24:07,454 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:24:07,455 INFO NameIs
# 2021-05-01 11:24:07,455 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:24:07,742 INFO sentence boundary detection class initiated.
# 2021-05-01 11:24:07,743 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:24:07,743 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/107869.txt ...
# 2021-05-01 11:24:07,759 INFO AnGap
# 2021-05-01 11:24:07,760 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:24:07,760 INFO AlkPhos
# 2021-05-01 11:24:07,760 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:24:07,761 INFO TotBili
# 2021-05-01 11:24:07,761 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:24:07,866 INFO sentence boundary detection class initiated.
# 2021-05-01 11:24:07,866 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:24:07,867 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/128652.txt ...
# 2021-05-01 11:24:07,967 INFO sentence boundary detection class initiated.
# 2021-05-01 11:24:07,968 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:24:07,968 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/102087.txt ...
# 2021-05-01 11:24:07,988 INFO LDLcalc
# 2021-05-01 11:24:07,988 WARNING 'LDLcalc' => 'LD' 'Lcalc'
# 2021-05-01 11:24:07,994 INFO NameIs
# 2021-05-01 11:24:07,995 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:24:07,995 INFO NameIs
# 2021-05-01 11:24:07,996 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:24:07,996 INFO NameIs
# 2021-05-01 11:24:07,997 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:24:08,200 INFO sentence boundary detection class initiated.
# 2021-05-01 11:24:08,201 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:24:08,202 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/127944.txt ...
# 2021-05-01 11:24:08,353 INFO sentence boundary detection class initiated.
# ...
# 2021-05-01 11:25:30,737 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:25:30,738 INFO AlkPhos
# 2021-05-01 11:25:30,738 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:25:30,739 INFO TotBili
# 2021-05-01 11:25:30,740 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:25:30,741 INFO AlkPhos
# 2021-05-01 11:25:30,741 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:25:30,742 INFO TotBili
# 2021-05-01 11:25:30,743 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:25:30,744 INFO AlkPhos
# 2021-05-01 11:25:30,744 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:25:30,745 INFO TotBili
# 2021-05-01 11:25:30,745 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:25:30,746 INFO DirBili
# 2021-05-01 11:25:30,746 WARNING 'DirBili' => 'Dir' 'Bili'
# 2021-05-01 11:25:30,747 INFO IndBili
# 2021-05-01 11:25:30,747 WARNING 'IndBili' => 'Ind' 'Bili'
# 2021-05-01 11:25:30,748 INFO AlkPhos
# 2021-05-01 11:25:30,748 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:25:30,748 INFO TotBili
# 2021-05-01 11:25:30,749 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:25:30,749 INFO TotBili
# 2021-05-01 11:25:30,750 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:25:30,753 INFO LDLcalc
# 2021-05-01 11:25:30,754 WARNING 'LDLcalc' => 'LD' 'Lcalc'
# 2021-05-01 11:25:30,754 INFO LDLcalc
# 2021-05-01 11:25:30,755 WARNING 'LDLcalc' => 'LD' 'Lcalc'
# 2021-05-01 11:25:30,759 INFO freeCa
# 2021-05-01 11:25:30,760 WARNING 'freeCa' => 'free' 'Ca'
# 2021-05-01 11:25:30,760 INFO freeCa
# 2021-05-01 11:25:30,761 WARNING 'freeCa' => 'free' 'Ca'
# 2021-05-01 11:25:30,761 INFO freeCa
# 2021-05-01 11:25:30,762 WARNING 'freeCa' => 'free' 'Ca'
# 2021-05-01 11:25:30,762 INFO freeCa
# 2021-05-01 11:25:30,763 WARNING 'freeCa' => 'free' 'Ca'
# 2021-05-01 11:25:30,763 INFO freeCa
# 2021-05-01 11:25:30,764 WARNING 'freeCa' => 'free' 'Ca'
# 2021-05-01 11:25:30,764 INFO freeCa
# 2021-05-01 11:25:30,764 WARNING 'freeCa' => 'free' 'Ca'
# 2021-05-01 11:25:30,949 INFO sentence boundary detection class initiated.
# 2021-05-01 11:25:30,950 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:25:30,950 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/109866.txt ...
# 2021-05-01 11:25:31,122 INFO sentence boundary detection class initiated.
# 2021-05-01 11:25:31,123 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:25:31,123 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/111542.txt ...
# 2021-05-01 11:25:31,356 INFO sentence boundary detection class initiated.
# 2021-05-01 11:25:31,356 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:25:31,357 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/143562.txt ...
# 2021-05-01 11:25:31,392 INFO AnGap
# 2021-05-01 11:25:31,393 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:25:31,394 INFO AlkPhos
# 2021-05-01 11:25:31,394 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:25:31,394 INFO TotBili
# 2021-05-01 11:25:31,395 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:25:31,395 INFO DirBili
# 2021-05-01 11:25:31,396 WARNING 'DirBili' => 'Dir' 'Bili'
# 2021-05-01 11:25:31,396 INFO IndBili
# 2021-05-01 11:25:31,396 WARNING 'IndBili' => 'Ind' 'Bili'
# 2021-05-01 11:25:31,632 INFO sentence boundary detection class initiated.
# 2021-05-01 11:25:31,633 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:25:31,633 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/101779.txt ...
# 2021-05-01 11:25:31,864 INFO sentence boundary detection class initiated.
# 2021-05-01 11:25:31,864 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:25:31,865 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/127741.txt ...
# 2021-05-01 11:25:31,881 INFO AnGap
# 2021-05-01 11:25:31,882 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:25:31,882 INFO AlkPhos
# 2021-05-01 11:25:31,883 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:25:31,883 INFO TotBili
# 2021-05-01 11:25:31,884 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:25:31,888 INFO AnGap
# 2021-05-01 11:25:31,889 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:25:32,038 INFO sentence boundary detection class initiated.
# 2021-05-01 11:25:32,039 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:25:32,039 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/117872.txt ...
# 2021-05-01 11:25:32,052 INFO AnGap
# 2021-05-01 11:25:32,053 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:25:32,054 INFO AlkPhos
# 2021-05-01 11:25:32,054 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:25:32,055 INFO TotBili
# 2021-05-01 11:25:32,055 WARNING 'TotBili' => 'Tot' 'Bili'
# first index not match  ('ntermittent hemoptysis/blood streaked sputum', 'ADE', (6883, 6927))
# 2021-05-01 11:25:32,258 INFO sentence boundary detection class initiated.
# 2021-05-01 11:25:32,259 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:25:32,259 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/109697.txt ...
# 2021-05-01 11:25:32,337 WARNING ('Suspension', 'Form', (19228, 19238)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:25:32,887 INFO sentence boundary detection class initiated.
# 2021-05-01 11:25:32,888 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:25:32,888 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/114836.txt ...
# 2021-05-01 11:25:32,904 INFO AnGap
# 2021-05-01 11:25:32,904 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:25:32,905 INFO AnGap
# 2021-05-01 11:25:32,905 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:25:32,906 INFO AlkPhos
# 2021-05-01 11:25:32,906 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:25:32,907 INFO TotBili
# 2021-05-01 11:25:32,907 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:25:32,908 INFO AlkPhos
# 2021-05-01 11:25:32,909 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:25:32,909 INFO TotBili
# 2021-05-01 11:25:32,909 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:25:32,910 INFO AlkPhos
# 2021-05-01 11:25:32,910 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:25:32,911 INFO TotBili
# 2021-05-01 11:25:32,911 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:25:32,912 INFO AlkPhos
# 2021-05-01 11:25:32,912 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:25:32,912 INFO TotBili
# 2021-05-01 11:25:32,913 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:25:32,914 INFO AlkPhos
# 2021-05-01 11:25:32,914 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:25:32,914 INFO TotBili
# 2021-05-01 11:25:32,915 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:25:32,916 INFO AlkPhos
# 2021-05-01 11:25:32,916 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:25:32,916 INFO TotBili
# 2021-05-01 11:25:32,917 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:25:33,207 INFO sentence boundary detection class initiated.
# 2021-05-01 11:25:33,207 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:25:33,207 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/161477.txt ...
# 2021-05-01 11:25:33,252 INFO AnGap
# 2021-05-01 11:25:33,253 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:25:33,257 INFO AlkPhos
# 2021-05-01 11:25:33,257 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:25:33,257 INFO TotBili
# 2021-05-01 11:25:33,258 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:25:33,258 INFO DirBili
# 2021-05-01 11:25:33,259 WARNING 'DirBili' => 'Dir' 'Bili'
# 2021-05-01 11:25:33,259 INFO IndBili
# 2021-05-01 11:25:33,259 WARNING 'IndBili' => 'Ind' 'Bili'
# 2021-05-01 11:25:33,261 INFO TotProt
# 2021-05-01 11:25:33,262 WARNING 'TotProt' => 'Tot' 'Prot'
# 2021-05-01 11:25:33,262 INFO UricAcd
# 2021-05-01 11:25:33,263 WARNING 'UricAcd' => 'Uric' 'Acd'
# 2021-05-01 11:25:33,264 INFO LDLcalc
# 2021-05-01 11:25:33,265 WARNING 'LDLcalc' => 'LD' 'Lcalc'
# 2021-05-01 11:25:33,274 INFO FENa
# 2021-05-01 11:25:33,275 WARNING 'FENa' => 'FE' 'Na'
# last index not match  ('O2', 'Drug', (1701, 1703))
# 2021-05-01 11:25:33,753 INFO sentence boundary detection class initiated.
# 2021-05-01 11:25:33,753 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:25:33,754 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/106361.txt ...
# 2021-05-01 11:25:33,789 INFO AnGap
# 2021-05-01 11:25:33,790 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:25:33,790 INFO AlkPhos
# 2021-05-01 11:25:33,791 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:25:33,792 INFO TotBili
# 2021-05-01 11:25:33,792 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:25:33,793 INFO TotProt
# 2021-05-01 11:25:33,794 WARNING 'TotProt' => 'Tot' 'Prot'
# 2021-05-01 11:25:33,796 INFO freeCa
# 2021-05-01 11:25:33,796 WARNING 'freeCa' => 'free' 'Ca'
# 2021-05-01 11:25:33,816 INFO ProAir
# 2021-05-01 11:25:33,816 WARNING 'ProAir' => 'Pro' 'Air'
# 2021-05-01 11:25:33,850 WARNING ('2L', 'Dosage', (11456, 11458)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:25:33,851 ERROR ['LNC', (11457, 11460), (11903, 11906), (151, 11)]	('NC', 'Route', (11458, 11460)) not matched by their offsets.
# 2021-05-01 11:25:33,851 WARNING ('NC', 'Route', (11667, 11669)) offset is overlapped with previous entity; current tok not overlap
# last index not match  ('2L', 'Dosage', (11456, 11458))
# first index not match  ('NC', 'Route', (11458, 11460))
# last index not match  ('NC', 'Route', (11458, 11460))
# last index not match  ('2L', 'Dosage', (11665, 11667))
# first index not match  ('NC', 'Route', (11667, 11669))
# last index not match  ('NC', 'Route', (11667, 11669))
# 2021-05-01 11:25:35,147 INFO sentence boundary detection class initiated.
# 2021-05-01 11:25:35,151 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:25:35,152 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/117907.txt ...
# 2021-05-01 11:25:35,168 INFO AnGap
# 2021-05-01 11:25:35,169 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:25:35,170 INFO AnGap
# 2021-05-01 11:25:35,170 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:25:35,171 INFO AnGap
# 2021-05-01 11:25:35,172 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:25:35,172 INFO AlkPhos
# 2021-05-01 11:25:35,173 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:25:35,173 INFO TotBili
# 2021-05-01 11:25:35,173 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:25:35,179 INFO freeCa
# 2021-05-01 11:25:35,180 WARNING 'freeCa' => 'free' 'Ca'
# 2021-05-01 11:25:35,262 INFO sentence boundary detection class initiated.
# 2021-05-01 11:25:35,263 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:25:35,263 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/186788.txt ...
# 2021-05-01 11:25:35,723 INFO sentence boundary detection class initiated.
# 2021-05-01 11:25:35,723 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:25:35,724 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/131903.txt ...
# 2021-05-01 11:25:35,789 INFO sentence boundary detection class initiated.
# 2021-05-01 11:25:35,790 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:25:35,790 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/107255.txt ...
# 2021-05-01 11:25:35,816 INFO AnGap
# 2021-05-01 11:25:35,816 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:25:35,818 INFO AlkPhos
# 2021-05-01 11:25:35,819 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:25:35,819 INFO TotBili
# 2021-05-01 11:25:35,820 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:25:35,820 INFO DirBili
# 2021-05-01 11:25:35,821 WARNING 'DirBili' => 'Dir' 'Bili'
# 2021-05-01 11:25:35,822 INFO TotProt
# 2021-05-01 11:25:35,822 WARNING 'TotProt' => 'Tot' 'Prot'
# 2021-05-01 11:25:35,822 INFO UricAcd
# 2021-05-01 11:25:35,823 WARNING 'UricAcd' => 'Uric' 'Acd'
# 2021-05-01 11:25:35,837 INFO OxyContin
# 2021-05-01 11:25:35,838 WARNING 'OxyContin' => 'Oxy' 'Contin'
# 2021-05-01 11:25:35,863 WARNING ('2', 'Dosage', (9727, 9728)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:25:35,863 WARNING ('1', 'Dosage', (9745, 9746)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:25:35,864 WARNING ('1', 'Dosage', (10061, 10062)) offset is overlapped with previous entity; current tok not overlap
# first index not match  ('1', 'Dosage', (9745, 9746))
# last index not match  ('1', 'Dosage', (9745, 9746))
# first index not match  ('2', 'Dosage', (9727, 9728))
# last index not match  ('2', 'Dosage', (9727, 9728))
# first index not match  ('1', 'Dosage', (10061, 10062))
# last index not match  ('1', 'Dosage', (10061, 10062))
# 2021-05-01 11:25:36,368 INFO sentence boundary detection class initiated.
# 2021-05-01 11:25:36,368 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:25:36,369 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/119069.txt ...
# 2021-05-01 11:25:36,653 INFO sentence boundary detection class initiated.
# 2021-05-01 11:25:36,653 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:25:36,654 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/104979.txt ...
# 2021-05-01 11:25:36,811 INFO sentence boundary detection class initiated.
# 2021-05-01 11:25:36,812 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:25:36,812 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/105050.txt ...
# 2021-05-01 11:25:36,848 INFO NotDone
# 2021-05-01 11:25:36,849 WARNING 'NotDone' => 'Not' 'Done'
# 2021-05-01 11:25:36,913 WARNING ('morphine', 'Drug', (1677, 1685)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:25:36,917 WARNING ('pain', 'Reason', (23257, 23261)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:25:38,234 INFO sentence boundary detection class initiated.
# 2021-05-01 11:25:38,235 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:25:38,235 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/117871.txt ...
# 2021-05-01 11:25:38,251 INFO AnGap
# 2021-05-01 11:25:38,252 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:25:38,252 INFO AnGap
# 2021-05-01 11:25:38,253 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:25:38,408 INFO sentence boundary detection class initiated.
# 2021-05-01 11:25:38,409 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:25:38,409 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/168915.txt ...
# 2021-05-01 11:25:38,562 INFO sentence boundary detection class initiated.
# 2021-05-01 11:25:38,563 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:25:38,563 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/107322.txt ...
# 2021-05-01 11:25:38,594 INFO NameIs
# 2021-05-01 11:25:38,594 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:25:38,607 INFO FeNa
# 2021-05-01 11:25:38,608 WARNING 'FeNa' => 'Fe' 'Na'
# 2021-05-01 11:25:38,636 WARNING ('ARF', 'Reason', (15073, 15076)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:25:38,891 INFO sentence boundary detection class initiated.
# 2021-05-01 11:25:38,892 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:25:38,892 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/118564.txt ...
# 2021-05-01 11:25:39,008 INFO sentence boundary detection class initiated.
# 2021-05-01 11:25:39,008 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:25:39,009 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/track2-training_data/100883.txt ...
# 2021-05-01 11:25:39,047 WARNING ('Hypotension', 'Reason', (5871, 5882)) offset is overlapped with previous entity; current tok not overlap
# last index not match  ('b.i.d', 'Frequency', (2293, 2298))

# %%
"""
0 32436
1 2409
3 162
2 446
4 94

3 51321
1 55317
4 49820
2 54012
0 18137
"""

for k, v in dpos.items():
    print(k, len(v))
    
for k, v in dneg.items():
    print(k, len(v))
# Out:
# 0 32302
# 1 2464
# 1 53586
# 0 15919

# %%
dpos[1]
# Out:
# [(1,
#   'Frequency-Drug',
#   'Hospital 1 [s1] ( 2 times a day ) as needed [e1] for itchiness : Can apply to back of calf or other regions of itchy skin .',
#   'Disp : * 60 Capsule ( s ) * Refills : * 0 * 22 . [s2] Camphor - Menthol [e2] 0.5 - 0.5 % Lotion Sig : One ( 1 ) Appl Topical',
#   'Frequency',
#   'Drug',
#   'T3',
#   'T1',
#   '110727'),
#  (1,
#   'Frequency-Drug',
#   'Subcutaneous [s1] once a month [e1] .',
#   'Disp : * 30 Tablet ( s ) * Refills : * 0 * 5 . [s2] Golimumab [e2] 50 mg / 0.5 mL Pen Injector Sig : Fifty ( 50 ) mg',
#   'Frequency',
#   'Drug',
#   'T278',
#   'T178',
#   '110727'),
#  (1,
#   'Route-Drug',
#   '[s1] Subcutaneous [e1] once a month .',
#   'Disp : * 30 Tablet ( s ) * Refills : * 0 * 5 . [s2] Golimumab [e2] 50 mg / 0.5 mL Pen Injector Sig : Fifty ( 50 ) mg',
#   'Route',
#   'Drug',
#   'T277',
#   'T178',
#   '110727'),
#  (1,
#   'Reason-Drug',
#   'Sig : 1 - 2 Tablets PO every six ( 6 ) hours as needed for [s1] heartburn [e1] .',
#   '6 . [s2] Phenobarb - Hyoscy - Atropine - Scop [e2] 16.2 - 0.1037 - 0.0194 mg Tablet',
#   'Reason',
#   'Drug',
#   'T198',
#   'T101',
#   '110727'),
#  (1,
#   'Frequency-Drug',
#   'Sig : 1 - 2 Tablets PO [s1] every six ( 6 ) hours as needed [e1] for heartburn .',
#   '6 . [s2] Phenobarb - Hyoscy - Atropine - Scop [e2] 16.2 - 0.1037 - 0.0194 mg Tablet',
#   'Frequency',
#   'Drug',
#   'T282',
#   'T101',
#   '110727'),
#  (1,
#   'Route-Drug',
#   'Sig : 1 - 2 Tablets [s1] PO [e1] every six ( 6 ) hours as needed for heartburn .',
#   '6 . [s2] Phenobarb - Hyoscy - Atropine - Scop [e2] 16.2 - 0.1037 - 0.0194 mg Tablet',
#   'Route',
#   'Drug',
#   'T281',
#   'T101',
#   '110727'),
#  (1,
#   'Form-Drug',
#   'Sig : 1 - 2 [s1] Tablets [e1] PO every six ( 6 ) hours as needed for heartburn .',
#   '6 . [s2] Phenobarb - Hyoscy - Atropine - Scop [e2] 16.2 - 0.1037 - 0.0194 mg Tablet',
#   'Form',
#   'Drug',
#   'T280',
#   'T101',
#   '110727'),
#  (1,
#   'Dosage-Drug',
#   'Sig : [s1] 1 - 2 [e1] Tablets PO every six ( 6 ) hours as needed for heartburn .',
#   '6 . [s2] Phenobarb - Hyoscy - Atropine - Scop [e2] 16.2 - 0.1037 - 0.0194 mg Tablet',
#   'Dosage',
#   'Drug',
#   'T279',
#   'T101',
#   '110727'),
#  (1,
#   'Frequency-Drug',
#   'Sig : One ( 1 ) Tablet Sustained Release 24 hr PO [s1] BID ( 2 times a day ) [e1] .',
#   '8 . [s2] Metoprolol Succinate [e2] 100 mg Tablet Sustained Release 24 hr',
#   'Frequency',
#   'Drug',
#   'T288',
#   'T42',
#   '110727'),
#  (1,
#   'Route-Drug',
#   'Sig : One ( 1 ) Tablet Sustained Release 24 hr [s1] PO [e1] BID ( 2 times a day ) .',
#   '8 . [s2] Metoprolol Succinate [e2] 100 mg Tablet Sustained Release 24 hr',
#   'Route',
#   'Drug',
#   'T287',
#   'T42',
#   '110727'),
#  (1,
#   'Form-Drug',
#   'Sig : One ( 1 ) [s1] Tablet Sustained Release 24 hr [e1] PO BID ( 2 times a day ) .',
#   '8 . [s2] Metoprolol Succinate [e2] 100 mg Tablet Sustained Release 24 hr',
#   'Form',
#   'Drug',
#   'T286',
#   'T42',
#   '110727'),
#  (1,
#   'Dosage-Drug',
#   'Sig : [s1] One ( 1 ) [e1] Tablet Sustained Release 24 hr PO BID ( 2 times a day ) .',
#   '8 . [s2] Metoprolol Succinate [e2] 100 mg Tablet Sustained Release 24 hr',
#   'Dosage',
#   'Drug',
#   'T285',
#   'T42',
#   '110727'),
#  (1,
#   'Frequency-Drug',
#   '[s1] DAILY ( Daily ) [e1] .',
#   '9 . [s2] Hydrochlorothiazide [e2] 12.5 mg Capsule Sig : One ( 1 ) Capsule PO',
#   'Frequency',
#   'Drug',
#   'T291',
#   'T146',
#   '110727'),
#  (1,
#   'Reason-Drug',
#   'Hospital 1 ( 2 times a day ) as needed for [s1] itchiness [e1] : Can apply to back of calf or other regions of itchy skin .',
#   'Disp : * 60 Capsule ( s ) * Refills : * 0 * 22 . [s2] Camphor - Menthol [e2] 0.5 - 0.5 % Lotion Sig : One ( 1 ) Appl Topical',
#   'Reason',
#   'Drug',
#   'T330',
#   'T1',
#   '110727'),
#  (1,
#   'Reason-Drug',
#   'He developed a body rash that was determined to be [s1] folliculitis [e1] .',
#   'He completed the 2 week course IV [s2] antibiotics [e2] in house .',
#   'Reason',
#   'Drug',
#   'T387',
#   'T386',
#   '110727'),
#  (1,
#   'Reason-Drug',
#   'His major issue remained to be [s1] pain management [e1] .',
#   'He required a large amount of [s2] narcotics [e2] to control his pain , but after overdose ( see below ) he was switched to a very conservative regimen .',
#   'Reason',
#   'Drug',
#   'T389',
#   'T388',
#   '110727'),
#  (1,
#   'Reason-Drug',
#   'He had one positive [s1] blood culture with pan - sensitive staph [e1] .',
#   'He was placed on zosyn , later narrowed to [s2] nafcillin [e2] .',
#   'Reason',
#   'Drug',
#   'T383',
#   'T71',
#   '110727'),
#  (1,
#   'Reason-Drug',
#   'He had one positive [s1] blood culture with pan - sensitive staph [e1] .',
#   'He was placed on [s2] zosyn [e2] , later narrowed to nafcillin .',
#   'Reason',
#   'Drug',
#   'T383',
#   'T60',
#   '110727'),
#  (1,
#   'Frequency-Drug',
#   '[s1] TID [e1] from 130 mg TID , in addition to being ordered for PRN',
#   "# Medication overdose : On 2202 - 1 - 26 , on recommendation from the pain service , patient ' s [s2] MS Contin [e2] dose was increased to 160 mg",
#   'Frequency',
#   'Drug',
#   'T211',
#   'T96',
#   '110727'),
#  (1,
#   'Strength-Drug',
#   'TID from [s1] 130 mg [e1] TID , in addition to being ordered for PRN',
#   "# Medication overdose : On 2202 - 1 - 26 , on recommendation from the pain service , patient ' s [s2] MS Contin [e2] dose was increased to 160 mg",
#   'Strength',
#   'Drug',
#   'T392',
#   'T96',
#   '110727'),
#  (1,
#   'Frequency-Drug',
#   'TID from 130 mg [s1] TID [e1] , in addition to being ordered for PRN',
#   "# Medication overdose : On 2202 - 1 - 26 , on recommendation from the pain service , patient ' s [s2] MS Contin [e2] dose was increased to 160 mg",
#   'Frequency',
#   'Drug',
#   'T393',
#   'T96',
#   '110727'),
#  (1,
#   'Frequency-Drug',
#   'TID from 130 mg TID , in addition to being ordered for [s1] PRN [e1]',
#   '[s2] Dilaudid [e2] .',
#   'Frequency',
#   'Drug',
#   'T394',
#   'T171',
#   '110727'),
#  (1,
#   'Route-Drug',
#   '[s1] PO [e1] DAILY ( Daily ) .',
#   '20 . [s2] Aspirin [e2] 81 mg Tablet , Chewable Sig : One ( 1 ) Tablet , Chewable',
#   'Route',
#   'Drug',
#   'T422',
#   'T31',
#   '110727'),
#  (1,
#   'Frequency-Drug',
#   'PO [s1] DAILY ( Daily ) [e1] .',
#   '20 . [s2] Aspirin [e2] 81 mg Tablet , Chewable Sig : One ( 1 ) Tablet , Chewable',
#   'Frequency',
#   'Drug',
#   'T325',
#   'T31',
#   '110727'),
#  (1,
#   'Form-Drug',
#   'Disp : * 60 [s1] Capsule [e1] ( s ) * Refills : * 0 * 22 . Camphor - Menthol 0.5 - 0.5 % Lotion Sig : One ( 1 ) Appl Topical',
#   '21 . [s2] Docusate Sodium [e2] 100 mg Capsule Sig : One ( 1 ) Capsule PO BID ( 2 times a day ) : hold for loose stools .',
#   'Form',
#   'Drug',
#   'T352',
#   'T90',
#   '110727'),
#  (1,
#   'Reason-Drug',
#   '[s1] Schizoaffective disorder [e1] : - continued home seroquel',
#   '- restarted home benzos , trazodone and [s2] gabapentin [e2] .',
#   'Reason',
#   'Drug',
#   'T65',
#   'T69',
#   '101372'),
#  (1,
#   'Reason-Drug',
#   '[s1] Schizoaffective disorder [e1] : - continued home seroquel',
#   '- restarted home benzos , [s2] trazodone [e2] and gabapentin .',
#   'Reason',
#   'Drug',
#   'T65',
#   'T68',
#   '101372'),
#  (1,
#   'Reason-Drug',
#   '[s1] Schizoaffective disorder [e1] : - continued home seroquel',
#   '- restarted home [s2] benzos [e2] , trazodone and gabapentin .',
#   'Reason',
#   'Drug',
#   'T65',
#   'T67',
#   '101372'),
#  (1,
#   'Frequency-Drug',
#   '[s1] Q4H ( every 4 hours ) as needed [e1] for pain .',
#   '2 . [s2] oxycodone - acetaminophen [e2] 5 - 325 mg Tablet Sig : 1 - 2 Tablets PO',
#   'Frequency',
#   'Drug',
#   'T91',
#   'T85',
#   '101372'),
#  (1,
#   'Reason-Drug',
#   'Q4H ( every 4 hours ) as needed for [s1] pain [e1] .',
#   '2 . [s2] oxycodone - acetaminophen [e2] 5 - 325 mg Tablet Sig : 1 - 2 Tablets PO',
#   'Reason',
#   'Drug',
#   'T92',
#   'T85',
#   '101372'),
#  (1,
#   'Dosage-Drug',
#   'Release 24 hr Sig : [s1] Four ( 4 ) [e1] Capsule , Sust .',
#   '9 . [s2] amphetamine - dextroamphetamine [e2] 5 mg Capsule , Sust .',
#   'Dosage',
#   'Drug',
#   'T220',
#   'T217',
#   '101372'),
#  (1,
#   'Form-Drug',
#   'Release 24 hr Sig : Four ( 4 ) [s1] Capsule , Sust . Release 24 hr [e1] PO bid ( ) .',
#   '9 . [s2] amphetamine - dextroamphetamine [e2] 5 mg Capsule , Sust .',
#   'Form',
#   'Drug',
#   'T221',
#   'T217',
#   '101372'),
#  (1,
#   'Form-Drug',
#   'Disp : * 30 [s1] Tablet ( s ) [e1] * Refills : * 2 * 4 . gabapentin 300 mg Capsule Sig : One ( 1 ) Capsule PO HS ( at bedtime ) .',
#   'Disp : * 30 Tablet ( s ) * Refills : * 0 * 3 . [s2] aspirin [e2] 325 mg Tablet Sig : One ( 1 ) Tablet PO DAILY ( Daily ) .',
#   'Form',
#   'Drug',
#   'T229',
#   'T93',
#   '101372'),
#  (1,
#   'Form-Drug',
#   'Disp : * 60 [s1] Capsule , Delayed Release ( E.C. ) [e1] ( s ) * Refills : * 2 * 8 . ibuprofen 400 mg Tablet Sig : Two ( 2 ) Tablet PO Q8H ( every 8 hours ) as needed for pain .',
#   '7 . [s2] omeprazole [e2] 20 mg Capsule , Delayed Release ( E.C. ) Sig : Two ( 2 ) Capsule , Delayed Release ( E.C. ) PO DAILY ( Daily ) .',
#   'Form',
#   'Drug',
#   'T230',
#   'T202',
#   '101372'),
#  (1,
#   'Route-Drug',
#   '[s1] Subcutaneous [e1] Hospital 1 ( 2 times a day ) : Continue taking lovenox injections until INR is between 3 - 14 on coumadin as directed by your primary care physician .',
#   '9 . [s2] Enoxaparin [e2] 80 mg / 0.8 mL Syringe Sig : One ( 1 ) syringe',
#   'Route',
#   'Drug',
#   'T136',
#   'T131',
#   '106384'),
#  (1,
#   'Frequency-Drug',
#   'Subcutaneous Hospital 1 ( [s1] 2 times a day [e1] ) : Continue taking lovenox injections until INR is between 3 - 14 on coumadin as directed by your primary care physician .',
#   '9 . [s2] Enoxaparin [e2] 80 mg / 0.8 mL Syringe Sig : One ( 1 ) syringe',
#   'Frequency',
#   'Drug',
#   'T137',
#   'T131',
#   '106384'),
#  (1,
#   'ADE-Drug',
#   'The patient had worsening rash throughout his torso with [s1] lip swelling [e1] and tongue swelling .',
#   'The patient was initially continued on [s2] Tegretol [e2] .',
#   'ADE',
#   'Drug',
#   'T55',
#   'T24',
#   '110445'),
#  (1,
#   'ADE-Drug',
#   'The patient had worsening rash throughout his torso with lip swelling and [s1] tongue swelling [e1] .',
#   'The patient was initially continued on [s2] Tegretol [e2] .',
#   'ADE',
#   'Drug',
#   'T56',
#   'T24',
#   '110445'),
#  (1,
#   'ADE-Drug',
#   'The patient had worsening [s1] rash [e1] throughout his torso with lip swelling and tongue swelling .',
#   'The patient was initially continued on [s2] Tegretol [e2] .',
#   'ADE',
#   'Drug',
#   'T52',
#   'T24',
#   '110445'),
#  (1,
#   'Form-Drug',
#   '[s1] Injection [e1] Q8H ( every 8 hours ) for 6 days .',
#   '1 . [s2] ceftazidime [e2] 2 gram Recon Soln Sig : One ( 1 ) Recon Soln',
#   'Form',
#   'Drug',
#   'T58',
#   'T56',
#   '115267'),
#  (1,
#   'Duration-Drug',
#   'Injection Q8H ( every 8 hours ) [s1] for 6 days [e1] .',
#   '1 . [s2] ceftazidime [e2] 2 gram Recon Soln Sig : One ( 1 ) Recon Soln',
#   'Duration',
#   'Drug',
#   'T59',
#   'T56',
#   '115267'),
#  (1,
#   'Frequency-Drug',
#   'Injection [s1] Q8H ( every 8 hours ) [e1] for 6 days .',
#   '1 . [s2] ceftazidime [e2] 2 gram Recon Soln Sig : One ( 1 ) Recon Soln',
#   'Frequency',
#   'Drug',
#   'T60',
#   'T56',
#   '115267'),
#  (1,
#   'Reason-Drug',
#   '# ) [s1] UTI [e1] : growing MRSA and pseudomonas .',
#   'He will is on [s2] vancomycin [e2] / ceftazidime , and will complete a 14 day course .',
#   'Reason',
#   'Drug',
#   'T114',
#   'T36',
#   '115267'),
#  (1,
#   'Reason-Drug',
#   '# ) [s1] UTI [e1] : growing MRSA and pseudomonas .',
#   'He will is on vancomycin / [s2] ceftazidime [e2] , and will complete a 14 day course .',
#   'Reason',
#   'Drug',
#   'T114',
#   'T44',
#   '115267'),
#  (1,
#   'ADE-Drug',
#   'Component of [s1] redman syndrome [e1] was suspected .',
#   '# ) Rash w / vancomycin : pt did develop red rash on arms and face w / [s2] vancomycin [e2] infusion .',
#   'ADE',
#   'Drug',
#   'T119',
#   'T47',
#   '115267'),
#  (1,
#   'ADE-Drug',
#   'He was noted to be increasingly [s1] somnelent [e1] with periods of central apenea .',
#   'After initially being admitted to the floor , he developed seizures requiring 10 mg IV [s2] ativan [e2] and started on fosphenytoin with a load and transferred to the MICU .',
#   'ADE',
#   'Drug',
#   'T197',
#   'T37',
#   '115267'),
#  (1,
#   'ADE-Drug',
#   'He was noted to be increasingly somnelent with periods of [s1] central apenea [e1] .',
#   'After initially being admitted to the floor , he developed seizures requiring 10 mg IV [s2] ativan [e2] and started on fosphenytoin with a load and transferred to the MICU .',
#   'ADE',
#   'Drug',
#   'T198',
#   'T37',
#   '115267'),
#  (1,
#   'Reason-Drug',
#   'Infectious causes in setting of severe MS First Name ( Titles ) Last Name ( Titles ) 45861 [s1] seizures [e1] , most notably his UTI .',
#   'He was started on [s2] fosphenytoin [e2]',
#   'Reason',
#   'Drug',
#   'T200',
#   'T39',
#   '115267'),
#  (1,
#   'Reason-Drug',
#   '# ) UTI : growing [s1] MRSA [e1] and pseudomonas .',
#   'He will is on [s2] vancomycin [e2] / ceftazidime , and will complete a 14 day course .',
#   'Reason',
#   'Drug',
#   'T201',
#   'T36',
#   '115267'),
#  (1,
#   'Reason-Drug',
#   '# ) UTI : growing [s1] MRSA [e1] and pseudomonas .',
#   'He will is on vancomycin / [s2] ceftazidime [e2] , and will complete a 14 day course .',
#   'Reason',
#   'Drug',
#   'T201',
#   'T44',
#   '115267'),
#  (1,
#   'Reason-Drug',
#   '# ) UTI : growing MRSA and [s1] pseudomonas [e1] .',
#   'He will is on vancomycin / [s2] ceftazidime [e2] , and will complete a 14 day course .',
#   'Reason',
#   'Drug',
#   'T202',
#   'T44',
#   '115267'),
#  (1,
#   'Strength-Drug',
#   'Take [s1] 150 mg [e1] in the morning and at noon , and 200 mg at night ( 3 total doses per day ) * * START vancomycin [ antibiotic ] * * START ceftazidine [ antibiotic ] * * START benadryl , take 20 minutes before vancomycin infusion',
#   'The following changes have been made to your medications : * * START [s2] phenytoin ( dilantin ) [ anti - seizure medication ] [e2] .',
#   'Strength',
#   'Drug',
#   'T14',
#   'T90',
#   '115267'),
#  (1,
#   'Frequency-Drug',
#   'Take 150 mg [s1] in the morning and at noon [e1] , and 200 mg at night ( 3 total doses per day ) * * START vancomycin [ antibiotic ] * * START ceftazidine [ antibiotic ] * * START benadryl , take 20 minutes before vancomycin infusion',
#   'The following changes have been made to your medications : * * START [s2] phenytoin ( dilantin ) [ anti - seizure medication ] [e2] .',
#   'Frequency',
#   'Drug',
#   'T188',
#   'T90',
#   '115267'),
#  (1,
#   'Strength-Drug',
#   'Take 150 mg in the morning and at noon , and [s1] 200 mg [e1] at night ( 3 total doses per day ) * * START vancomycin [ antibiotic ] * * START ceftazidine [ antibiotic ] * * START benadryl , take 20 minutes before vancomycin infusion',
#   'The following changes have been made to your medications : * * START [s2] phenytoin ( dilantin ) [ anti - seizure medication ] [e2] .',
#   'Strength',
#   'Drug',
#   'T189',
#   'T90',
#   '115267'),
#  (1,
#   'Frequency-Drug',
#   'Take 150 mg in the morning and at noon , and 200 mg [s1] at night [e1] ( 3 total doses per day ) * * START vancomycin [ antibiotic ] * * START ceftazidine [ antibiotic ] * * START benadryl , take 20 minutes before vancomycin infusion',
#   'The following changes have been made to your medications : * * START [s2] phenytoin ( dilantin ) [ anti - seizure medication ] [e2] .',
#   'Frequency',
#   'Drug',
#   'T190',
#   'T90',
#   '115267'),
#  (1,
#   'Dosage-Drug',
#   'Take 150 mg in the morning and at noon , and 200 mg at night ( [s1] 3 [e1] total doses per day ) * * START vancomycin [ antibiotic ] * * START ceftazidine [ antibiotic ] * * START benadryl , take 20 minutes before vancomycin infusion',
#   'The following changes have been made to your medications : * * START [s2] phenytoin ( dilantin ) [ anti - seizure medication ] [e2] .',
#   'Dosage',
#   'Drug',
#   'T213',
#   'T90',
#   '115267'),
#  (1,
#   'Frequency-Drug',
#   'Take 150 mg in the morning and at noon , and 200 mg at night ( 3 total doses [s1] per day [e1] ) * * START vancomycin [ antibiotic ] * * START ceftazidine [ antibiotic ] * * START benadryl , take 20 minutes before vancomycin infusion',
#   'The following changes have been made to your medications : * * START [s2] phenytoin ( dilantin ) [ anti - seizure medication ] [e2] .',
#   'Frequency',
#   'Drug',
#   'T214',
#   'T90',
#   '115267'),
#  (1,
#   'Reason-Drug',
#   'She has had three [s1] pneumonia [e1] over the last year , never needing admission to hospital .',
#   'Treated with [s2] Solu - Medrol [e2] and antibiotics including a antifungal .',
#   'Reason',
#   'Drug',
#   'T8',
#   'T9',
#   '159079'),
#  (1,
#   'Reason-Drug',
#   'She has had three [s1] pneumonia [e1] over the last year , never needing admission to hospital .',
#   'Treated with Solu - Medrol and [s2] antibiotics [e2] including a antifungal .',
#   'Reason',
#   'Drug',
#   'T8',
#   'T10',
#   '159079'),
#  (1,
#   'Reason-Drug',
#   'She has had three [s1] pneumonia [e1] over the last year , never needing admission to hospital .',
#   'Treated with Solu - Medrol and antibiotics including a [s2] antifungal [e2] .',
#   'Reason',
#   'Drug',
#   'T8',
#   'T11',
#   '159079'),
#  (1,
#   'Reason-Drug',
#   '# [s1] Gastroesophageal reflux [e1] - stable',
#   '- continued on home [s2] omeprazole [e2]',
#   'Reason',
#   'Drug',
#   'T23',
#   'T24',
#   '159079'),
#  (1,
#   'Route-Drug',
#   '[s1] Inhalation [e1] daily',
#   '12 . [s2] Symbicort * NF * ( budesonide - formoterol ) [e2] 160 - 4.5 mcg / actuation',
#   'Route',
#   'Drug',
#   'T146',
#   'T144',
#   '159079'),
#  (1,
#   'Frequency-Drug',
#   'Inhalation [s1] daily [e1]',
#   '12 . [s2] Symbicort * NF * ( budesonide - formoterol ) [e2] 160 - 4.5 mcg / actuation',
#   'Frequency',
#   'Drug',
#   'T147',
#   'T144',
#   '159079'),
#  (1,
#   'Dosage-Drug',
#   '[s1] Tapered dose - DOWN [e1] RX * prednisone 10 mg as directed tablet ( s ) by mouth daily Disp # * 26 Tablet Refills : * 0',
#   '13 . [s2] PredniSONE [e2] 60 mg PO DAILY Duration : 2 Days',
#   'Dosage',
#   'Drug',
#   'T153',
#   'T148',
#   '159079'),
#  (1,
#   'Dosage-Drug',
#   '[s1] Tapered dose - DOWN [e1] RX * prednisone 20 mg 2 tablet ( s ) by mouth once daily Disp # * 4',
#   '14 . [s2] PredniSONE [e2] 40 mg PO DAILY Duration : 2 Days',
#   'Dosage',
#   'Drug',
#   'T164',
#   'T159',
#   '159079'),
#  (1,
#   'Dosage-Drug',
#   '[s1] Tapered dose - DOWN [e1] RX * prednisone 20 mg 1 tablet ( s ) by mouth daily Disp # * 2 Tablet',
#   '15 . [s2] PredniSONE [e2] 20 mg PO DAILY Duration : 2 Days',
#   'Dosage',
#   'Drug',
#   'T176',
#   'T171',
#   '159079'),
#  (1,
#   'Dosage-Drug',
#   '[s1] Tapered dose - DOWN [e1] RX * prednisone 10 mg 1 tablet ( s ) by mouth daily Disp # * 2 Tablet',
#   '16 . [s2] PredniSONE [e2] 10 mg PO DAILY Duration : 2 Days',
#   'Dosage',
#   'Drug',
#   'T188',
#   'T183',
#   '159079'),
#  (1,
#   'Dosage-Drug',
#   'Sig : [s1] One ( 1 ) [e1] Tablet , Chewable PO QID ( 4 times a day ) as needed for Heart burn .',
#   '4 . [s2] calcium carbonate [e2] 200 mg calcium ( 500 mg ) Tablet , Chewable',
#   'Dosage',
#   'Drug',
#   'T49',
#   'T44',
#   '103377'),
#  (1,
#   'Form-Drug',
#   'Sig : One ( 1 ) [s1] Tablet , Chewable [e1] PO QID ( 4 times a day ) as needed for Heart burn .',
#   '4 . [s2] calcium carbonate [e2] 200 mg calcium ( 500 mg ) Tablet , Chewable',
#   'Form',
#   'Drug',
#   'T50',
#   'T44',
#   '103377'),
#  (1,
#   'Route-Drug',
#   'Sig : One ( 1 ) Tablet , Chewable [s1] PO [e1] QID ( 4 times a day ) as needed for Heart burn .',
#   '4 . [s2] calcium carbonate [e2] 200 mg calcium ( 500 mg ) Tablet , Chewable',
#   'Route',
#   'Drug',
#   'T51',
#   'T44',
#   '103377'),
#  (1,
#   'Frequency-Drug',
#   'Sig : One ( 1 ) Tablet , Chewable PO [s1] QID ( 4 times a day ) as needed [e1] for Heart burn .',
#   '4 . [s2] calcium carbonate [e2] 200 mg calcium ( 500 mg ) Tablet , Chewable',
#   'Frequency',
#   'Drug',
#   'T52',
#   'T44',
#   '103377'),
#  (1,
#   'Reason-Drug',
#   'Sig : One ( 1 ) Tablet , Chewable PO QID ( 4 times a day ) as needed for [s1] Heart burn [e1] .',
#   '4 . [s2] calcium carbonate [e2] 200 mg calcium ( 500 mg ) Tablet , Chewable',
#   'Reason',
#   'Drug',
#   'T53',
#   'T44',
#   '103377'),
#  (1,
#   'Form-Drug',
#   '6 . senna 8.6 mg Tablet Sig : One ( 1 ) [s1] Tablet [e1] PO BID ( 2 times a day ) .',
#   '5 . [s2] levetiracetam [e2] 250 mg Tablet Sig : Three ( 3 ) Tablet PO BID ( 2 times a day ) .',
#   'Form',
#   'Drug',
#   'T65',
#   'T54',
#   '103377'),
#  (1,
#   'Route-Drug',
#   '6 . senna 8.6 mg Tablet Sig : One ( 1 ) Tablet [s1] PO [e1] BID ( 2 times a day ) .',
#   '5 . [s2] levetiracetam [e2] 250 mg Tablet Sig : Three ( 3 ) Tablet PO BID ( 2 times a day ) .',
#   'Route',
#   'Drug',
#   'T66',
#   'T54',
#   '103377'),
#  (1,
#   'Reason-Drug',
#   'Tumor cells stained positive for TTF - 1 , cytokeratin 7 , synaptophysin , were focally positive for chromogranin and negative for CK 20 and LCA , consistent with a [s1] carcinoma of lung [e1] origin .',
#   '- Date range ( 3 ) 100411 concurrent XRT and [s2] cisplatin [e2] / etoposide',
#   'Reason',
#   'Drug',
#   'T123',
#   'T124',
#   '103377'),
#  (1,
#   'Reason-Drug',
#   'Tumor cells stained positive for TTF - 1 , cytokeratin 7 , synaptophysin , were focally positive for chromogranin and negative for CK 20 and LCA , consistent with a [s1] carcinoma of lung [e1] origin .',
#   '- Date range ( 3 ) 100411 concurrent XRT and cisplatin / [s2] etoposide [e2]',
#   'Reason',
#   'Drug',
#   'T123',
#   'T125',
#   '103377'),
#  (1,
#   'Reason-Drug',
#   'She became fluid overloaded and [s1] diuresis [e1] was attempted .',
#   'She did not respond well to [s2] Lasix [e2] and continued to retain fluid .',
#   'Reason',
#   'Drug',
#   'T10',
#   'T11',
#   '120237'),
#  (1,
#   'Strength-Drug',
#   '[s1] 3 mg [e1] initial dose , given risk for stroke in patient with A - fibb .',
#   '[s2] Coumadin [e2] restarted 11 - 10 as per instruction with Dr. First Name ( STitle ) , and Dr. Last Name ( STitle ) .',
#   'Strength',
#   'Drug',
#   'T78',
#   'T21',
#   '192877'),
#  (1,
#   'Frequency-Drug',
#   '[s1] Q6 [e1] for abscess stopped after IV then PO course for 10 days .',
#   '[s2] Clindamycin [e2] 450 PO',
#   'Frequency',
#   'Drug',
#   'T80',
#   'T29',
#   '192877'),
#  (1,
#   'Reason-Drug',
#   'Q6 for [s1] abscess [e1] stopped after IV then PO course for 10 days .',
#   '[s2] Clindamycin [e2] 450 PO',
#   'Reason',
#   'Drug',
#   'T81',
#   'T29',
#   '192877'),
#  (1,
#   'Route-Drug',
#   'Q6 for abscess stopped after IV then [s1] PO [e1] course for 10 days .',
#   '[s2] Clindamycin [e2] 450 PO',
#   'Route',
#   'Drug',
#   'T83',
#   'T29',
#   '192877'),
#  (1,
#   'Duration-Drug',
#   'Q6 for abscess stopped after IV then PO course for [s1] 10 days [e1] .',
#   '[s2] Clindamycin [e2] 450 PO',
#   'Duration',
#   'Drug',
#   'T84',
#   'T29',
#   '192877'),
#  (1,
#   'Frequency-Drug',
#   '[s1] DAILY ( Daily ) [e1] .',
#   '1 . [s2] Ferrous Sulfate [e2] 325 ( 65 ) mg Tablet Sig : One ( 1 ) Tablet PO',
#   'Frequency',
#   'Drug',
#   'T102',
#   'T26',
#   '192877'),
#  (1,
#   'Reason-Drug',
#   '# Hypotension : likely secondary to [s1] hypovolemia [e1] .',
#   '[s2] Fluids [e2] given on admission .',
#   'Reason',
#   'Drug',
#   'T150',
#   'T149',
#   '192877'),
#  (1,
#   'Reason-Drug',
#   'Major Surgical or Invasive Procedure : None History of Present Illness : 79 yo woman with history of [s1] a - fib [e1] , CHF s / p bioprosthetic mitral and s / p tricuspid valve annuloplasty , who initially was admitted to 11 - 4 after she presented to ED with persistent bleeding following L tooth extractions and posterior superior palate I and D .',
#   'Patient initially had INR elevated to 2.1 secondary to [s2] warfarin [e2] use for atrial fibrillation .',
#   'Reason',
#   'Drug',
#   'T131',
#   'T44',
#   '192877'),
#  (1,
#   'Reason-Drug',
#   '3 mg initial dose , given risk for [s1] stroke in patient with A - fibb [e1] .',
#   '[s2] Coumadin [e2] restarted 11 - 10 as per instruction with Dr. First Name ( STitle ) , and Dr. Last Name ( STitle ) .',
#   'Reason',
#   'Drug',
#   'T138',
#   'T21',
#   '192877'),
#  (1,
#   'Reason-Drug',
#   '- Patient will continue to follow with Dr. Last Name ( STitle ) 410 in clinic # [s1] Sepsis / Febrile neutropenia [e1] : Pt had low grade fevers on 6 - 30 , and fever to 101.7 @ 430 7 - 1 , afebrile at the time of transfer 7 - 2 .',
#   'Pt on broad spectrum abx coverage with Last Name ( un ) 2830 / [s2] vanco [e2] .',
#   'Reason',
#   'Drug',
#   'T122',
#   'T121',
#   '113824'),
#  (1,
#   'Reason-Drug',
#   'She was found to have [s1] 3 abscessed teeth [e1] which were removed on 6 - 5 .',
#   'She was begun on [s2] clindamycin [e2] 300 mg QID on 6 - 2 she took until 6 - 12 .',
#   'Reason',
#   'Drug',
#   'T119',
#   'T65',
#   '113824'),
#  (1,
#   'Reason-Drug',
#   'Before being transferred to the ICU for the second time during this admission , she also developed [s1] hypotension [e1] with SBP in 80 s after receving ambisome .',
#   'She responded to [s2] fluid [e2] boluses and did not require pressor support .',
#   'ADE',
#   'Drug',
#   'T128',
#   'T106',
#   '113824'),
#  (1,
#   'Reason-Drug',
#   'Name 10 ( Name Is ) were found to have [s1] acute myelogenous leukemia [e1] so you underwent induction chemotherapy with ( 7 + 3 ) Doctor First Name + cytarabine .',
#   'You tolerated the [s2] chemotherapy [e2] well and your blood counts dropped as expected .',
#   'Reason',
#   'Drug',
#   'T126',
#   'T98',
#   '113824'),
#  (1,
#   'Reason-Drug',
#   "1 . [s1] Non - Hodgkin ' s T cell lymphoma [e1] , diagnosed in 1 - / 2113 , s / p",
#   '[s2] Rituximab [e2] with disease progression , s / p CHOP with evidence of progression after 3 rd cycle , s / p Pentostatin , Rituxan c / b TTP , s / p mini - allo - MUD BMT in 12 / 2114 complicated by grade 1 skin',
#   'Reason',
#   'Drug',
#   'T80',
#   'T34',
#   '109667'),
#  (1,
#   'Form-Drug',
#   '[s1] Tablet , Delayed Release ( E.C. ) [e1] ( s ) 4 . Citalopram 20 mg Tablet Sig : Two ( 2 ) Tablet PO DAILY ( Daily ) .',
#   '3 . [s2] Pantoprazole [e2] 40 mg Tablet , Delayed Release ( E.C. ) Sig : One ( 1 ) Tablet , Delayed Release ( E.C. ) PO Q24H ( every 24 hours ) .',
#   'Form',
#   'Drug',
#   'T105',
#   'T46',
#   '109667'),
#  (1,
#   'Reason-Drug',
#   'Rituximab with disease progression , s / p CHOP with evidence of progression after 3 rd cycle , s / p Pentostatin , Rituxan c / b TTP , s / p mini - allo - MUD BMT in 12 / 2114 complicated by [s1] grade 1 skin GVHD [e1] , off CSA since 6 - / 2115 , Prednisone since 2 - / 2116 , Cellcept 06 / 2115 .',
#   'GVHD , off [s2] CSA [e2] since 6 - / 2115 , Prednisone since 2 - / 2116 , Cellcept 06 / 2115 .',
#   'Reason',
#   'Drug',
#   'T126',
#   'T125',
#   '109667'),
#  (1,
#   'Form-Drug',
#   'Disp : * 12 [s1] Capsule ( s ) [e1] * Refills : * 0 * 7 . Diphenhydramine HCl 25 mg Tablet Sig : One ( 1 ) Tablet PO every six ( 6 ) hours for 3 days .',
#   '6 . [s2] Zantac [e2] 150 mg Capsule Sig : One ( 1 ) Capsule PO every six ( 6 ) hours for 3 days .',
#   'Form',
#   'Drug',
#   'T130',
#   'T4',
#   '109667'),
#  (1,
#   'Form-Drug',
#   'Disp : * 12 [s1] Tablet ( s ) [e1] * Refills : * 0 * Discharge Disposition : Home',
#   'Disp : * 12 Capsule ( s ) * Refills : * 0 * 7 . [s2] Diphenhydramine HCl [e2] 25 mg Tablet Sig : One ( 1 ) Tablet PO every six ( 6 ) hours for 3 days .',
#   'Form',
#   'Drug',
#   'T131',
#   'T5',
#   '109667'),
#  (1,
#   'Reason-Drug',
#   '- [s1] a . fib [e1] ( on Coumadin ) - pacemaker / defibrillator ( he reports for slow heart rate ) - CAD s / p 2 stents',
#   'fib ( on [s2] Coumadin [e2] ) - pacemaker / defibrillator ( he reports for slow heart rate ) - CAD s / p 2 stents',
#   'Reason',
#   'Drug',
#   'T100',
#   'T81',
#   '114144'),
#  (1,
#   'ADE-Drug',
#   'You had a CT scan and were found to have a [s1] bleed in your brain [e1] in the area of the left basal ganglia .',
#   'As you were on [s2] warfarin ( Coumadin ) [e2] which is a blood thinner and worsens bleeding , this was reversed with medications and Coumadin was stopped .',
#   'ADE',
#   'Drug',
#   'T177',
#   'T84',
#   '114144'),
#  (1,
#   'ADE-Drug',
#   'Additionally , on 1 - 18 pt [s1] developed papular rash over posterior thighs and peri - rectal area [e1] and was started on acyclovir .',
#   'ID : Pt was initially started on nafcillin / gentamicin ; initial Cx were positive for MSSA and pt was maintained on nafcillin until 1 - 13 , when she developed a drug rash and was changed to [s2] vancomycin [e2] .',
#   'ADE',
#   'Drug',
#   'T179',
#   'T133',
#   '125206'),
#  (1,
#   'Reason-Drug',
#   '# PSYCH : Pt with h / o [s1] anxiety [e1] and depression , presently somewhat anxious , especially during movement , transition to sitting .',
#   '[s2] Ativan [e2] was continuedprn .',
#   'Reason',
#   'Drug',
#   'T206',
#   'T156',
#   '125206'),
#  (1,
#   'Reason-Drug',
#   '# PSYCH : Pt with h / o anxiety and [s1] depression [e1] , presently somewhat anxious , especially during movement , transition to sitting .',
#   '[s2] Ativan [e2] was continuedprn .',
#   'Reason',
#   'Drug',
#   'T207',
#   'T156',
#   '125206'),
#  (1,
#   'Frequency-Drug',
#   '[s1] DAILY ( Daily ) as needed [e1] .',
#   '7 . [s2] Camphor - Menthol [e2] 0.5 - 0.5 % Lotion Last Name ( STitle ) : One ( 1 ) Appl Topical',
#   'Frequency',
#   'Drug',
#   'T253',
#   'T90',
#   '125206'),
#  (1,
#   'Frequency-Drug',
#   '[s1] Q72H ( every 72 hours ) [e1] .',
#   '10 . [s2] Fentanyl [e2] 100 mcg / hr Patch 72 HR Hospital 1 : One ( 1 ) Transdermal',
#   'Frequency',
#   'Drug',
#   'T263',
#   'T3',
#   '125206'),
#  (1,
#   'Frequency-Drug',
#   '[s1] Q12H ( every 12 hours ) [e1] .',
#   '11 . [s2] Enoxaparin [e2] 30 mg / 0.3 mL Syringe Hospital 1 : One ( 1 ) Subcutaneous',
#   'Frequency',
#   'Drug',
#   'T267',
#   'T68',
#   '125206'),
#  (1,
#   'Route-Drug',
#   '[s1] Rectal [e1] Q6H ( every 6 hours ) as needed for T > 101.4 .',
#   '16 . [s2] Acetaminophen [e2] 650 mg Suppository Hospital 1 : One ( 1 ) Suppository',
#   'Route',
#   'Drug',
#   'T287',
#   'T78',
#   '125206'),
#  (1,
#   'Frequency-Drug',
#   'Rectal [s1] Q6H ( every 6 hours ) as needed [e1] for T > 101.4 .',
#   '16 . [s2] Acetaminophen [e2] 650 mg Suppository Hospital 1 : One ( 1 ) Suppository',
#   'Frequency',
#   'Drug',
#   'T288',
#   'T78',
#   '125206'),
#  (1,
#   'Reason-Drug',
#   'Rectal Q6H ( every 6 hours ) as needed for [s1] T > 101.4 [e1] .',
#   '16 . [s2] Acetaminophen [e2] 650 mg Suppository Hospital 1 : One ( 1 ) Suppository',
#   'Reason',
#   'Drug',
#   'T289',
#   'T78',
#   '125206'),
#  (1,
#   'Frequency-Drug',
#   '[s1] TID ( 3 times a day ) [e1] .',
#   '17 . [s2] Metoprolol Tartrate [e2] 25 mg Tablet Hospital 1 : Three ( 3 ) Tablet PO',
#   'Frequency',
#   'Drug',
#   'T292',
#   'T26',
#   '125206'),
#  (1,
#   'Route-Drug',
#   '[s1] PO [e1] Q4 - 6 H ( every 4 to 6 hours ) as needed .',
#   '19 . [s2] Oxycodone - Acetaminophen [e2] 5 - 325 mg Tablet Hospital 1 : One ( 1 ) Tablet',
#   'Route',
#   'Drug',
#   'T299',
#   'T123',
#   '125206'),
#  (1,
#   'Frequency-Drug',
#   'PO [s1] Q4 - 6 H ( every 4 to 6 hours ) as needed [e1] .',
#   '19 . [s2] Oxycodone - Acetaminophen [e2] 5 - 325 mg Tablet Hospital 1 : One ( 1 ) Tablet',
#   'Frequency',
#   'Drug',
#   'T300',
#   'T123',
#   '125206'),
#  (1,
#   'Reason-Drug',
#   'Retropharyngeal abcesses were drained , and she had bilateral knee arthrocentesis and washout for [s1] septic joints [e1] .',
#   'Pt was treated with [s2] vancomycin [e2] after nafcillin resulted in rash ( pt seen by derm , termed " drug hypersensitivity " ) .',
#   'Reason',
#   'Drug',
#   'T355',
#   'T111',
#   '125206'),
#  (1,
#   'Reason-Drug',
#   'In addition , on 1 - 3 pt noted to have SVT , with rate up to the 160 s , and [s1] SBP decrease [e1] .',
#   'She was cardioverted x2 and started on [s2] amiodarone [e2] , which has since been discontinued .',
#   'Reason',
#   'Drug',
#   'T339',
#   'T82',
#   '125206'),
#  (1,
#   'Reason-Drug',
#   'In addition , on 1 - 3 pt noted to have [s1] SVT , with rate up to the 160 s [e1] , and SBP decrease .',
#   'She was cardioverted x2 and started on [s2] amiodarone [e2] , which has since been discontinued .',
#   'Reason',
#   'Drug',
#   'T338',
#   'T82',
#   '125206'),
#  (1,
#   'Reason-Drug',
#   'pt seen by endocrine service who recommend minimum dose of prednisone 10 mg po qdaily give almost certain component of [s1] adrenal insufficiency [e1] .',
#   'home regimen of [s2] prednisone [e2] 15 mg qdaily ( home regimen for RA ) was continued .',
#   'Reason',
#   'Drug',
#   'T348',
#   'T23',
#   '125206'),
#  (1,
#   'Reason-Drug',
#   '# [s1] PPx [e1] : Pt was given lovenox and IVC filter for DVT prophylaxis .',
#   '[s2] PPI [e2] given steroid regimen .',
#   'Reason',
#   'Drug',
#   'T368',
#   'T208',
#   '125206'),
#  (1,
#   'Route-Drug',
#   '[s1] Peripheral IV [e1] - Inspect site every shift',
#   '26 . [s2] Sodium Chloride [e2] 0.9 % Flush 3 ml IV DAILY : PRN',
#   'Route',
#   'Drug',
#   'T377',
#   'T226',
#   '125206'),
#  (1,
#   'Reason-Drug',
#   '? ? ? ? ? ? Increase your intake of fluids and fiber , as narcotic pain medicine can cause [s1] constipation [e1] .',
#   'We generally recommend taking an over the counter stool softener , such as [s2] Docusate ( Colace ) [e2] while taking narcotic pain medication .',
#   'ADE',
#   'Drug',
#   'T39',
#   'T34',
#   '114965'),
#  (1,
#   'Duration-Drug',
#   'Intravenous Q12H ( every 12 hours ) [s1] for 7 days [e1] .',
#   '16 . [s2] Meropenem [e2] 500 mg Recon Soln Sig : One ( 1 ) Recon Soln',
#   'Duration',
#   'Drug',
#   'T31',
#   'T60',
#   '114959'),
#  (1,
#   'Frequency-Drug',
#   'Intravenous [s1] Q12H ( every 12 hours ) [e1] for 7 days .',
#   '16 . [s2] Meropenem [e2] 500 mg Recon Soln Sig : One ( 1 ) Recon Soln',
#   'Frequency',
#   'Drug',
#   'T32',
#   'T60',
#   '114959'),
#  (1,
#   'Route-Drug',
#   '[s1] Intravenous [e1] Q12H ( every 12 hours ) for 7 days .',
#   '16 . [s2] Meropenem [e2] 500 mg Recon Soln Sig : One ( 1 ) Recon Soln',
#   'Route',
#   'Drug',
#   'T33',
#   'T60',
#   '114959'),
#  (1,
#   'Route-Drug',
#   '[s1] PO [e1] DAILY ( Daily ) .',
#   '5 . [s2] Aspirin [e2] 81 mg Tablet , Chewable Sig : One ( 1 ) Tablet , Chewable',
#   'Route',
#   'Drug',
#   'T155',
#   'T5',
#   '114959'),
#  (1,
#   'Frequency-Drug',
#   'PO [s1] DAILY ( Daily ) [e1] .',
#   '5 . [s2] Aspirin [e2] 81 mg Tablet , Chewable Sig : One ( 1 ) Tablet , Chewable',
#   'Frequency',
#   'Drug',
#   'T156',
#   'T5',
#   '114959'),
#  (1,
#   'Frequency-Drug',
#   '[s1] Q4 - 6 H ( every 4 to 6 hours ) [e1] .',
#   '6 . [s2] Ipratropium Bromide [e2] 0.02 % Solution Sig : One ( 1 ) Inhalation',
#   'Frequency',
#   'Drug',
#   'T162',
#   'T157',
#   '114959'),
#  (1,
#   'Frequency-Drug',
#   '[s1] Q4 - 6 H ( every 4 to 6 hours ) [e1] .',
#   '7 . [s2] Albuterol Sulfate [e2] 0.083 % Solution Sig : One ( 1 ) Inhalation',
#   'Frequency',
#   'Drug',
#   'T168',
#   'T163',
#   '114959'),
#  (1,
#   'Frequency-Drug',
#   '[s1] DAILY ( Daily ) [e1] .',
#   '9 . [s2] Zinc Sulfate [e2] 220 ( 50 ) mg Capsule Sig : One ( 1 ) Capsule PO',
#   'Frequency',
#   'Drug',
#   'T178',
#   'T66',
#   '114959'),
#  (1,
#   'Route-Drug',
#   'Small amount of fecal oozing [s1] anal area [e1] , this is normal with this system .',
#   'Nursing applying [s2] double guard [e2] onitment , and nystatin to site Hospital 1 .',
#   'Route',
#   'Drug',
#   'T224',
#   'T222',
#   '114959'),
#  (1,
#   'Reason-Drug',
#   'Please continue to monitor and treat her [s1] hypothyroidism [e1] .',
#   'Her [s2] Levothyroxine [e2] was increased as the TSH increased .',
#   'Reason',
#   'Drug',
#   'T227',
#   'T226',
#   '114959'),
#  (1,
#   'Reason-Drug',
#   'WBC 14.8 HCT 31.2 10 - 29 : small maroon stool 10 - 30 : dark melena ; go - lytely for c - s in am 10 - 31 : [s1] BRBPR [e1] , SBPs 70 s , HCT 23',
#   'Got 2 U [s2] pRBCs [e2] 2185 - 10 - 31 TO OR : En bloc resection of a portion of sigmoid with a right hemicolectomy for a bleeding cecal mass with adherent sigmoid colon',
#   'Reason',
#   'Drug',
#   'T230',
#   'T232',
#   '114959'),
#  (1,
#   'Frequency-Drug',
#   '[s1] DAILY ( Daily ) [e1] .',
#   '11 . [s2] Therapeutic Multivitamin [e2] Liquid Sig : Five ( 5 ) ML PO',
#   'Frequency',
#   'Drug',
#   'T186',
#   'T77',
#   '114959'),
#  (1,
#   'Reason-Drug',
#   'She did have some periods of [s1] severe agitation [e1] and hallucinating on the first night postoperatively .',
#   'She was medicated with Haldol and [s2] Ativan . [e2]',
#   'Reason',
#   'Drug',
#   'T47',
#   'T24',
#   '134445'),
#  (1,
#   'Reason-Drug',
#   'She did have some periods of [s1] severe agitation [e1] and hallucinating on the first night postoperatively .',
#   'She was medicated with [s2] Haldol [e2] and Ativan .',
#   'Reason',
#   'Drug',
#   'T47',
#   'T48',
#   '134445'),
#  (1,
#   'Frequency-Drug',
#   'IV [s1] t . i . d . and p.r.n. [e1] for agitation .',
#   'They suggested holding Wellbutrin and Ativan and minimizing narcotic use and starting [s2] Haldol [e2] 2 mg',
#   'Frequency',
#   'Drug',
#   'T50',
#   'T8',
#   '134445'),
#  (1,
#   'Reason-Drug',
#   'IV t . i . d . and p.r.n. for [s1] agitation [e1] .',
#   'They suggested holding Wellbutrin and Ativan and minimizing narcotic use and starting [s2] Haldol [e2] 2 mg',
#   'Reason',
#   'Drug',
#   'T40',
#   'T8',
#   '134445'),
#  (1,
#   'Reason-Drug',
#   'Psychiatry assessment found the patient [s1] delirious [e1] and given the acute onset following craniotomy as well as disorientation , psychotic beliefs about Satan , there are obviously concerns .',
#   'They suggested holding Wellbutrin and Ativan and minimizing [s2] narcotic [e2] use and starting Haldol 2 mg',
#   'ADE',
#   'Drug',
#   'T60',
#   'T58',
#   '134445'),
#  (1,
#   'Frequency-Drug',
#   'She will be weaned down to 2 mg p.o. [s1] b.i.d. [e1] over the course of a weeks time and follow - up in the Brain Hospital 341 Clinic on 2186 - 8 - 14 .',
#   'She has been weaned down on her [s2] steroid [e2] medication .',
#   'Frequency',
#   'Drug',
#   'T64',
#   'T61',
#   '134445'),
#  (1,
#   'Route-Drug',
#   'She will be weaned down to 2 mg [s1] p.o. [e1] b.i.d. over the course of a weeks time and follow - up in the Brain Hospital 341 Clinic on 2186 - 8 - 14 .',
#   'She has been weaned down on her [s2] steroid [e2] medication .',
#   'Route',
#   'Drug',
#   'T63',
#   'T61',
#   '134445'),
#  (1,
#   'Strength-Drug',
#   'She will be weaned down to [s1] 2 mg [e1] p.o. b.i.d. over the course of a weeks time and follow - up in the Brain Hospital 341 Clinic on 2186 - 8 - 14 .',
#   'She has been weaned down on her [s2] steroid [e2] medication .',
#   'Strength',
#   'Drug',
#   'T62',
#   'T61',
#   '134445'),
#  (1,
#   'ADE-Drug',
#   '# [s1] Angioedema [e1] : C / w angioedema .',
#   'Most commonly associated with [s2] ACE - I [e2] .',
#   'ADE',
#   'Drug',
#   'T15',
#   'T16',
#   '107058'),
#  (1,
#   'Reason-Drug',
#   '# [s1] ESRD [e1] : In work - up for PD and transplant .',
#   'Sevelamer and [s2] calcitriol [e2] continued .',
#   'Reason',
#   'Drug',
#   'T27',
#   'T29',
#   '107058'),
#  (1,
#   'Reason-Drug',
#   '# [s1] ESRD [e1] : In work - up for PD and transplant .',
#   '[s2] Sevelamer [e2] and calcitriol continued .',
#   'Reason',
#   'Drug',
#   'T27',
#   'T28',
#   '107058'),
#  (1,
#   'Route-Drug',
#   'Sustained Release [s1] PO [e1] DAILY ( Daily ) .',
#   '3 . [s2] Nifedipine [e2] 90 mg Tablet Sustained Release Sig : One ( 1 ) Tablet',
#   'Route',
#   'Drug',
#   'T86',
#   'T81',
#   '107058'),
#  (1,
#   'Frequency-Drug',
#   'Sustained Release PO [s1] DAILY ( Daily ) [e1] .',
#   '3 . [s2] Nifedipine [e2] 90 mg Tablet Sustained Release Sig : One ( 1 ) Tablet',
#   'Frequency',
#   'Drug',
#   'T87',
#   'T81',
#   '107058'),
#  (1,
#   'Route-Drug',
#   '[s1] Subcutaneous [e1] once a day .',
#   '4 . [s2] Insulin Glargine [e2] 100 unit / mL Solution Sig : Eight ( 8 ) units',
#   'Route',
#   'Drug',
#   'T92',
#   'T88',
#   '107058'),
#  (1,
#   'Frequency-Drug',
#   'Subcutaneous [s1] once a day [e1] .',
#   '4 . [s2] Insulin Glargine [e2] 100 unit / mL Solution Sig : Eight ( 8 ) units',
#   'Frequency',
#   'Drug',
#   'T93',
#   'T88',
#   '107058'),
#  (1,
#   'ADE-Drug',
#   'Discharge Instructions : You were admitted to the hospital with a reaction called [s1] angioedema [e1] .',
#   'We think that this was due to your [s2] Lisinopril [e2] dosing .',
#   'ADE',
#   'Drug',
#   'T115',
#   'T116',
#   '107058'),
#  (1,
#   'Reason-Drug',
#   '# [s1] DM [e1] : He reports episodes of hypoglycemia at home in the 50 s and Lantus was recently lowered .',
#   'His [s2] Glyburide [e2] was stopped on admission due to his end stage renal disease .',
#   'Reason',
#   'Drug',
#   'T24',
#   'T26',
#   '107058'),
#  (1,
#   'Reason-Drug',
#   'Brief Hospital Course : NEURO : [s1] SEIZURES [e1] : On initial EEG , he was thought to be in complex partial status , and was given a trial of ativan with electrographic and clinical improvement .',
#   'He was increased on his [s2] Keppra [e2] from 500 mg Hospital 1 to 1500 mg Hospital 1 .',
#   'Reason',
#   'Drug',
#   'T3',
#   'T5',
#   '176448'),
#  (1,
#   'Reason-Drug',
#   'On 5 - 29 , He was loaded on phosphenytoin and started on maintenance dosing with improvement in [s1] seizure [e1] frequency .',
#   'On 6 - 1 , he was loaded on [s2] vimpat [e2] 200 mg IV , and started on maintenance of 100 mg',
#   'Reason',
#   'Drug',
#   'T8',
#   'T9',
#   '176448'),
#  (1,
#   'Reason-Drug',
#   '1 . [s1] HSV ENCEPHALITIS [e1] - ID was consulted on admission .',
#   'Patient has completed 2 21 day courses of [s2] acyclovir [e2] .',
#   'Reason',
#   'Drug',
#   'T41',
#   'T44',
#   '176448'),
#  (1,
#   'Reason-Drug',
#   '2 . [s1] FEVER OF UNKNOWN ORIGIN [e1] - Patient developed fever to 102 daily .',
#   'He was initially treated with empiric course of [s2] vanco [e2] / zosyn but fevers persisted with no clear source and all cultures negative .',
#   'Reason',
#   'Drug',
#   'T48',
#   'T49',
#   '176448'),
#  (1,
#   'Reason-Drug',
#   '2 . [s1] FEVER OF UNKNOWN ORIGIN [e1] - Patient developed fever to 102 daily .',
#   'He was initially treated with empiric course of vanco / [s2] zosyn [e2] but fevers persisted with no clear source and all cultures negative .',
#   'Reason',
#   'Drug',
#   'T48',
#   'T50',
#   '176448'),
#  (1,
#   'ADE-Drug',
#   'He did also develop a mild [s1] maculopapular rash [e1] and elevated eosinophil count , which point toward drug fever .',
#   'His [s2] seizure medications [e2] were likely culprit , but could not be stopped due to nonconvulsive status .',
#   'ADE',
#   'Drug',
#   'T51',
#   'T54',
#   '176448'),
#  (1,
#   'ADE-Drug',
#   'He did also develop a mild maculopapular rash and [s1] elevated eosinophil count [e1] , which point toward drug fever .',
#   'His [s2] seizure medications [e2] were likely culprit , but could not be stopped due to nonconvulsive status .',
#   'ADE',
#   'Drug',
#   'T52',
#   'T54',
#   '176448'),
#  (1,
#   'ADE-Drug',
#   'He did also develop a mild maculopapular rash and elevated eosinophil count , which point toward [s1] drug fever [e1] .',
#   'His [s2] seizure medications [e2] were likely culprit , but could not be stopped due to nonconvulsive status .',
#   'ADE',
#   'Drug',
#   'T53',
#   'T54',
#   '176448'),
#  (1,
#   'Reason-Drug',
#   '4 . [s1] UTI [e1]',
#   'Urine culture from 7 - 9 grew > 100 , 000 E coli , treated with [s2] ceftriaxone [e2] .',
#   'Reason',
#   'Drug',
#   'T55',
#   'T56',
#   '176448'),
#  (1,
#   'Reason-Drug',
#   '5 . [s1] PNA [e1]',
#   'Sputum culture from 7 - 9 grew Klebsiella , treated with [s2] ceftriaxone [e2] .',
#   'Reason',
#   'Drug',
#   'T57',
#   'T58',
#   '176448'),
#  (1,
#   'ADE-Drug',
#   'GI : [s1] TRANAMINITIS [e1] - Patient had normal LFTs on admission but developed elevation in AST / ALT to 300 - 400 with no elevated bilirubin but with elevated ammonia .',
#   'This was likely a medication side effect , and improved with stopping [s2] Depakote [e2] .',
#   'ADE',
#   'Drug',
#   'T59',
#   'T62',
#   '176448'),
#  (1,
#   'ADE-Drug',
#   'GI : TRANAMINITIS - Patient had normal LFTs on admission but developed [s1] elevation in AST / ALT [e1] to 300 - 400 with no elevated bilirubin but with elevated ammonia .',
#   'This was likely a medication side effect , and improved with stopping [s2] Depakote [e2] .',
#   'ADE',
#   'Drug',
#   'T60',
#   'T62',
#   '176448'),
#  (1,
#   'ADE-Drug',
#   'GI : TRANAMINITIS - Patient had normal LFTs on admission but developed elevation in AST / ALT to 300 - 400 with no elevated bilirubin but with [s1] elevated ammonia [e1] .',
#   'This was likely a medication side effect , and improved with stopping [s2] Depakote [e2] .',
#   'ADE',
#   'Drug',
#   'T61',
#   'T62',
#   '176448'),
#  (1,
#   'Reason-Drug',
#   'He presented after he was in an accident while driving from RI to VT , rented a second car , and was in a second accident , at which point he was brought to an outside hospital and eventually diagnosed with [s1] HSV meningitis [e1] .',
#   'He was started on a course of IV [s2] acyclovir [e2] , and discharged to Hospital 38 rehab .',
#   'Reason',
#   'Drug',
#   'T110',
#   'T112',
#   '176448'),
#  (1,
#   'Strength-Drug',
#   'He calmed down after administration of [s1] 2 mg [e1] IV',
#   '[s2] Ativan [e2] .',
#   'Strength',
#   'Drug',
#   'T7',
#   'T9',
#   '102136'),
#  (1,
#   'Route-Drug',
#   '[s1] PO [e1] qhs , Vistaril 50 mg Po TID , Inderal 20 mg PO BID , Lexapro 20 mg',
#   'You will not be discharged with any of your psychiatric medicines , so please do not take your [s2] Topamax [e2] 150 mg',
#   'Route',
#   'Drug',
#   'T139',
#   'T137',
#   '102136'),
#  (1,
#   'Frequency-Drug',
#   'PO [s1] qhs [e1] , Vistaril 50 mg Po TID , Inderal 20 mg PO BID , Lexapro 20 mg',
#   'You will not be discharged with any of your psychiatric medicines , so please do not take your [s2] Topamax [e2] 150 mg',
#   'Frequency',
#   'Drug',
#   'T140',
#   'T137',
#   '102136'),
#  (1,
#   'Route-Drug',
#   '[s1] PO [e1] daily .',
#   'PO qhs , Vistaril 50 mg Po TID , Inderal 20 mg PO BID , [s2] Lexapro [e2] 20 mg',
#   'Route',
#   'Drug',
#   'T151',
#   'T149',
#   '102136'),
#  (1,
#   'Frequency-Drug',
#   'PO [s1] daily [e1] .',
#   'PO qhs , Vistaril 50 mg Po TID , Inderal 20 mg PO BID , [s2] Lexapro [e2] 20 mg',
#   'Frequency',
#   'Drug',
#   'T152',
#   'T149',
#   '102136'),
#  (1,
#   'Form-Drug',
#   'Disp : * 30 [s1] Tablet ( s ) [e1] * Refills : * 2 * 2 . B - Complex with Vitamin C Tablet Sig : One ( 1 ) Cap PO DAILY ( Daily ) .',
#   '1 . [s2] Folic Acid [e2] 1 mg Tablet Sig : One ( 1 ) Tablet PO DAILY ( Daily ) .',
#   'Form',
#   'Drug',
#   'T153',
#   'T90',
#   '102136'),
#  (1,
#   'Form-Drug',
#   'Disp : * 30 [s1] tablets [e1] * Refills : * 2 * 3 . Multivitamin Tablet Sig : One ( 1 ) Tablet PO DAILY ( Daily ) .',
#   'Disp : * 30 Tablet ( s ) * Refills : * 2 * 2 . [s2] B - Complex with Vitamin C [e2] Tablet Sig : One ( 1 ) Cap PO DAILY ( Daily ) .',
#   'Form',
#   'Drug',
#   'T154',
#   'T97',
#   '102136'),
#  (1,
#   'Form-Drug',
#   'Disp : * 30 [s1] Tablet ( s ) [e1] * Refills : * 2 * 4 . Thiamine HCl 100 mg Tablet Sig : One ( 1 ) Tablet PO DAILY ( Daily ) .',
#   'Disp : * 30 tablets * Refills : * 2 * 3 . [s2] Multivitamin [e2] Tablet Sig : One ( 1 ) Tablet PO DAILY ( Daily ) .',
#   'Form',
#   'Drug',
#   'T155',
#   'T103',
#   '102136'),
#  (1,
#   'Form-Drug',
#   'Disp : * 30 [s1] Tablet ( s ) [e1] * Refills : * 2 * Discharge Disposition : Home',
#   'Disp : * 30 Tablet ( s ) * Refills : * 2 * 4 . [s2] Thiamine HCl [e2] 100 mg Tablet Sig : One ( 1 ) Tablet PO DAILY ( Daily ) .',
#   'Form',
#   'Drug',
#   'T156',
#   'T109',
#   '102136'),
#  (1,
#   'Reason-Drug',
#   'The patient remained fairly [s1] anxious [e1] .',
#   'The patient was given [s2] Valium [e2] per CIWA scale .',
#   'Reason',
#   'Drug',
#   'T9',
#   'T10',
#   '130153'),
#  (1,
#   'ADE-Drug',
#   'At this time a [s1] morbilliform drug erruption [e1] was noted truncally , and eosinophilia persisted .',
#   'As WBC continued to rise , all [s2] abx [e2] were stopped .',
#   'ADE',
#   'Drug',
#   'T36',
#   'T31',
#   '106026'),
#  (1,
#   'Reason-Drug',
#   'In the Name ( NI ) , pt had temp up to 104.2 , [s1] BP down to 85 / 47 [e1] , and HR up to 119 .',
#   'She was given 7 L [s2] IVF [e2] , a R SC central line was placed , and she was started on levophed .',
#   'Reason',
#   'Drug',
#   'T37',
#   'T19',
#   '106026'),
#  (1,
#   'Reason-Drug',
#   '# [s1] Pneumonia [e1] - Patient had chest CT with ground - glass parenchymal opacity , suggestive of pneumonia .',
#   'He was started on [s2] vanco [e2] / zosyn / azithro and was continued on these antibiotics for 7 days after he was no longer neutropenic per pulmonary recommendations .',
#   'Reason',
#   'Drug',
#   'T28',
#   'T30',
#   '102283'),
#  (1,
#   'Reason-Drug',
#   '# [s1] Pneumonia [e1] - Patient had chest CT with ground - glass parenchymal opacity , suggestive of pneumonia .',
#   'He was started on vanco / [s2] zosyn [e2] / azithro and was continued on these antibiotics for 7 days after he was no longer neutropenic per pulmonary recommendations .',
#   'Reason',
#   'Drug',
#   'T28',
#   'T31',
#   '102283'),
#  (1,
#   'Reason-Drug',
#   '# [s1] Pneumonia [e1] - Patient had chest CT with ground - glass parenchymal opacity , suggestive of pneumonia .',
#   'He was started on vanco / zosyn / [s2] azithro [e2] and was continued on these antibiotics for 7 days after he was no longer neutropenic per pulmonary recommendations .',
#   'Reason',
#   'Drug',
#   'T28',
#   'T32',
#   '102283'),
#  (1,
#   'Reason-Drug',
#   '# Pneumonia - Patient had chest CT with ground - glass parenchymal opacity , suggestive of [s1] pneumonia [e1] .',
#   'He was started on [s2] vanco [e2] / zosyn / azithro and was continued on these antibiotics for 7 days after he was no longer neutropenic per pulmonary recommendations .',
#   'Reason',
#   'Drug',
#   'T29',
#   'T30',
#   '102283'),
#  (1,
#   'Reason-Drug',
#   '# Pneumonia - Patient had chest CT with ground - glass parenchymal opacity , suggestive of [s1] pneumonia [e1] .',
#   'He was started on vanco / [s2] zosyn [e2] / azithro and was continued on these antibiotics for 7 days after he was no longer neutropenic per pulmonary recommendations .',
#   'Reason',
# ...
#   'Disp : * 3 Tablet ( s ) * Refills : * 0 * 6 . [s2] Oxycodone - Acetaminophen [e2] 5 - 325 mg Tablet Sig : 1 - 2 Tablets PO',
#   'Duration',
#   'Drug',
#   'T173',
#   'T165',
#   '164366'),
#  (1,
#   'Route-Drug',
#   '[s1] Transdermal [e1] once a day .',
#   'Disp : * 30 Tablet ( s ) * Refills : * 0 * 10 . [s2] Andro Gel [e2] 1 % ( 50 mg ) Gel in Packet Sig : One ( 1 ) packet',
#   'Route',
#   'Drug',
#   'T200',
#   'T195',
#   '164366'),
#  (1,
#   'Frequency-Drug',
#   'Transdermal [s1] once a day [e1] .',
#   'Disp : * 30 Tablet ( s ) * Refills : * 0 * 10 . [s2] Andro Gel [e2] 1 % ( 50 mg ) Gel in Packet Sig : One ( 1 ) packet',
#   'Frequency',
#   'Drug',
#   'T201',
#   'T195',
#   '164366'),
#  (1,
#   'Reason-Drug',
#   'The etiology of his SIRS was unclear as his infectious workup was largely negative with the exception of [s1] a potential LLL pneumonia [e1] .',
#   'It was thought that this was most likely due to an anaphylactic reaction to [s2] amoxicillin [e2] as on further questioning he endorsed pruritis , facial erythema / edema , and that these symptoms felt quite similar to an anaphylactic exposure to bactrim he had several years ago .',
#   'Reason',
#   'Drug',
#   'T29',
#   'T31',
#   '164366'),
#  (1,
#   'Reason-Drug',
#   '# [s1] Elevated creatinine [e1] - He also had mild renal insufficiency which was likely secondary to contrast nephropathy after the IR procedure .',
#   'The patient was transferred to the medical floor on 2193 - 8 - 3 , and his creatinine normalized with IV [s2] fluids [e2] and time .',
#   'ADE',
#   'Drug',
#   'T56',
#   'T27',
#   '110342'),
#  (1,
#   'Form-Drug',
#   'Disp : * 10 [s1] Tablet ( s ) [e1] * Refills : * 0 * 2 . Azithromycin 250 mg Tablet Sig : One ( 1 ) Tablet PO once a day for 2 days .',
#   '1 . [s2] Cefpodoxime [e2] 100 mg Tablet Sig : Two ( 2 ) Tablet PO Q12H ( every 12 hours ) for 3 days .',
#   'Form',
#   'Drug',
#   'T45',
#   'T22',
#   '110342'),
#  (1,
#   'Form-Drug',
#   'Disp : * 2 [s1] Tablet ( s ) [e1] * Refills : * 0 * Discharge Disposition : Home',
#   'Disp : * 10 Tablet ( s ) * Refills : * 0 * 2 . [s2] Azithromycin [e2] 250 mg Tablet Sig : One ( 1 ) Tablet PO once a day for 2 days .',
#   'Form',
#   'Drug',
#   'T50',
#   'T33',
#   '110342'),
#  (1,
#   'Route-Drug',
#   '[s1] PO [e1] DAILY ( Daily ) .',
#   '3 . [s2] Cholecalciferol ( Vitamin D3 ) [e2] 400 unit Tablet Sig : 2.5 Tablets',
#   'Route',
#   'Drug',
#   'T187',
#   'T36',
#   '111882'),
#  (1,
#   'Frequency-Drug',
#   'PO [s1] DAILY ( Daily ) [e1] .',
#   '3 . [s2] Cholecalciferol ( Vitamin D3 ) [e2] 400 unit Tablet Sig : 2.5 Tablets',
#   'Frequency',
#   'Drug',
#   'T188',
#   'T36',
#   '111882'),
#  (1,
#   'Frequency-Drug',
#   'PO [s1] DAILY ( Daily ) [e1] .',
#   '5 . [s2] Atovaquone [e2] 750 mg / 5 mL Suspension Sig : Two ( 2 ) 5 ml teaspoons',
#   'Frequency',
#   'Drug',
#   'T196',
#   'T192',
#   '111882'),
#  (1,
#   'Route-Drug',
#   '[s1] PO [e1] DAILY ( Daily ) .',
#   '5 . [s2] Atovaquone [e2] 750 mg / 5 mL Suspension Sig : Two ( 2 ) 5 ml teaspoons',
#   'Route',
#   'Drug',
#   'T5',
#   'T192',
#   '111882'),
#  (1,
#   'Frequency-Drug',
#   'Injection [s1] QMOWEFR [e1] ( Hospital 1 766 - Wednesday - Friday ) .',
#   'Disp : * 30 Tablet ( s ) * Refills : * 2 * 7 . [s2] Epoetin Alfa [e2] 4 , 000 unit / mL Solution Sig : One ( 1 ) injection',
#   'Frequency',
#   'Drug',
#   'T204',
#   'T97',
#   '111882'),
#  (1,
#   'Form-Drug',
#   '[s1] Injection [e1] QMOWEFR ( Hospital 1 766 - Wednesday - Friday ) .',
#   'Disp : * 30 Tablet ( s ) * Refills : * 2 * 7 . [s2] Epoetin Alfa [e2] 4 , 000 unit / mL Solution Sig : One ( 1 ) injection',
#   'Form',
#   'Drug',
#   'T203',
#   'T97',
#   '111882'),
#  (1,
#   'Reason-Drug',
#   'Peripartum cardiomyopathy was also considered however given the timing of onset and biopsy showing immune complexes seen on endocardial biopsy , [s1] lupus cardiomyopathy [e1] was thought to be more likely .',
#   'She was treated with steroids , cytoxan , plasmaphoresis , [s2] IVIG [e2] and supportive care , and improved from an EF of 15 to 33 % .',
#   'Reason',
#   'Drug',
#   'T254',
#   'T253',
#   '111882'),
#  (1,
#   'Reason-Drug',
#   'Peripartum cardiomyopathy was also considered however given the timing of onset and biopsy showing immune complexes seen on endocardial biopsy , [s1] lupus cardiomyopathy [e1] was thought to be more likely .',
#   'She was treated with steroids , cytoxan , [s2] plasmaphoresis [e2] , IVIG and supportive care , and improved from an EF of 15 to 33 % .',
#   'Reason',
#   'Drug',
#   'T254',
#   'T252',
#   '111882'),
#  (1,
#   'Reason-Drug',
#   'Peripartum cardiomyopathy was also considered however given the timing of onset and biopsy showing immune complexes seen on endocardial biopsy , [s1] lupus cardiomyopathy [e1] was thought to be more likely .',
#   'She was treated with steroids , [s2] cytoxan [e2] , plasmaphoresis , IVIG and supportive care , and improved from an EF of 15 to 33 % .',
#   'Reason',
#   'Drug',
#   'T254',
#   'T251',
#   '111882'),
#  (1,
#   'Reason-Drug',
#   'Peripartum cardiomyopathy was also considered however given the timing of onset and biopsy showing immune complexes seen on endocardial biopsy , [s1] lupus cardiomyopathy [e1] was thought to be more likely .',
#   'She was treated with [s2] steroids [e2] , cytoxan , plasmaphoresis , IVIG and supportive care , and improved from an EF of 15 to 33 % .',
#   'Reason',
#   'Drug',
#   'T254',
#   'T250',
#   '111882'),
#  (1,
#   'Reason-Drug',
#   'Cardiomyopathy and renal failure on current admission were felt to be manifestation of underlying [s1] lupus [e1] .',
#   'Rheumatology was consulted and recommended aggressive therapy with [s2] steriods [e2] , cytoxan and plasmapheresis .',
#   'Reason',
#   'Drug',
#   'T265',
#   'T263',
#   '111882'),
#  (1,
#   'Reason-Drug',
#   'Cardiomyopathy and renal failure on current admission were felt to be manifestation of underlying [s1] lupus [e1] .',
#   'Rheumatology was consulted and recommended aggressive therapy with steriods , cytoxan and [s2] plasmapheresis [e2] .',
#   'Reason',
#   'Drug',
#   'T265',
#   'T264',
#   '111882'),
#  (1,
#   'Reason-Drug',
#   '# [s1] Anemia [e1] : Likely due to acute renal disease , cytoxan therapy .',
#   'Pt was given one unit of [s2] PRBCs [e2] while in patient and started on epo with good improvement in her crit .',
#   'ADE',
#   'Drug',
#   'T292',
#   'T295',
#   '111882'),
#  (1,
#   'Reason-Drug',
#   '# ) [s1] sCHF [e1] , volume overload : On admission , pt was clearly tachypneic but satting well on room air .',
#   'Reported 3 pillow orthopnea and paroxysmal noctural dyspnea , in the setting of recent d / c [s2] Lasix [e2] and IVF resuscitation , LE edema also suggested fluid overload .',
#   'Reason',
#   'Drug',
#   'T256',
#   'T55',
#   '111882'),
#  (1,
#   'Reason-Drug',
#   '# ) sCHF , [s1] volume overload [e1] : On admission , pt was clearly tachypneic but satting well on room air .',
#   'Reported 3 pillow orthopnea and paroxysmal noctural dyspnea , in the setting of recent d / c [s2] Lasix [e2] and IVF resuscitation , LE edema also suggested fluid overload .',
#   'Reason',
#   'Drug',
#   'T257',
#   'T55',
#   '111882'),
#  (1,
#   'Reason-Drug',
#   'Cardiomyopathy and renal failure on current admission were felt to be manifestation of underlying [s1] lupus [e1] .',
#   'Rheumatology was consulted and recommended aggressive therapy with steriods , [s2] cytoxan [e2] and plasmapheresis .',
#   'Reason',
#   'Drug',
#   'T265',
#   'T132',
#   '111882'),
#  (1,
#   'Reason-Drug',
#   '# [s1] Joint pain [e1] : ? medication side effect ( IVIG , hydralazine ) vs lupus flare , however pt has never had joint pain with lupus flares in the past .',
#   'Hydralazine was discontinued , symptomatic relief with [s2] tylenol [e2] , PT .',
#   'ADE',
#   'Drug',
#   'T150',
#   'T47',
#   '111882'),
#  (1,
#   'Frequency-Drug',
#   '[s1] DAILY [e1] ( Daily ) .',
#   '4 . [s2] Multivitamin , Tx - Minerals [e2] Tablet Sig : One ( 1 ) Tablet PO',
#   'Frequency',
#   'Drug',
#   'T83',
#   'T78',
#   '184696'),
#  (1,
#   'Route-Drug',
#   '[s1] Injection [e1] once a week .',
#   '8 . [s2] Procrit [e2] 10 , 000 unit / mL Solution Sig : Numeric Identifier 961 ( Numeric Identifier 961 ) units',
#   'Route',
#   'Drug',
#   'T112',
#   'T108',
#   '184696'),
#  (1,
#   'Frequency-Drug',
#   'Injection [s1] once a week [e1] .',
#   '8 . [s2] Procrit [e2] 10 , 000 unit / mL Solution Sig : Numeric Identifier 961 ( Numeric Identifier 961 ) units',
#   'Frequency',
#   'Drug',
#   'T113',
#   'T108',
#   '184696'),
#  (1,
#   'Form-Drug',
#   '[s1] Weekly [e1] Transdermal QFRI ( every Friday ) .',
#   'Numeric Identifier : * 30 Tablet ( s ) * Refills : * 2 * 12 . [s2] Clonidine [e2] 0.3 mg / 24 hr Patch Weekly Sig : One ( 1 ) Patch',
#   'Form',
#   'Drug',
#   'T143',
#   'T135',
#   '184696'),
#  (1,
#   'Route-Drug',
#   'Weekly [s1] Transdermal [e1] QFRI ( every Friday ) .',
#   'Numeric Identifier : * 30 Tablet ( s ) * Refills : * 2 * 12 . [s2] Clonidine [e2] 0.3 mg / 24 hr Patch Weekly Sig : One ( 1 ) Patch',
#   'Route',
#   'Drug',
#   'T144',
#   'T135',
#   '184696'),
#  (1,
#   'Frequency-Drug',
#   'Weekly Transdermal [s1] QFRI [e1] ( every Friday ) .',
#   'Numeric Identifier : * 30 Tablet ( s ) * Refills : * 2 * 12 . [s2] Clonidine [e2] 0.3 mg / 24 hr Patch Weekly Sig : One ( 1 ) Patch',
#   'Frequency',
#   'Drug',
#   'T145',
#   'T135',
#   '184696'),
#  (1,
#   'ADE-Drug',
#   'You had [s1] acute kidney failure [e1] and were seen by the kidney specialists .',
#   'This was thought to be secondary to medication effect ( [s2] pantoprazole [e2] ) and possibly the cardiac catheterization dye .',
#   'ADE',
#   'Drug',
#   'T178',
#   'T179',
#   '184696'),
#  (1,
#   'ADE-Drug',
#   'You had [s1] acute kidney failure [e1] and were seen by the kidney specialists .',
#   'This was thought to be secondary to medication effect ( pantoprazole ) and possibly the [s2] cardiac catheterization dye [e2] .',
#   'ADE',
#   'Drug',
#   'T178',
#   'T180',
#   '184696'),
#  (1,
#   'Reason-Drug',
#   '[s1] HTN [e1] : Uncontrolled while hospitalized , partly because not tolerating all of his PO medications at the begining of his hospital course .',
#   'His [s2] valsartan [e2] and BB were uptitrated to achieve better control but valsartan was again decreased 12 - 30 renal failure .',
#   'Reason',
#   'Drug',
#   'T248',
#   'T249',
#   '184696'),
#  (1,
#   'Reason-Drug',
#   '[s1] HTN [e1] : Uncontrolled while hospitalized , partly because not tolerating all of his PO medications at the begining of his hospital course .',
#   'His valsartan and [s2] BB [e2] were uptitrated to achieve better control but valsartan was again decreased 12 - 30 renal failure .',
#   'Reason',
#   'Drug',
#   'T248',
#   'T250',
#   '184696'),
#  (1,
#   'ADE-Drug',
#   "[s1] Acute on chronic renal failure [e1] : The creatinine remained at baseline 2 - 2.4 throughout his hospital course but day after catheterization and after having received adquate hydration , sodium bicarbonate and mucomyst pt ' s creatinine jumped to peak 3.3 .",
#   'IT weas thought to be secondary to [s2] contraste dye [e2] versus his PPI has he had high eosinophilia .',
#   'ADE',
#   'Drug',
#   'T255',
#   'T259',
#   '184696'),
#  (1,
#   'Frequency-Drug',
#   '[s1] Q4H ( every 4 hours ) as needed [e1] for pain : do not exceed 12 pills in any 24 hour period .',
#   'Disp : * 60 Capsule ( s ) * Refills : * 0 * 4 . [s2] Oxycodone - Acetaminophen [e2] 5 - 325 mg Tablet Sig : 1 - 2 Tablets PO',
#   'Frequency',
#   'Drug',
#   'T42',
#   'T34',
#   '166834'),
#  (1,
#   'Reason-Drug',
#   'She does suffer from [s1] GERD [e1] , for which she uses',
#   '[s2] Prilosec [e2] .',
#   'Reason',
#   'Drug',
#   'T56',
#   'T57',
#   '166834'),
#  (1,
#   'Form-Drug',
#   '[s1] PCA [e1] .',
#   'The patient clearly denied pain , anxiety ; her post - op pain was controlled with [s2] dilaudid [e2]',
#   'Form',
#   'Drug',
#   'T75',
#   'T74',
#   '166834'),
#  (1,
#   'Reason-Drug',
#   'Q4H ( every 4 hours ) as needed for [s1] pain [e1] : do not exceed 12 pills in any 24 hour period .',
#   'Disp : * 60 Capsule ( s ) * Refills : * 0 * 4 . [s2] Oxycodone - Acetaminophen [e2] 5 - 325 mg Tablet Sig : 1 - 2 Tablets PO',
#   'Reason',
#   'Drug',
#   'T43',
#   'T34',
#   '166834'),
#  (1,
#   'Reason-Drug',
#   'ENT tried scoping her to assess for vocal cord swelling , but she did not tolerate procedure secondarely to [s1] anxiety and dyscomfort [e1] .',
#   'ER tried giving 5 mg of [s2] midazolam [e2] and re - doing procedure , but patient was still unable to tolerate it .',
#   'Reason',
#   'Drug',
#   'T2',
#   'T4',
#   '168831'),
#  (1,
#   'Route-Drug',
#   '[s1] IM [e1] ) .',
#   'She is has a tough access and ER could only get a small IV in R forearm ( that is why they gave [s2] epineprhine [e2]',
#   'Route',
#   'Drug',
#   'T22',
#   'T21',
#   '168831'),
#  (1,
#   'Reason-Drug',
#   '[s1] Asthma [e1] - Pt w / o any wheezing or SOB .',
#   'She was continued on [s2] Albuterol [e2] and on day of discharge Montelukast was restarted .',
#   'Reason',
#   'Drug',
#   'T35',
#   'T36',
#   '168831'),
#  (1,
#   'ADE-Drug',
#   'It was determined that you have [s1] angioedema [e1] , which is an allergic reaction .',
#   'It may have been due to your [s2] Lisinopril [e2] or the Naprosyn .',
#   'ADE',
#   'Drug',
#   'T215',
#   'T216',
#   '168831'),
#  (1,
#   'ADE-Drug',
#   'It was determined that you have [s1] angioedema [e1] , which is an allergic reaction .',
#   'It may have been due to your Lisinopril or the [s2] Naprosyn [e2] .',
#   'ADE',
#   'Drug',
#   'T215',
#   'T217',
#   '168831'),
#  (1,
#   'Reason-Drug',
#   '1 . [s1] Locally - advanced pancreatic cancer [e1] - Initially diagnosed in 2162 by abdominal ultrasound in the setting of crampy abdominal pain .',
#   'She received 31 cycles of [s2] gemcitabine [e2] without any grade',
#   'Reason',
#   'Drug',
#   'T29',
#   'T2',
#   '111458'),
#  (1,
#   'Reason-Drug',
#   '# [s1] Acute renal failure [e1] - Oliguric on arrival to ICU .',
#   'Cr quickly improved with IV [s2] fluids [e2] and support of MAPs .',
#   'Reason',
#   'Drug',
#   'T69',
#   'T68',
#   '111458'),
#  (1,
#   'Route-Drug',
#   'When tolerating oral intake , the patient was transitioned to [s1] oral [e1] pain medications .',
#   'Neuro : Post - operatively , the patient received Fentanyl & [s2] Dilaudid [e2] IV with good effect and adequate pain control .',
#   'Route',
#   'Drug',
#   'T6',
#   'T3',
#   '116451'),
#  (1,
#   'Route-Drug',
#   'When tolerating oral intake , the patient was transitioned to [s1] oral [e1] pain medications .',
#   'Neuro : Post - operatively , the patient received [s2] Fentanyl [e2] & Dilaudid IV with good effect and adequate pain control .',
#   'Route',
#   'Drug',
#   'T6',
#   'T2',
#   '116451'),
#  (1,
#   'Reason-Drug',
#   'Immunosuppression : He received [s1] induction immunosuppression [e1] ( solumedrol and cellcept ) .',
#   'Postop , [s2] solumedrol [e2] was taperedb by post op day 6 to prednisone 20 mg daily .',
#   'Reason',
#   'Drug',
#   'T32',
#   'T35',
#   '116451'),
#  (1,
#   'Frequency-Drug',
#   '[s1] BID ( 2 times a day ) [e1] .',
#   '5 . [s2] mycophenolate mofetil [e2] 500 mg Tablet Sig : Two ( 2 ) Tablet PO',
#   'Frequency',
#   'Drug',
#   'T94',
#   'T88',
#   '116451'),
#  (1,
#   'Route-Drug',
#   '[s1] PO [e1] DAILY ( Daily ) .',
#   '3 . [s2] Aspirin [e2] 81 mg Tablet , Chewable Sig : One ( 1 ) Tablet , Chewable',
#   'Route',
#   'Drug',
#   'T23',
#   'T18',
#   '100579'),
#  (1,
#   'Frequency-Drug',
#   'PO [s1] DAILY [e1] ( Daily ) .',
#   '3 . [s2] Aspirin [e2] 81 mg Tablet , Chewable Sig : One ( 1 ) Tablet , Chewable',
#   'Frequency',
#   'Drug',
#   'T24',
#   'T18',
#   '100579'),
#  (1,
#   'Frequency-Drug',
#   '[s1] QID [e1] ( 4 times a day ) as needed for itching .',
#   '11 . [s2] Camphor - Menthol [e2] 0.5 - 0.5 % Lotion Sig : One ( 1 ) Appl Topical',
#   'Frequency',
#   'Drug',
#   'T84',
#   'T78',
#   '100579'),
#  (1,
#   'Reason-Drug',
#   'QID ( 4 times a day ) as needed for [s1] itching [e1] .',
#   '11 . [s2] Camphor - Menthol [e2] 0.5 - 0.5 % Lotion Sig : One ( 1 ) Appl Topical',
#   'Reason',
#   'Drug',
#   'T85',
#   'T78',
#   '100579'),
#  (1,
#   'Frequency-Drug',
#   'Miscellaneous [s1] Q6H ( every 6 hours ) as needed [e1] for mucus .',
#   '16 . [s2] Acetylcysteine [e2] 20 % ( 200 mg / mL ) Solution Sig : One ( 1 ) ML',
#   'Frequency',
#   'Drug',
#   'T119',
#   'T115',
#   '100579'),
#  (1,
#   'Reason-Drug',
#   'Miscellaneous Q6H ( every 6 hours ) as needed for [s1] mucus [e1] .',
#   '16 . [s2] Acetylcysteine [e2] 20 % ( 200 mg / mL ) Solution Sig : One ( 1 ) ML',
#   'Reason',
#   'Drug',
#   'T120',
#   'T115',
#   '100579'),
#  ...]

# %%
all_in_one(dpos, dneg, dn="2018n2c2_gs_aio_1_train", do_train=True)

# %%
all_in_one(dpos, dneg, dn="2018n2c2", do_train=True)
partial_unique(dpos, dneg, dn="2018n2c2", do_train=True)
all_in_unique(dpos, dneg, dn="2018n2c2", do_train=True)

# %% [markdown]
# ### test

# %%
_, _, rel_cnts = get_all_rel_types(n2c2_test, n2c2_valid_comb)
rel_cnts, reduce(lambda x, y: x + y, [e[1] for e in rel_cnts])

# %%
preds = create_test_samples(n2c2_test, n2c2_valid, n2c2_valid_comb)

# %%
preds[0]

# %%
"""
0 34231
1 36929
2 34477
3 32600
4 31398
"""
for k, v in preds.items():
    print(k, len(v))

# %%
all_in_one(preds, dn="2018n2c2", do_train=False)
partial_unique(preds, dn="2018n2c2", do_train=False)
all_in_unique(preds, dn="2018n2c2", do_train=False)

# %% [markdown]
# ### test with labels

# %%
CUTOFF = 4

# %%
dpos, dneg = create_training_samples(n2c2_test, n2c2_valid, n2c2_valid_comb)
# Out:
# 2021-04-30 18:41:39,561 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:39,561 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:39,562 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/107515.txt ...
# 2021-04-30 18:41:39,583 INFO freeCa
# 2021-04-30 18:41:39,583 WARNING 'freeCa' => 'free' 'Ca'
# 2021-04-30 18:41:39,622 WARNING ('hypergylcemia', 'ADE', (9527, 9540)) offset is overlapped with previous entity; current tok not overlap
# 2021-04-30 18:41:40,280 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:40,280 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:40,281 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/155521.txt ...
# 2021-04-30 18:41:40,300 INFO AnGap
# 2021-04-30 18:41:40,301 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:40,302 INFO AlkPhos
# 2021-04-30 18:41:40,302 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:41:40,302 INFO TotBili
# 2021-04-30 18:41:40,303 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:41:40,493 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:40,494 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:40,494 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/152925.txt ...
# 2021-04-30 18:41:40,676 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:40,677 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:40,677 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/146944.txt ...
# 2021-04-30 18:41:40,697 INFO AnGap
# 2021-04-30 18:41:40,697 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:40,698 INFO AlkPhos
# 2021-04-30 18:41:40,698 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:41:40,699 INFO TotBili
# 2021-04-30 18:41:40,699 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:41:40,700 INFO AlkPhos
# 2021-04-30 18:41:40,700 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:41:40,701 INFO TotBili
# 2021-04-30 18:41:40,701 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:41:40,702 INFO LDLcalc
# 2021-04-30 18:41:40,703 WARNING 'LDLcalc' => 'LD' 'Lcalc'
# 2021-04-30 18:41:40,704 INFO freeCa
# 2021-04-30 18:41:40,704 WARNING 'freeCa' => 'free' 'Ca'
# 2021-04-30 18:41:40,738 WARNING ('severe angioedema', 'Reason', (7616, 7633)) offset is overlapped with previous entity; current tok not overlap
# 2021-04-30 18:41:40,738 WARNING ('lip and tongue swelling', 'Reason', (7639, 7662)) offset is overlapped with previous entity; current tok not overlap
# 2021-04-30 18:41:40,861 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:40,862 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:40,862 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/100130.txt ...
# 2021-04-30 18:41:40,988 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:40,988 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:40,989 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/112520.txt ...
# last index not match  ('p.o', 'Route', (9048, 9051))
# 2021-04-30 18:41:41,202 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:41,203 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:41,203 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/139955.txt ...
# 2021-04-30 18:41:41,226 INFO AnGap
# 2021-04-30 18:41:41,227 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:41,227 INFO AnGap
# 2021-04-30 18:41:41,228 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:41,229 INFO AnGap
# 2021-04-30 18:41:41,229 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:41,230 INFO AnGap
# 2021-04-30 18:41:41,230 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:41,231 INFO AnGap
# 2021-04-30 18:41:41,231 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:41,232 INFO AnGap
# 2021-04-30 18:41:41,233 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:41,233 INFO AnGap
# 2021-04-30 18:41:41,234 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:41,234 INFO AnGap
# 2021-04-30 18:41:41,235 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:41,235 INFO AlkPhos
# 2021-04-30 18:41:41,236 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:41:41,236 INFO TotBili
# 2021-04-30 18:41:41,237 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:41:41,237 INFO AlkPhos
# 2021-04-30 18:41:41,238 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:41:41,238 INFO TotBili
# 2021-04-30 18:41:41,238 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:41:41,239 INFO AlkPhos
# 2021-04-30 18:41:41,239 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:41:41,240 INFO TotBili
# 2021-04-30 18:41:41,240 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:41:41,493 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:41,494 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:41,494 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/110135.txt ...
# 2021-04-30 18:41:41,520 INFO NotDone
# 2021-04-30 18:41:41,521 WARNING 'NotDone' => 'Not' 'Done'
# 2021-04-30 18:41:41,526 INFO qMon
# 2021-04-30 18:41:41,527 WARNING 'qMon' => 'q' 'Mon'
# 2021-04-30 18:41:41,535 INFO NameIs
# 2021-04-30 18:41:41,535 WARNING 'NameIs' => 'Name' 'Is'
# 2021-04-30 18:41:41,561 WARNING ('1L', 'Dosage', (936, 938)) offset is overlapped with previous entity; current tok not overlap
# 2021-04-30 18:41:41,561 ERROR ['LNS', (937, 940), (924, 927), (11, 4)]	('NS', 'Drug', (938, 940)) not matched by their offsets.
# last index not match  ('1L', 'Dosage', (936, 938))
# first index not match  ('NS', 'Drug', (938, 940))
# last index not match  ('NS', 'Drug', (938, 940))
# 2021-04-30 18:41:42,137 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:42,138 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:42,138 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/104140.txt ...
# 2021-04-30 18:41:42,158 INFO AnGap
# 2021-04-30 18:41:42,159 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:42,162 INFO AnGap
# 2021-04-30 18:41:42,163 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:42,163 INFO AnGap
# 2021-04-30 18:41:42,164 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:42,165 INFO AnGap
# 2021-04-30 18:41:42,165 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:42,166 INFO AnGap
# 2021-04-30 18:41:42,166 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:42,167 INFO AlkPhos
# 2021-04-30 18:41:42,167 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:41:42,168 INFO TotBili
# 2021-04-30 18:41:42,168 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:41:42,487 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:42,488 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:42,488 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/104168.txt ...
# 2021-04-30 18:41:42,510 INFO AnGap
# 2021-04-30 18:41:42,511 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:42,511 INFO AlkPhos
# 2021-04-30 18:41:42,512 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:41:42,512 INFO TotBili
# 2021-04-30 18:41:42,513 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:41:42,528 INFO NameIs
# 2021-04-30 18:41:42,528 WARNING 'NameIs' => 'Name' 'Is'
# 2021-04-30 18:41:42,529 INFO NameIs
# 2021-04-30 18:41:42,529 WARNING 'NameIs' => 'Name' 'Is'
# 2021-04-30 18:41:42,695 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:42,696 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:42,696 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/116237.txt ...
# 2021-04-30 18:41:43,108 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:43,109 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:43,109 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/109698.txt ...
# 2021-04-30 18:41:43,136 WARNING ('constipation', 'ADE', (2815, 2827)) offset is overlapped with previous entity; current tok not overlap
# 2021-04-30 18:41:43,298 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:43,298 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:43,299 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/102068.txt ...
# 2021-04-30 18:41:43,322 INFO AnGap
# 2021-04-30 18:41:43,323 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:43,324 INFO AnGap
# 2021-04-30 18:41:43,324 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:43,325 INFO AlkPhos
# 2021-04-30 18:41:43,325 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:41:43,326 INFO TotBili
# 2021-04-30 18:41:43,326 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:41:43,332 INFO GynOnc
# 2021-04-30 18:41:43,332 WARNING 'GynOnc' => 'Gyn' 'Onc'
# 2021-04-30 18:41:43,339 INFO NameIs
# 2021-04-30 18:41:43,340 WARNING 'NameIs' => 'Name' 'Is'
# 2021-04-30 18:41:43,642 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:43,643 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:43,643 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/111160.txt ...
# 2021-04-30 18:41:43,674 INFO AnGap
# 2021-04-30 18:41:43,674 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:43,675 INFO AlkPhos
# 2021-04-30 18:41:43,675 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:41:43,676 INFO TotBili
# 2021-04-30 18:41:43,676 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:41:43,677 INFO AlkPhos
# 2021-04-30 18:41:43,677 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:41:43,678 INFO TotBili
# 2021-04-30 18:41:43,678 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:41:43,728 WARNING ('delerium', 'ADE', (12702, 12710)) offset is overlapped with previous entity; current tok not overlap
# 2021-04-30 18:41:43,728 WARNING ('insomnia', 'Reason', (12763, 12771)) offset is overlapped with previous entity; current tok not overlap
# 2021-04-30 18:41:44,387 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:44,387 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:44,388 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/108343.txt ...
# 2021-04-30 18:41:44,419 INFO freeCa
# 2021-04-30 18:41:44,420 WARNING 'freeCa' => 'free' 'Ca'
# 2021-04-30 18:41:44,422 INFO NotDone
# 2021-04-30 18:41:44,422 WARNING 'NotDone' => 'Not' 'Done'
# 2021-04-30 18:41:44,424 INFO AnGap
# 2021-04-30 18:41:44,424 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:44,432 INFO FeNa
# 2021-04-30 18:41:44,433 WARNING 'FeNa' => 'Fe' 'Na'
# 2021-04-30 18:41:44,479 WARNING ('1', 'Dosage', (11043, 11044)) offset is overlapped with previous entity; current tok not overlap
# first index not match  ('1', 'Dosage', (11043, 11044))
# last index not match  ('1', 'Dosage', (11043, 11044))
# 2021-04-30 18:41:45,299 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:45,299 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:45,300 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/104948.txt ...
# 2021-04-30 18:41:45,327 INFO AnGap
# 2021-04-30 18:41:45,328 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:45,328 INFO NotDone
# 2021-04-30 18:41:45,329 WARNING 'NotDone' => 'Not' 'Done'
# 2021-04-30 18:41:45,329 INFO UricAcd
# 2021-04-30 18:41:45,330 WARNING 'UricAcd' => 'Uric' 'Acd'
# 2021-04-30 18:41:45,331 INFO freeCa
# 2021-04-30 18:41:45,332 WARNING 'freeCa' => 'free' 'Ca'
# 2021-04-30 18:41:45,375 WARNING ('1', 'Dosage', (2094, 2095)) offset is overlapped with previous entity; current tok not overlap
# 2021-04-30 18:41:45,375 WARNING ('1', 'Dosage', (2115, 2116)) offset is overlapped with previous entity; current tok not overlap
# 2021-04-30 18:41:45,376 WARNING ('1', 'Dosage', (2137, 2138)) offset is overlapped with previous entity; current tok not overlap
# 2021-04-30 18:41:45,376 WARNING ('1', 'Dosage', (2164, 2165)) offset is overlapped with previous entity; current tok not overlap
# 2021-04-30 18:41:45,378 WARNING ('6weeks', 'Duration', (9073, 9079)) offset is overlapped with previous entity; current tok not overlap
# first index not match  ('1', 'Dosage', (2094, 2095))
# last index not match  ('1', 'Dosage', (2094, 2095))
# first index not match  ('1', 'Dosage', (2115, 2116))
# last index not match  ('1', 'Dosage', (2115, 2116))
# first index not match  ('1', 'Dosage', (2137, 2138))
# last index not match  ('1', 'Dosage', (2137, 2138))
# first index not match  ('1', 'Dosage', (2164, 2165))
# last index not match  ('1', 'Dosage', (2164, 2165))
# first index not match  ('6weeks', 'Duration', (9073, 9079))
# last index not match  ('6weeks', 'Duration', (9073, 9079))
# 2021-04-30 18:41:45,957 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:45,958 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:45,958 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/100509.txt ...
# 2021-04-30 18:41:45,986 INFO AnGap
# 2021-04-30 18:41:45,987 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:45,988 INFO AlkPhos
# 2021-04-30 18:41:45,988 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:41:45,988 INFO TotBili
# 2021-04-30 18:41:45,989 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:41:46,037 WARNING ('3days', 'Duration', (656, 661)) offset is overlapped with previous entity; current tok not overlap
# 2021-04-30 18:41:46,213 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:46,213 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:46,214 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/115138.txt ...
# 2021-04-30 18:41:46,253 WARNING ('flushing', 'Reason', (995, 1003)) offset is overlapped with previous entity; current tok not overlap
# 2021-04-30 18:41:46,253 WARNING ('periorbital/facial edema', 'Reason', (1005, 1029)) offset is overlapped with previous entity; current tok not overlap
# 2021-04-30 18:41:46,254 WARNING ('hives', 'Reason', (1034, 1039)) offset is overlapped with previous entity; current tok not overlap
# 2021-04-30 18:41:46,255 WARNING ('flushing', 'Reason', (4723, 4731)) offset is overlapped with previous entity; current tok not overlap
# 2021-04-30 18:41:46,255 WARNING ('periorbital/facial edema', 'Reason', (4733, 4757)) offset is overlapped with previous entity; current tok not overlap
# 2021-04-30 18:41:46,256 WARNING ('hives', 'Reason', (4763, 4768)) offset is overlapped with previous entity; current tok not overlap
# last index not match  ('D5W', 'Drug', (16036, 16039))
# first index not match  ('3days', 'Duration', (656, 661))
# last index not match  ('3days', 'Duration', (656, 661))
# 2021-04-30 18:41:46,406 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:46,407 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:46,407 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/104021.txt ...
# 2021-04-30 18:41:46,434 INFO AnGap
# 2021-04-30 18:41:46,435 WARNING 'AnGap' => 'An' 'Gap'
# last index not match  ('O2', 'Drug', (2768, 2770))
# 2021-04-30 18:41:46,883 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:46,883 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:46,884 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/109263.txt ...
# 2021-04-30 18:41:46,900 INFO AnGap
# 2021-04-30 18:41:46,900 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:46,901 INFO TotBili
# 2021-04-30 18:41:46,902 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:41:46,904 INFO AnGap
# 2021-04-30 18:41:46,905 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:47,110 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:47,110 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:47,111 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/108816.txt ...
# 2021-04-30 18:41:47,311 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:47,312 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:47,312 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/105088.txt ...
# last index not match  ('q8h', 'Frequency', (3884, 3887))
# 2021-04-30 18:41:47,360 INFO freeCa
# 2021-04-30 18:41:47,361 WARNING 'freeCa' => 'free' 'Ca'
# 2021-04-30 18:41:47,406 INFO NameIs
# 2021-04-30 18:41:47,406 WARNING 'NameIs' => 'Name' 'Is'
# 2021-04-30 18:41:47,407 INFO NameIs
# 2021-04-30 18:41:47,408 WARNING 'NameIs' => 'Name' 'Is'
# 2021-04-30 18:41:47,419 INFO NameIs
# 2021-04-30 18:41:47,420 WARNING 'NameIs' => 'Name' 'Is'
# 2021-04-30 18:41:48,813 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:48,814 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:48,814 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/121116.txt ...
# 2021-04-30 18:41:48,833 INFO AnGap
# 2021-04-30 18:41:48,834 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:48,835 INFO AnGap
# 2021-04-30 18:41:48,835 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:48,836 INFO AlkPhos
# 2021-04-30 18:41:48,836 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:41:48,837 INFO TotBili
# 2021-04-30 18:41:48,837 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:41:48,838 INFO AlkPhos
# 2021-04-30 18:41:48,838 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:41:48,839 INFO TotBili
# 2021-04-30 18:41:48,839 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:41:48,844 INFO NameIs
# 2021-04-30 18:41:48,844 WARNING 'NameIs' => 'Name' 'Is'
# 2021-04-30 18:41:49,029 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:49,029 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:49,030 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/102903.txt ...
# 2021-04-30 18:41:49,050 INFO NameIs
# 2021-04-30 18:41:49,051 WARNING 'NameIs' => 'Name' 'Is'
# 2021-04-30 18:41:49,052 INFO NameIs
# 2021-04-30 18:41:49,052 WARNING 'NameIs' => 'Name' 'Is'
# 2021-04-30 18:41:49,190 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:49,190 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:49,191 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/152311.txt ...
# 2021-04-30 18:41:49,213 INFO AnGap
# 2021-04-30 18:41:49,213 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:49,231 INFO NameIs
# 2021-04-30 18:41:49,231 WARNING 'NameIs' => 'Name' 'Is'
# last index not match  ('I.V', 'Route', (128, 131))
# 2021-04-30 18:41:49,859 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:49,859 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:49,860 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/106967.txt ...
# 2021-04-30 18:41:50,338 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:50,339 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:50,339 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/110731.txt ...
# 2021-04-30 18:41:50,374 INFO AnGap
# 2021-04-30 18:41:50,375 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:50,385 INFO DMFj
# 2021-04-30 18:41:50,385 WARNING 'DMFj' => 'DM' 'Fj'
# 2021-04-30 18:41:50,595 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:50,596 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:50,596 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/103761.txt ...
# 2021-04-30 18:41:50,621 INFO SlHazy
# 2021-04-30 18:41:50,621 WARNING 'SlHazy' => 'Sl' 'Hazy'
# 2021-04-30 18:41:50,639 INFO HYDROmorphone
# 2021-04-30 18:41:50,640 WARNING 'HYDROmorphone' => 'HYDR' 'Omorphone'
# 2021-04-30 18:41:50,673 WARNING ('fluid overload', 'Reason', (10805, 10819)) offset is overlapped with previous entity; current tok not overlap
# 2021-04-30 18:41:50,674 WARNING ('neutropenic', 'Reason', (12700, 12711)) offset is overlapped with previous entity; current tok not overlap
# 2021-04-30 18:41:51,504 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:51,505 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:51,505 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/185289.txt ...
# 2021-04-30 18:41:51,538 INFO qMonday
# 2021-04-30 18:41:51,539 WARNING 'qMonday' => 'q' 'Monday'
# 2021-04-30 18:41:52,219 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:52,220 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:52,220 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/106369.txt ...
# 2021-04-30 18:41:52,516 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:52,517 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:52,517 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/126085.txt ...
# 2021-04-30 18:41:52,553 INFO AnGap
# 2021-04-30 18:41:52,553 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:52,554 INFO AnGap
# 2021-04-30 18:41:52,554 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:52,555 INFO AnGap
# 2021-04-30 18:41:52,555 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:52,556 INFO AnGap
# 2021-04-30 18:41:52,556 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:52,557 INFO AnGap
# 2021-04-30 18:41:52,557 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:52,558 INFO AnGap
# 2021-04-30 18:41:52,559 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:52,559 INFO AnGap
# 2021-04-30 18:41:52,560 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:52,560 INFO AnGap
# 2021-04-30 18:41:52,561 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:52,562 INFO AnGap
# 2021-04-30 18:41:52,562 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:52,563 INFO AnGap
# 2021-04-30 18:41:52,563 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:52,564 INFO AnGap
# 2021-04-30 18:41:52,564 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:52,565 INFO TotBili
# 2021-04-30 18:41:52,566 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:41:52,566 INFO DirBili
# 2021-04-30 18:41:52,567 WARNING 'DirBili' => 'Dir' 'Bili'
# 2021-04-30 18:41:52,567 INFO IndBili
# 2021-04-30 18:41:52,568 WARNING 'IndBili' => 'Ind' 'Bili'
# 2021-04-30 18:41:52,568 INFO NotDone
# 2021-04-30 18:41:52,569 WARNING 'NotDone' => 'Not' 'Done'
# 2021-04-30 18:41:52,575 INFO freeCa
# 2021-04-30 18:41:52,576 WARNING 'freeCa' => 'free' 'Ca'
# 2021-04-30 18:41:52,577 INFO freeCa
# 2021-04-30 18:41:52,577 WARNING 'freeCa' => 'free' 'Ca'
# 2021-04-30 18:41:52,578 INFO freeCa
# 2021-04-30 18:41:52,578 WARNING 'freeCa' => 'free' 'Ca'
# 2021-04-30 18:41:52,578 INFO freeCa
# 2021-04-30 18:41:52,579 WARNING 'freeCa' => 'free' 'Ca'
# 2021-04-30 18:41:52,579 INFO freeCa
# 2021-04-30 18:41:52,580 WARNING 'freeCa' => 'free' 'Ca'
# 2021-04-30 18:41:52,588 INFO QACHSInsulin
# 2021-04-30 18:41:52,589 WARNING 'QACHSInsulin' => 'QACHS' 'Insulin'
# 2021-04-30 18:41:52,591 INFO NameIs
# 2021-04-30 18:41:52,592 WARNING 'NameIs' => 'Name' 'Is'
# 2021-04-30 18:41:52,650 WARNING ('HIT', 'ADE', (1014, 1017)) offset is overlapped with previous entity; current tok not overlap
# 2021-04-30 18:41:53,089 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:53,090 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:53,090 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/112446.txt ...
# 2021-04-30 18:41:53,260 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:53,261 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:53,261 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/113348.txt ...
# 2021-04-30 18:41:53,288 INFO NameIs
# 2021-04-30 18:41:53,289 WARNING 'NameIs' => 'Name' 'Is'
# 2021-04-30 18:41:53,289 INFO NameIs
# 2021-04-30 18:41:53,290 WARNING 'NameIs' => 'Name' 'Is'
# 2021-04-30 18:41:53,500 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:53,501 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:53,501 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/106792.txt ...
# 2021-04-30 18:41:53,523 INFO AnGap
# 2021-04-30 18:41:53,524 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:53,524 INFO AnGap
# 2021-04-30 18:41:53,525 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:53,525 INFO AnGap
# 2021-04-30 18:41:53,526 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:53,814 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:53,815 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:53,815 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/174339.txt ...
# 2021-04-30 18:41:54,026 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:54,027 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:54,027 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/102913.txt ...
# 2021-04-30 18:41:54,045 INFO CoreValve
# 2021-04-30 18:41:54,045 WARNING 'CoreValve' => 'Core' 'Valve'
# 2021-04-30 18:41:54,046 INFO CoreValve
# 2021-04-30 18:41:54,047 WARNING 'CoreValve' => 'Core' 'Valve'
# 2021-04-30 18:41:54,053 INFO AnGap
# 2021-04-30 18:41:54,054 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:54,060 INFO AlkPhos
# 2021-04-30 18:41:54,060 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:41:54,061 INFO TotBili
# 2021-04-30 18:41:54,062 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:41:54,063 INFO AnGap
# 2021-04-30 18:41:54,063 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:54,067 INFO CoreValve
# 2021-04-30 18:41:54,068 WARNING 'CoreValve' => 'Core' 'Valve'
# 2021-04-30 18:41:54,069 INFO CoreValve
# 2021-04-30 18:41:54,070 WARNING 'CoreValve' => 'Core' 'Valve'
# 2021-04-30 18:41:54,072 INFO CoreValve
# 2021-04-30 18:41:54,072 WARNING 'CoreValve' => 'Core' 'Valve'
# 2021-04-30 18:41:54,075 INFO CoreValve
# 2021-04-30 18:41:54,075 WARNING 'CoreValve' => 'Core' 'Valve'
# 2021-04-30 18:41:54,076 INFO CoreValve
# 2021-04-30 18:41:54,076 WARNING 'CoreValve' => 'Core' 'Valve'
# 2021-04-30 18:41:54,078 INFO CoreValve
# 2021-04-30 18:41:54,079 WARNING 'CoreValve' => 'Core' 'Valve'
# 2021-04-30 18:41:54,080 INFO CoreValve
# 2021-04-30 18:41:54,080 WARNING 'CoreValve' => 'Core' 'Valve'
# 2021-04-30 18:41:54,086 INFO CoreValve
# 2021-04-30 18:41:54,086 WARNING 'CoreValve' => 'Core' 'Valve'
# 2021-04-30 18:41:54,302 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:54,303 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:54,303 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/105885.txt ...
# 2021-04-30 18:41:54,403 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:54,404 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:54,404 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/147452.txt ...
# 2021-04-30 18:41:54,417 INFO cryoMaze
# 2021-04-30 18:41:54,418 WARNING 'cryoMaze' => 'cryo' 'Maze'
# 2021-04-30 18:41:54,422 INFO AnGap
# 2021-04-30 18:41:54,423 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:54,423 INFO AlkPhos
# 2021-04-30 18:41:54,423 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:41:54,424 INFO TotBili
# 2021-04-30 18:41:54,425 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:41:54,425 INFO LDLmeas
# 2021-04-30 18:41:54,426 WARNING 'LDLmeas' => 'LD' 'Lmeas'
# 2021-04-30 18:41:54,435 INFO CareGroup
# 2021-04-30 18:41:54,435 WARNING 'CareGroup' => 'Care' 'Group'
# last index not match  ('b.i.d', 'Frequency', (4471, 4476))
# 2021-04-30 18:41:54,694 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:54,695 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:54,696 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/115466.txt ...
# 2021-04-30 18:41:54,721 INFO AnGap
# 2021-04-30 18:41:54,722 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:54,723 INFO AnGap
# 2021-04-30 18:41:54,723 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:54,724 INFO AnGap
# 2021-04-30 18:41:54,724 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:55,016 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:55,016 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:55,017 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/101161.txt ...
# 2021-04-30 18:41:55,161 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:55,162 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:55,162 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/105475.txt ...
# 2021-04-30 18:41:55,404 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:55,404 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:55,405 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/104757.txt ...
# 2021-04-30 18:41:55,437 INFO freeCa
# 2021-04-30 18:41:55,438 WARNING 'freeCa' => 'free' 'Ca'
# 2021-04-30 18:41:55,439 INFO AlkPhos
# 2021-04-30 18:41:55,440 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:41:55,440 INFO TotBili
# 2021-04-30 18:41:55,440 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:41:55,442 INFO freeCa
# 2021-04-30 18:41:55,442 WARNING 'freeCa' => 'free' 'Ca'
# 2021-04-30 18:41:55,443 INFO AnGap
# 2021-04-30 18:41:55,444 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:55,488 WARNING ('1', 'Dosage', (3063, 3064)) offset is overlapped with previous entity; current tok not overlap
# 2021-04-30 18:41:55,488 WARNING ('1', 'Dosage', (3087, 3088)) offset is overlapped with previous entity; current tok not overlap
# 2021-04-30 18:41:55,489 WARNING ('1', 'Dosage', (3107, 3108)) offset is overlapped with previous entity; current tok not overlap
# 2021-04-30 18:41:55,489 WARNING ('1', 'Dosage', (3138, 3139)) offset is overlapped with previous entity; current tok not overlap
# first index not match  ('1', 'Dosage', (3063, 3064))
# last index not match  ('1', 'Dosage', (3063, 3064))
# first index not match  ('1', 'Dosage', (3087, 3088))
# last index not match  ('1', 'Dosage', (3087, 3088))
# first index not match  ('1', 'Dosage', (3107, 3108))
# last index not match  ('1', 'Dosage', (3107, 3108))
# first index not match  ('1', 'Dosage', (3138, 3139))
# last index not match  ('1', 'Dosage', (3138, 3139))
# 2021-04-30 18:41:55,928 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:55,929 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:55,929 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/156777.txt ...
# 2021-04-30 18:41:55,949 INFO AnGap
# 2021-04-30 18:41:55,950 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:55,950 INFO AlkPhos
# 2021-04-30 18:41:55,951 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:41:55,951 INFO TotBili
# 2021-04-30 18:41:55,952 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:41:56,076 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:56,077 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:56,077 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/151232.txt ...
# 2021-04-30 18:41:56,117 INFO NameIs
# 2021-04-30 18:41:56,117 WARNING 'NameIs' => 'Name' 'Is'
# 2021-04-30 18:41:56,118 INFO NameIs
# 2021-04-30 18:41:56,118 WARNING 'NameIs' => 'Name' 'Is'
# 2021-04-30 18:41:56,373 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:56,373 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:56,374 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/112445.txt ...
# 2021-04-30 18:41:56,408 INFO AnGap
# 2021-04-30 18:41:56,408 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:56,409 INFO TotBili
# 2021-04-30 18:41:56,409 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:41:56,410 INFO NotDone
# 2021-04-30 18:41:56,410 WARNING 'NotDone' => 'Not' 'Done'
# 2021-04-30 18:41:56,411 INFO NotDone
# 2021-04-30 18:41:56,411 WARNING 'NotDone' => 'Not' 'Done'
# 2021-04-30 18:41:56,412 INFO AnGap
# 2021-04-30 18:41:56,413 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:56,991 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:56,992 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:56,992 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/121702.txt ...
# 2021-04-30 18:41:57,153 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:57,153 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:57,154 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/122223.txt ...
# 2021-04-30 18:41:57,178 INFO IIIa
# 2021-04-30 18:41:57,179 WARNING 'IIIa' => 'II' 'Ia'
# 2021-04-30 18:41:57,357 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:57,357 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:57,358 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/113607.txt ...
# 2021-04-30 18:41:57,385 INFO NameIs
# 2021-04-30 18:41:57,386 WARNING 'NameIs' => 'Name' 'Is'
# 2021-04-30 18:41:57,880 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:57,880 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:57,881 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/114626.txt ...
# 2021-04-30 18:41:58,142 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:58,143 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:58,143 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/107128.txt ...
# 2021-04-30 18:41:58,195 WARNING ('Upper GI bleed', 'Reason', (6842, 6856)) offset is overlapped with previous entity; current tok not overlap
# 2021-04-30 18:41:58,558 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:58,559 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:58,559 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/104390.txt ...
# 2021-04-30 18:41:58,735 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:58,735 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:58,736 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/172206.txt ...
# 2021-04-30 18:41:58,751 INFO wAs
# 2021-04-30 18:41:58,751 WARNING 'wAs' => 'w' 'As'
# 2021-04-30 18:41:58,767 INFO NameIs
# 2021-04-30 18:41:58,768 WARNING 'NameIs' => 'Name' 'Is'
# 2021-04-30 18:41:58,768 INFO NameIs
# 2021-04-30 18:41:58,769 WARNING 'NameIs' => 'Name' 'Is'
# 2021-04-30 18:41:58,918 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:58,919 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:58,919 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/106961.txt ...
# 2021-04-30 18:41:58,943 INFO AnGap
# 2021-04-30 18:41:58,944 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:58,945 INFO AlkPhos
# 2021-04-30 18:41:58,945 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:41:58,946 INFO TotBili
# 2021-04-30 18:41:58,946 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:41:58,948 INFO AnGap
# 2021-04-30 18:41:58,949 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:58,949 INFO AnGap
# 2021-04-30 18:41:58,950 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:58,950 INFO AnGap
# 2021-04-30 18:41:58,951 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:58,951 INFO AnGap
# 2021-04-30 18:41:58,952 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:58,953 INFO AnGap
# 2021-04-30 18:41:58,953 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:58,954 INFO AlkPhos
# 2021-04-30 18:41:58,954 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:41:58,954 INFO TotBili
# 2021-04-30 18:41:58,955 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:41:58,955 INFO AlkPhos
# 2021-04-30 18:41:58,956 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:41:58,956 INFO TotBili
# 2021-04-30 18:41:58,957 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:41:58,957 INFO AlkPhos
# 2021-04-30 18:41:58,958 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:41:58,958 INFO TotBili
# 2021-04-30 18:41:58,959 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:41:58,959 INFO AlkPhos
# 2021-04-30 18:41:58,960 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:41:58,960 INFO TotBili
# 2021-04-30 18:41:58,961 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:41:58,961 INFO AlkPhos
# 2021-04-30 18:41:58,962 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:41:58,962 INFO TotBili
# 2021-04-30 18:41:58,963 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:41:58,964 INFO AlkPhos
# 2021-04-30 18:41:58,965 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:41:58,966 INFO TotBili
# 2021-04-30 18:41:58,967 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:41:58,969 INFO AnGap
# 2021-04-30 18:41:58,970 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:58,983 INFO NameIs
# 2021-04-30 18:41:58,984 WARNING 'NameIs' => 'Name' 'Is'
# last index not match  ('p.o', 'Route', (9050, 9053))
# last index not match  ('p.o', 'Route', (9106, 9109))
# 2021-04-30 18:41:59,247 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:59,248 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:59,248 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/121663.txt ...
# 2021-04-30 18:41:59,269 INFO AlkPhos
# 2021-04-30 18:41:59,270 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:41:59,271 INFO NotDone
# 2021-04-30 18:41:59,271 WARNING 'NotDone' => 'Not' 'Done'
# 2021-04-30 18:41:59,507 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:59,508 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:59,508 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/102051.txt ...
# 2021-04-30 18:41:59,525 INFO AnGap
# 2021-04-30 18:41:59,525 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:41:59,526 INFO AlkPhos
# 2021-04-30 18:41:59,526 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:41:59,527 INFO TotBili
# 2021-04-30 18:41:59,527 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:41:59,679 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:59,679 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:59,680 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/139825.txt ...
# 2021-04-30 18:41:59,743 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:59,743 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:59,744 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/122090.txt ...
# 2021-04-30 18:41:59,774 WARNING ('V', 'Route', (3232, 3233)) offset is overlapped with previous entity; current tok not overlap
# 2021-04-30 18:41:59,836 INFO sentence boundary detection class initiated.
# 2021-04-30 18:41:59,837 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:41:59,837 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/113265.txt ...
# 2021-04-30 18:41:59,874 INFO AnGap
# 2021-04-30 18:41:59,874 WARNING 'AnGap' => 'An' 'Gap'
# first index not match  ('V', 'Route', (3232, 3233))
# last index not match  ('V', 'Route', (3232, 3233))
# 2021-04-30 18:42:00,670 INFO sentence boundary detection class initiated.
# 2021-04-30 18:42:00,671 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:42:00,671 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/115199.txt ...
# 2021-04-30 18:42:00,701 INFO AnGap
# 2021-04-30 18:42:00,701 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:00,707 INFO NameIs
# 2021-04-30 18:42:00,707 WARNING 'NameIs' => 'Name' 'Is'
# 2021-04-30 18:42:00,801 INFO sentence boundary detection class initiated.
# 2021-04-30 18:42:00,802 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:42:00,803 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/105605.txt ...
# 2021-04-30 18:42:00,832 INFO AnGap
# 2021-04-30 18:42:00,832 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:00,833 INFO AnGap
# 2021-04-30 18:42:00,833 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:00,834 INFO AnGap
# 2021-04-30 18:42:00,835 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:00,835 INFO AnGap
# 2021-04-30 18:42:00,836 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:00,836 INFO AnGap
# 2021-04-30 18:42:00,837 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:00,838 INFO AnGap
# 2021-04-30 18:42:00,838 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:00,839 INFO AnGap
# 2021-04-30 18:42:00,839 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:00,840 INFO AnGap
# 2021-04-30 18:42:00,840 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:00,841 INFO AnGap
# 2021-04-30 18:42:00,841 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:00,842 INFO AlkPhos
# 2021-04-30 18:42:00,842 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:42:00,843 INFO TotBili
# 2021-04-30 18:42:00,843 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:42:00,844 INFO AlkPhos
# 2021-04-30 18:42:00,844 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:42:00,845 INFO TotBili
# 2021-04-30 18:42:00,845 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:42:00,846 INFO AlkPhos
# 2021-04-30 18:42:00,846 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:42:00,847 INFO TotBili
# 2021-04-30 18:42:00,847 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:42:00,848 INFO AlkPhos
# 2021-04-30 18:42:00,848 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:42:00,849 INFO TotBili
# 2021-04-30 18:42:00,849 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:42:00,852 INFO LDLcalc
# 2021-04-30 18:42:00,852 WARNING 'LDLcalc' => 'LD' 'Lcalc'
# 2021-04-30 18:42:01,148 INFO sentence boundary detection class initiated.
# 2021-04-30 18:42:01,149 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:42:01,149 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/113852.txt ...
# 2021-04-30 18:42:01,162 INFO AnGap
# 2021-04-30 18:42:01,168 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:01,275 INFO sentence boundary detection class initiated.
# 2021-04-30 18:42:01,275 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:42:01,276 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/111274.txt ...
# 2021-04-30 18:42:01,307 INFO AnGap
# 2021-04-30 18:42:01,307 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:01,308 INFO UricAcd
# 2021-04-30 18:42:01,308 WARNING 'UricAcd' => 'Uric' 'Acd'
# 2021-04-30 18:42:01,334 INFO NameIs
# 2021-04-30 18:42:01,335 WARNING 'NameIs' => 'Name' 'Is'
# 2021-04-30 18:42:01,724 INFO sentence boundary detection class initiated.
# 2021-04-30 18:42:01,724 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:42:01,725 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/123204.txt ...
# 2021-04-30 18:42:01,747 INFO AnGap
# 2021-04-30 18:42:01,748 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:01,749 INFO AlkPhos
# 2021-04-30 18:42:01,749 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:42:01,750 INFO TotBili
# 2021-04-30 18:42:01,750 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:42:01,751 INFO DirBili
# 2021-04-30 18:42:01,751 WARNING 'DirBili' => 'Dir' 'Bili'
# 2021-04-30 18:42:01,751 INFO IndBili
# 2021-04-30 18:42:01,752 WARNING 'IndBili' => 'Ind' 'Bili'
# 2021-04-30 18:42:01,906 INFO sentence boundary detection class initiated.
# 2021-04-30 18:42:01,906 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:42:01,907 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/101099.txt ...
# 2021-04-30 18:42:01,923 INFO AnGap
# 2021-04-30 18:42:01,923 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:01,924 INFO AnGap
# 2021-04-30 18:42:01,925 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:02,212 INFO sentence boundary detection class initiated.
# 2021-04-30 18:42:02,212 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:42:02,213 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/116903.txt ...
# 2021-04-30 18:42:02,387 INFO sentence boundary detection class initiated.
# 2021-04-30 18:42:02,387 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:42:02,388 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/104446.txt ...
# 2021-04-30 18:42:02,417 INFO FeUrea
# 2021-04-30 18:42:02,417 WARNING 'FeUrea' => 'Fe' 'Urea'
# 2021-04-30 18:42:02,450 WARNING ('HYPERKALEMIA', 'Reason', (8979, 8991)) offset is overlapped with previous entity; current tok not overlap
# 2021-04-30 18:42:02,916 INFO sentence boundary detection class initiated.
# 2021-04-30 18:42:02,917 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:42:02,917 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/196911.txt ...
# 2021-04-30 18:42:03,175 INFO sentence boundary detection class initiated.
# 2021-04-30 18:42:03,176 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:42:03,176 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/112350.txt ...
# 2021-04-30 18:42:03,407 INFO sentence boundary detection class initiated.
# 2021-04-30 18:42:03,408 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:42:03,408 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/102357.txt ...
# 2021-04-30 18:42:03,437 INFO NameIs
# 2021-04-30 18:42:03,438 WARNING 'NameIs' => 'Name' 'Is'
# first index not match  ('2 days', 'Duration', (6424, 6430))
# last index not match  ('O2', 'Drug', (3123, 3125))
# 2021-04-30 18:42:03,696 INFO sentence boundary detection class initiated.
# 2021-04-30 18:42:03,697 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:42:03,697 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/110753.txt ...
# 2021-04-30 18:42:03,722 INFO AnGap
# 2021-04-30 18:42:03,723 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:03,723 INFO TotProt
# 2021-04-30 18:42:03,724 WARNING 'TotProt' => 'Tot' 'Prot'
# 2021-04-30 18:42:03,725 INFO RheuFac
# 2021-04-30 18:42:03,725 WARNING 'RheuFac' => 'Rheu' 'Fac'
# 2021-04-30 18:42:04,209 INFO sentence boundary detection class initiated.
# 2021-04-30 18:42:04,209 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:42:04,210 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/101110.txt ...
# 2021-04-30 18:42:04,232 INFO AnGap
# 2021-04-30 18:42:04,233 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:04,234 INFO AnGap
# 2021-04-30 18:42:04,234 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:04,235 INFO AnGap
# 2021-04-30 18:42:04,236 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:04,236 INFO AnGap
# 2021-04-30 18:42:04,237 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:04,243 INFO AlkPhos
# 2021-04-30 18:42:04,243 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:42:04,243 INFO TotBili
# 2021-04-30 18:42:04,244 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:42:04,244 INFO DirBili
# 2021-04-30 18:42:04,245 WARNING 'DirBili' => 'Dir' 'Bili'
# 2021-04-30 18:42:04,245 INFO IndBili
# 2021-04-30 18:42:04,246 WARNING 'IndBili' => 'Ind' 'Bili'
# 2021-04-30 18:42:04,246 INFO AlkPhos
# 2021-04-30 18:42:04,247 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:42:04,247 INFO TotBili
# 2021-04-30 18:42:04,248 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:42:04,252 INFO freeCa
# 2021-04-30 18:42:04,252 WARNING 'freeCa' => 'free' 'Ca'
# 2021-04-30 18:42:04,253 INFO freeCa
# 2021-04-30 18:42:04,253 WARNING 'freeCa' => 'free' 'Ca'
# 2021-04-30 18:42:04,254 INFO freeCa
# ...
# 2021-04-30 18:42:43,911 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:42:43,911 INFO TotBili
# 2021-04-30 18:42:43,911 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:42:43,912 INFO DirBili
# 2021-04-30 18:42:43,912 WARNING 'DirBili' => 'Dir' 'Bili'
# 2021-04-30 18:42:43,913 INFO IndBili
# 2021-04-30 18:42:43,913 WARNING 'IndBili' => 'Ind' 'Bili'
# 2021-04-30 18:42:43,914 INFO AlkPhos
# 2021-04-30 18:42:43,914 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:42:43,915 INFO TotBili
# 2021-04-30 18:42:43,915 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:42:43,916 INFO AlkPhos
# 2021-04-30 18:42:43,916 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:42:43,916 INFO TotBili
# 2021-04-30 18:42:43,917 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:42:43,917 INFO AnGap
# 2021-04-30 18:42:43,918 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:43,919 INFO AnGap
# 2021-04-30 18:42:43,919 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:43,919 INFO AnGap
# 2021-04-30 18:42:43,920 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:43,922 INFO TotProt
# 2021-04-30 18:42:43,923 WARNING 'TotProt' => 'Tot' 'Prot'
# 2021-04-30 18:42:43,923 INFO TotProt
# 2021-04-30 18:42:43,924 WARNING 'TotProt' => 'Tot' 'Prot'
# 2021-04-30 18:42:43,959 WARNING ('steroids', 'Drug', (14019, 14027)) offset is overlapped with previous entity; current tok not overlap
# 2021-04-30 18:42:44,226 INFO sentence boundary detection class initiated.
# 2021-04-30 18:42:44,226 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:42:44,227 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/101786.txt ...
# 2021-04-30 18:42:44,244 INFO AnGap
# 2021-04-30 18:42:44,245 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:44,271 WARNING ('shortness of breat', 'Reason', (6561, 6579)) offset is overlapped with previous entity; current tok not overlap
# last index not match  ('shortness of breat', 'Reason', (6561, 6579))
# 2021-04-30 18:42:44,521 INFO sentence boundary detection class initiated.
# 2021-04-30 18:42:44,521 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:42:44,522 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/109330.txt ...
# 2021-04-30 18:42:44,542 INFO AnGap
# 2021-04-30 18:42:44,543 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:44,559 INFO NameIs
# 2021-04-30 18:42:44,560 WARNING 'NameIs' => 'Name' 'Is'
# 2021-04-30 18:42:44,560 INFO NameIs
# 2021-04-30 18:42:44,561 WARNING 'NameIs' => 'Name' 'Is'
# 2021-04-30 18:42:44,751 INFO sentence boundary detection class initiated.
# 2021-04-30 18:42:44,752 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:42:44,758 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/116204.txt ...
# 2021-04-30 18:42:44,783 INFO hypertensionShe
# 2021-04-30 18:42:44,784 WARNING 'hypertensionShe' => 'hypertension' 'She'
# 2021-04-30 18:42:44,803 WARNING ('hypotensive', 'Reason', (8810, 8821)) offset is overlapped with previous entity; current tok not overlap
# 2021-04-30 18:42:45,284 INFO sentence boundary detection class initiated.
# 2021-04-30 18:42:45,284 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:42:45,285 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/110891.txt ...
# 2021-04-30 18:42:45,301 INFO AnGap
# 2021-04-30 18:42:45,301 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:45,308 INFO NameIs
# 2021-04-30 18:42:45,309 WARNING 'NameIs' => 'Name' 'Is'
# 2021-04-30 18:42:45,309 INFO NameIs
# 2021-04-30 18:42:45,310 WARNING 'NameIs' => 'Name' 'Is'
# 2021-04-30 18:42:45,310 INFO NameIs
# 2021-04-30 18:42:45,311 WARNING 'NameIs' => 'Name' 'Is'
# 2021-04-30 18:42:45,329 WARNING ('2u', 'Dosage', (5293, 5295)) offset is overlapped with previous entity; current tok not overlap
# 2021-04-30 18:42:45,330 ERROR ['uFFP', (5294, 5298), (5429, 5433), (73, 5)]	('FFP', 'Drug', (5295, 5298)) not matched by their offsets.
# 2021-04-30 18:42:45,331 WARNING ('2u', 'Dosage', (5351, 5353)) offset is overlapped with previous entity; current tok not overlap
# 2021-04-30 18:42:45,331 ERROR ['uPRBC', (5352, 5357), (5485, 5490), (74, 3)]	('PRBC', 'Drug', (5353, 5357)) not matched by their offsets.
# 2021-04-30 18:42:45,543 INFO sentence boundary detection class initiated.
# 2021-04-30 18:42:45,544 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:42:45,544 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/113963.txt ...
# 2021-04-30 18:42:45,571 INFO AnGap
# 2021-04-30 18:42:45,571 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:45,572 INFO NotDone
# 2021-04-30 18:42:45,572 WARNING 'NotDone' => 'Not' 'Done'
# 2021-04-30 18:42:45,574 INFO AnGap
# 2021-04-30 18:42:45,575 WARNING 'AnGap' => 'An' 'Gap'
# last index not match  ('2u', 'Dosage', (5293, 5295))
# first index not match  ('FFP', 'Drug', (5295, 5298))
# last index not match  ('FFP', 'Drug', (5295, 5298))
# last index not match  ('2u', 'Dosage', (5351, 5353))
# first index not match  ('PRBC', 'Drug', (5353, 5357))
# last index not match  ('PRBC', 'Drug', (5353, 5357))
# 2021-04-30 18:42:45,586 INFO NameIs
# 2021-04-30 18:42:45,587 WARNING 'NameIs' => 'Name' 'Is'
# 2021-04-30 18:42:45,618 WARNING ('lasix', 'Drug', (15225, 15230)) offset is overlapped with previous entity; current tok not overlap
# 2021-04-30 18:42:46,444 INFO sentence boundary detection class initiated.
# 2021-04-30 18:42:46,445 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:42:46,450 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/107902.txt ...
# 2021-04-30 18:42:46,568 INFO sentence boundary detection class initiated.
# 2021-04-30 18:42:46,569 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:42:46,569 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/106349.txt ...
# 2021-04-30 18:42:46,595 INFO AnGap
# 2021-04-30 18:42:46,596 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:46,596 INFO AlkPhos
# 2021-04-30 18:42:46,597 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:42:46,597 INFO TotBili
# 2021-04-30 18:42:46,598 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:42:46,599 INFO AnGap
# 2021-04-30 18:42:46,600 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:46,601 INFO AlkPhos
# 2021-04-30 18:42:46,601 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:42:46,602 INFO TotBili
# 2021-04-30 18:42:46,602 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:42:46,603 INFO UricAcd
# 2021-04-30 18:42:46,603 WARNING 'UricAcd' => 'Uric' 'Acd'
# 2021-04-30 18:42:46,610 INFO OxyContin
# 2021-04-30 18:42:46,611 WARNING 'OxyContin' => 'Oxy' 'Contin'
# 2021-04-30 18:42:46,612 INFO OxyContin
# 2021-04-30 18:42:46,612 WARNING 'OxyContin' => 'Oxy' 'Contin'
# 2021-04-30 18:42:46,614 INFO AndroGel
# 2021-04-30 18:42:46,615 WARNING 'AndroGel' => 'Andro' 'Gel'
# last index not match  ('p.o', 'Route', (5493, 5496))
# last index not match  ('p.o', 'Route', (5555, 5558))
# last index not match  ('p.o', 'Route', (5625, 5628))
# last index not match  ('p.o', 'Route', (6209, 6212))
# 2021-04-30 18:42:47,351 INFO sentence boundary detection class initiated.
# 2021-04-30 18:42:47,352 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:42:47,352 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/198207.txt ...
# 2021-04-30 18:42:47,543 INFO sentence boundary detection class initiated.
# 2021-04-30 18:42:47,544 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:42:47,544 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/113222.txt ...
# 2021-04-30 18:42:47,570 INFO AnGap
# 2021-04-30 18:42:47,570 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:47,583 INFO NameIs
# 2021-04-30 18:42:47,584 WARNING 'NameIs' => 'Name' 'Is'
# 2021-04-30 18:42:47,585 INFO NameIs
# 2021-04-30 18:42:47,586 WARNING 'NameIs' => 'Name' 'Is'
# 2021-04-30 18:42:47,586 INFO NameIs
# 2021-04-30 18:42:47,587 WARNING 'NameIs' => 'Name' 'Is'
# 2021-04-30 18:42:47,607 WARNING ('pressure dropped', 'Reason', (1547, 1563)) offset is overlapped with previous entity; current tok not overlap
# 2021-04-30 18:42:47,609 WARNING ('angioedema', 'Reason', (7153, 7163)) offset is overlapped with previous entity; current tok not overlap
# 2021-04-30 18:42:47,922 INFO sentence boundary detection class initiated.
# 2021-04-30 18:42:47,923 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:42:47,923 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/124465.txt ...
# 2021-04-30 18:42:48,051 INFO sentence boundary detection class initiated.
# 2021-04-30 18:42:48,051 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:42:48,052 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/139178.txt ...
# 2021-04-30 18:42:48,073 INFO AnGap
# 2021-04-30 18:42:48,073 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:48,074 INFO AlkPhos
# 2021-04-30 18:42:48,074 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:42:48,075 INFO TotBili
# 2021-04-30 18:42:48,075 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:42:48,076 INFO AlkPhos
# 2021-04-30 18:42:48,076 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:42:48,076 INFO TotBili
# 2021-04-30 18:42:48,077 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:42:48,077 INFO TotProt
# 2021-04-30 18:42:48,078 WARNING 'TotProt' => 'Tot' 'Prot'
# 2021-04-30 18:42:48,289 INFO sentence boundary detection class initiated.
# 2021-04-30 18:42:48,290 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:42:48,290 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/106015.txt ...
# 2021-04-30 18:42:48,317 INFO NameIs
# 2021-04-30 18:42:48,317 WARNING 'NameIs' => 'Name' 'Is'
# 2021-04-30 18:42:48,318 INFO NameIs
# 2021-04-30 18:42:48,318 WARNING 'NameIs' => 'Name' 'Is'
# 2021-04-30 18:42:48,327 INFO AnGap
# 2021-04-30 18:42:48,327 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:48,380 WARNING ('Diarrhea', 'Reason', (15355, 15363)) offset is overlapped with previous entity; current tok not overlap
# 2021-04-30 18:42:49,286 INFO sentence boundary detection class initiated.
# 2021-04-30 18:42:49,287 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:42:49,287 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/127018.txt ...
# 2021-04-30 18:42:49,306 INFO AnGap
# 2021-04-30 18:42:49,307 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:49,307 INFO AnGap
# 2021-04-30 18:42:49,308 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:49,309 INFO AlkPhos
# 2021-04-30 18:42:49,309 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:42:49,309 INFO TotBili
# 2021-04-30 18:42:49,310 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:42:49,619 INFO sentence boundary detection class initiated.
# 2021-04-30 18:42:49,620 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:42:49,620 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/108950.txt ...
# 2021-04-30 18:42:49,641 INFO AnGap
# 2021-04-30 18:42:49,641 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:49,642 INFO AnGap
# 2021-04-30 18:42:49,642 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:49,643 INFO AnGap
# 2021-04-30 18:42:49,644 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:49,645 INFO NotDone
# 2021-04-30 18:42:49,645 WARNING 'NotDone' => 'Not' 'Done'
# 2021-04-30 18:42:49,646 INFO NotDone
# 2021-04-30 18:42:49,646 WARNING 'NotDone' => 'Not' 'Done'
# 2021-04-30 18:42:49,649 INFO AnGap
# 2021-04-30 18:42:49,649 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:49,650 INFO TotBili
# 2021-04-30 18:42:49,650 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:42:49,650 INFO DirBili
# 2021-04-30 18:42:49,651 WARNING 'DirBili' => 'Dir' 'Bili'
# 2021-04-30 18:42:49,651 INFO IndBili
# 2021-04-30 18:42:49,652 WARNING 'IndBili' => 'Ind' 'Bili'
# 2021-04-30 18:42:50,008 INFO sentence boundary detection class initiated.
# 2021-04-30 18:42:50,008 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:42:50,009 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/149071.txt ...
# 2021-04-30 18:42:50,039 INFO TotProt
# 2021-04-30 18:42:50,040 WARNING 'TotProt' => 'Tot' 'Prot'
# 2021-04-30 18:42:50,041 INFO AnGap
# 2021-04-30 18:42:50,041 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:50,470 INFO sentence boundary detection class initiated.
# 2021-04-30 18:42:50,470 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:42:50,471 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/116011.txt ...
# 2021-04-30 18:42:50,521 WARNING ('1', 'Dosage', (1583, 1584)) offset is overlapped with previous entity; current tok not overlap
# 2021-04-30 18:42:50,522 WARNING ('1', 'Dosage', (2128, 2129)) offset is overlapped with previous entity; current tok not overlap
# 2021-04-30 18:42:50,524 WARNING ('3', 'Dosage', (8340, 8341)) offset is overlapped with previous entity; current tok not overlap
# first index not match  ('1', 'Dosage', (1583, 1584))
# last index not match  ('1', 'Dosage', (1583, 1584))
# first index not match  ('1', 'Dosage', (2128, 2129))
# last index not match  ('1', 'Dosage', (2128, 2129))
# first index not match  ('3', 'Dosage', (8340, 8341))
# last index not match  ('3', 'Dosage', (8340, 8341))
# 2021-04-30 18:42:50,942 INFO sentence boundary detection class initiated.
# 2021-04-30 18:42:50,943 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:42:50,943 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/104549.txt ...
# 2021-04-30 18:42:50,977 INFO AnGap
# 2021-04-30 18:42:50,977 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:50,980 INFO AnGap
# 2021-04-30 18:42:50,981 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:50,981 INFO AnGap
# 2021-04-30 18:42:50,982 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:50,983 INFO AnGap
# 2021-04-30 18:42:50,983 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:50,984 INFO AnGap
# 2021-04-30 18:42:50,985 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:50,986 INFO AnGap
# 2021-04-30 18:42:50,986 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:50,986 INFO AlkPhos
# 2021-04-30 18:42:50,987 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:42:50,987 INFO TotBili
# 2021-04-30 18:42:50,988 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:42:50,988 INFO AlkPhos
# 2021-04-30 18:42:50,989 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:42:50,989 INFO TotBili
# 2021-04-30 18:42:50,989 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:42:51,812 INFO sentence boundary detection class initiated.
# 2021-04-30 18:42:51,812 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:42:51,813 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/164726.txt ...
# 2021-04-30 18:42:51,827 INFO AnGap
# 2021-04-30 18:42:51,827 WARNING 'AnGap' => 'An' 'Gap'
# 2021-04-30 18:42:51,828 INFO AlkPhos
# 2021-04-30 18:42:51,828 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-04-30 18:42:51,829 INFO TotBili
# 2021-04-30 18:42:51,829 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-04-30 18:42:51,922 INFO sentence boundary detection class initiated.
# 2021-04-30 18:42:51,922 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:42:51,922 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/104788.txt ...
# 2021-04-30 18:42:52,059 INFO sentence boundary detection class initiated.
# 2021-04-30 18:42:52,059 INFO word level tokenization with replace_number set to False
# 2021-04-30 18:42:52,060 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/100511.txt ...
# 2021-04-30 18:42:52,075 INFO OxyContin
# 2021-04-30 18:42:52,076 WARNING 'OxyContin' => 'Oxy' 'Contin'
# 2021-04-30 18:42:52,090 WARNING ('in', 'Reason', (4691, 4693)) offset is overlapped with previous entity; current tok not overlap
# first index not match  ('in', 'Reason', (4691, 4693))
# last index not match  ('in', 'Reason', (4691, 4693))

# %%
all_in_one(dpos, dneg, dn="2018n2c2_gs", do_train=False)

# %%
for CUTOFF in range(1,5):
    dpos, dneg = create_training_samples(n2c2_test, n2c2_valid, n2c2_valid_comb)
    all_in_one(dpos, dneg, dn="2018n2c2_gs", do_train=False)
# Out:
# 2021-05-01 11:26:29,219 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:29,220 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:29,220 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/107515.txt ...
# 2021-05-01 11:26:29,242 INFO freeCa
# 2021-05-01 11:26:29,242 WARNING 'freeCa' => 'free' 'Ca'
# 2021-05-01 11:26:29,282 WARNING ('hypergylcemia', 'ADE', (9527, 9540)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:26:29,942 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:29,943 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:29,943 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/155521.txt ...
# 2021-05-01 11:26:29,963 INFO AnGap
# 2021-05-01 11:26:29,963 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:29,964 INFO AlkPhos
# 2021-05-01 11:26:29,964 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:26:29,965 INFO TotBili
# 2021-05-01 11:26:29,965 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:26:30,156 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:30,156 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:30,157 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/152925.txt ...
# 2021-05-01 11:26:30,383 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:30,383 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:30,384 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/146944.txt ...
# 2021-05-01 11:26:30,403 INFO AnGap
# 2021-05-01 11:26:30,404 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:30,404 INFO AlkPhos
# 2021-05-01 11:26:30,405 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:26:30,405 INFO TotBili
# 2021-05-01 11:26:30,406 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:26:30,406 INFO AlkPhos
# 2021-05-01 11:26:30,407 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:26:30,407 INFO TotBili
# 2021-05-01 11:26:30,407 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:26:30,409 INFO LDLcalc
# 2021-05-01 11:26:30,410 WARNING 'LDLcalc' => 'LD' 'Lcalc'
# 2021-05-01 11:26:30,411 INFO freeCa
# 2021-05-01 11:26:30,411 WARNING 'freeCa' => 'free' 'Ca'
# 2021-05-01 11:26:30,440 WARNING ('severe angioedema', 'Reason', (7616, 7633)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:26:30,441 WARNING ('lip and tongue swelling', 'Reason', (7639, 7662)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:26:30,563 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:30,564 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:30,564 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/100130.txt ...
# 2021-05-01 11:26:30,695 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:30,695 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:30,696 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/112520.txt ...
# last index not match  ('p.o', 'Route', (9048, 9051))
# 2021-05-01 11:26:30,876 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:30,877 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:30,877 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/139955.txt ...
# 2021-05-01 11:26:30,899 INFO AnGap
# 2021-05-01 11:26:30,900 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:30,901 INFO AnGap
# 2021-05-01 11:26:30,901 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:30,902 INFO AnGap
# 2021-05-01 11:26:30,903 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:30,904 INFO AnGap
# 2021-05-01 11:26:30,904 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:30,905 INFO AnGap
# 2021-05-01 11:26:30,905 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:30,906 INFO AnGap
# 2021-05-01 11:26:30,906 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:30,907 INFO AnGap
# 2021-05-01 11:26:30,908 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:30,908 INFO AnGap
# 2021-05-01 11:26:30,909 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:30,909 INFO AlkPhos
# 2021-05-01 11:26:30,910 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:26:30,910 INFO TotBili
# 2021-05-01 11:26:30,911 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:26:30,912 INFO AlkPhos
# 2021-05-01 11:26:30,912 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:26:30,913 INFO TotBili
# 2021-05-01 11:26:30,913 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:26:30,914 INFO AlkPhos
# 2021-05-01 11:26:30,914 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:26:30,915 INFO TotBili
# 2021-05-01 11:26:30,915 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:26:31,177 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:31,177 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:31,178 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/110135.txt ...
# 2021-05-01 11:26:31,203 INFO NotDone
# 2021-05-01 11:26:31,204 WARNING 'NotDone' => 'Not' 'Done'
# 2021-05-01 11:26:31,209 INFO qMon
# 2021-05-01 11:26:31,210 WARNING 'qMon' => 'q' 'Mon'
# 2021-05-01 11:26:31,218 INFO NameIs
# 2021-05-01 11:26:31,219 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:26:31,244 WARNING ('1L', 'Dosage', (936, 938)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:26:31,244 ERROR ['LNS', (937, 940), (924, 927), (11, 4)]	('NS', 'Drug', (938, 940)) not matched by their offsets.
# last index not match  ('1L', 'Dosage', (936, 938))
# first index not match  ('NS', 'Drug', (938, 940))
# last index not match  ('NS', 'Drug', (938, 940))
# 2021-05-01 11:26:31,830 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:31,830 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:31,830 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/104140.txt ...
# 2021-05-01 11:26:31,851 INFO AnGap
# 2021-05-01 11:26:31,851 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:31,855 INFO AnGap
# 2021-05-01 11:26:31,855 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:31,856 INFO AnGap
# 2021-05-01 11:26:31,857 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:31,857 INFO AnGap
# 2021-05-01 11:26:31,858 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:31,858 INFO AnGap
# 2021-05-01 11:26:31,859 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:31,859 INFO AlkPhos
# 2021-05-01 11:26:31,860 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:26:31,860 INFO TotBili
# 2021-05-01 11:26:31,861 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:26:32,216 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:32,217 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:32,217 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/104168.txt ...
# 2021-05-01 11:26:32,239 INFO AnGap
# 2021-05-01 11:26:32,239 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:32,240 INFO AlkPhos
# 2021-05-01 11:26:32,240 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:26:32,241 INFO TotBili
# 2021-05-01 11:26:32,241 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:26:32,256 INFO NameIs
# 2021-05-01 11:26:32,257 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:26:32,257 INFO NameIs
# 2021-05-01 11:26:32,258 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:26:32,422 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:32,423 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:32,423 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/116237.txt ...
# 2021-05-01 11:26:32,818 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:32,819 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:32,819 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/109698.txt ...
# 2021-05-01 11:26:32,847 WARNING ('constipation', 'ADE', (2815, 2827)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:26:33,017 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:33,018 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:33,018 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/102068.txt ...
# 2021-05-01 11:26:33,041 INFO AnGap
# 2021-05-01 11:26:33,042 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:33,043 INFO AnGap
# 2021-05-01 11:26:33,043 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:33,044 INFO AlkPhos
# 2021-05-01 11:26:33,044 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:26:33,045 INFO TotBili
# 2021-05-01 11:26:33,045 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:26:33,051 INFO GynOnc
# 2021-05-01 11:26:33,051 WARNING 'GynOnc' => 'Gyn' 'Onc'
# 2021-05-01 11:26:33,057 INFO NameIs
# 2021-05-01 11:26:33,058 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:26:33,360 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:33,361 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:33,361 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/111160.txt ...
# 2021-05-01 11:26:33,392 INFO AnGap
# 2021-05-01 11:26:33,392 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:33,393 INFO AlkPhos
# 2021-05-01 11:26:33,393 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:26:33,394 INFO TotBili
# 2021-05-01 11:26:33,394 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:26:33,395 INFO AlkPhos
# 2021-05-01 11:26:33,395 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:26:33,396 INFO TotBili
# 2021-05-01 11:26:33,396 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:26:33,441 WARNING ('delerium', 'ADE', (12702, 12710)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:26:33,441 WARNING ('insomnia', 'Reason', (12763, 12771)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:26:34,096 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:34,097 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:34,097 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/108343.txt ...
# 2021-05-01 11:26:34,129 INFO freeCa
# 2021-05-01 11:26:34,130 WARNING 'freeCa' => 'free' 'Ca'
# 2021-05-01 11:26:34,132 INFO NotDone
# 2021-05-01 11:26:34,132 WARNING 'NotDone' => 'Not' 'Done'
# 2021-05-01 11:26:34,134 INFO AnGap
# 2021-05-01 11:26:34,134 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:34,142 INFO FeNa
# 2021-05-01 11:26:34,143 WARNING 'FeNa' => 'Fe' 'Na'
# 2021-05-01 11:26:34,221 WARNING ('1', 'Dosage', (11043, 11044)) offset is overlapped with previous entity; current tok not overlap
# first index not match  ('1', 'Dosage', (11043, 11044))
# last index not match  ('1', 'Dosage', (11043, 11044))
# 2021-05-01 11:26:35,021 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:35,022 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:35,022 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/104948.txt ...
# 2021-05-01 11:26:35,048 INFO AnGap
# 2021-05-01 11:26:35,049 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:35,050 INFO NotDone
# 2021-05-01 11:26:35,050 WARNING 'NotDone' => 'Not' 'Done'
# 2021-05-01 11:26:35,051 INFO UricAcd
# 2021-05-01 11:26:35,051 WARNING 'UricAcd' => 'Uric' 'Acd'
# 2021-05-01 11:26:35,053 INFO freeCa
# 2021-05-01 11:26:35,053 WARNING 'freeCa' => 'free' 'Ca'
# 2021-05-01 11:26:35,095 WARNING ('1', 'Dosage', (2094, 2095)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:26:35,095 WARNING ('1', 'Dosage', (2115, 2116)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:26:35,096 WARNING ('1', 'Dosage', (2137, 2138)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:26:35,096 WARNING ('1', 'Dosage', (2164, 2165)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:26:35,098 WARNING ('6weeks', 'Duration', (9073, 9079)) offset is overlapped with previous entity; current tok not overlap
# first index not match  ('1', 'Dosage', (2094, 2095))
# last index not match  ('1', 'Dosage', (2094, 2095))
# first index not match  ('1', 'Dosage', (2115, 2116))
# last index not match  ('1', 'Dosage', (2115, 2116))
# first index not match  ('1', 'Dosage', (2137, 2138))
# last index not match  ('1', 'Dosage', (2137, 2138))
# first index not match  ('1', 'Dosage', (2164, 2165))
# last index not match  ('1', 'Dosage', (2164, 2165))
# first index not match  ('6weeks', 'Duration', (9073, 9079))
# last index not match  ('6weeks', 'Duration', (9073, 9079))
# 2021-05-01 11:26:35,637 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:35,637 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:35,638 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/100509.txt ...
# 2021-05-01 11:26:35,666 INFO AnGap
# 2021-05-01 11:26:35,667 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:35,667 INFO AlkPhos
# 2021-05-01 11:26:35,668 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:26:35,668 INFO TotBili
# 2021-05-01 11:26:35,668 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:26:35,718 WARNING ('3days', 'Duration', (656, 661)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:26:35,897 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:35,897 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:35,898 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/115138.txt ...
# 2021-05-01 11:26:35,932 WARNING ('flushing', 'Reason', (995, 1003)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:26:35,933 WARNING ('periorbital/facial edema', 'Reason', (1005, 1029)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:26:35,933 WARNING ('hives', 'Reason', (1034, 1039)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:26:35,934 WARNING ('flushing', 'Reason', (4723, 4731)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:26:35,935 WARNING ('periorbital/facial edema', 'Reason', (4733, 4757)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:26:35,935 WARNING ('hives', 'Reason', (4763, 4768)) offset is overlapped with previous entity; current tok not overlap
# last index not match  ('D5W', 'Drug', (16036, 16039))
# first index not match  ('3days', 'Duration', (656, 661))
# last index not match  ('3days', 'Duration', (656, 661))
# 2021-05-01 11:26:36,085 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:36,086 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:36,086 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/104021.txt ...
# 2021-05-01 11:26:36,113 INFO AnGap
# 2021-05-01 11:26:36,113 WARNING 'AnGap' => 'An' 'Gap'
# last index not match  ('O2', 'Drug', (2768, 2770))
# 2021-05-01 11:26:36,586 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:36,587 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:36,587 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/109263.txt ...
# 2021-05-01 11:26:36,604 INFO AnGap
# 2021-05-01 11:26:36,605 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:36,605 INFO TotBili
# 2021-05-01 11:26:36,606 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:26:36,608 INFO AnGap
# 2021-05-01 11:26:36,609 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:36,823 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:36,823 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:36,824 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/108816.txt ...
# 2021-05-01 11:26:37,021 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:37,022 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:37,022 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/105088.txt ...
# last index not match  ('q8h', 'Frequency', (3884, 3887))
# 2021-05-01 11:26:37,070 INFO freeCa
# 2021-05-01 11:26:37,070 WARNING 'freeCa' => 'free' 'Ca'
# 2021-05-01 11:26:37,119 INFO NameIs
# 2021-05-01 11:26:37,120 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:26:37,121 INFO NameIs
# 2021-05-01 11:26:37,121 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:26:37,132 INFO NameIs
# 2021-05-01 11:26:37,133 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:26:38,472 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:38,473 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:38,473 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/121116.txt ...
# 2021-05-01 11:26:38,492 INFO AnGap
# 2021-05-01 11:26:38,493 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:38,493 INFO AnGap
# 2021-05-01 11:26:38,494 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:38,495 INFO AlkPhos
# 2021-05-01 11:26:38,495 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:26:38,496 INFO TotBili
# 2021-05-01 11:26:38,496 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:26:38,497 INFO AlkPhos
# 2021-05-01 11:26:38,497 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:26:38,497 INFO TotBili
# 2021-05-01 11:26:38,498 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:26:38,502 INFO NameIs
# 2021-05-01 11:26:38,503 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:26:38,680 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:38,681 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:38,681 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/102903.txt ...
# 2021-05-01 11:26:38,701 INFO NameIs
# 2021-05-01 11:26:38,702 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:26:38,703 INFO NameIs
# 2021-05-01 11:26:38,703 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:26:38,869 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:38,869 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:38,870 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/152311.txt ...
# 2021-05-01 11:26:38,892 INFO AnGap
# 2021-05-01 11:26:38,892 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:38,910 INFO NameIs
# 2021-05-01 11:26:38,910 WARNING 'NameIs' => 'Name' 'Is'
# last index not match  ('I.V', 'Route', (128, 131))
# 2021-05-01 11:26:39,563 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:39,564 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:39,564 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/106967.txt ...
# 2021-05-01 11:26:40,082 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:40,082 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:40,083 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/110731.txt ...
# 2021-05-01 11:26:40,118 INFO AnGap
# 2021-05-01 11:26:40,118 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:40,128 INFO DMFj
# 2021-05-01 11:26:40,129 WARNING 'DMFj' => 'DM' 'Fj'
# 2021-05-01 11:26:40,322 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:40,323 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:40,323 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/103761.txt ...
# 2021-05-01 11:26:40,348 INFO SlHazy
# 2021-05-01 11:26:40,348 WARNING 'SlHazy' => 'Sl' 'Hazy'
# 2021-05-01 11:26:40,366 INFO HYDROmorphone
# 2021-05-01 11:26:40,367 WARNING 'HYDROmorphone' => 'HYDR' 'Omorphone'
# 2021-05-01 11:26:40,400 WARNING ('fluid overload', 'Reason', (10805, 10819)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:26:40,401 WARNING ('neutropenic', 'Reason', (12700, 12711)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:26:41,293 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:41,293 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:41,293 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/185289.txt ...
# 2021-05-01 11:26:41,326 INFO qMonday
# 2021-05-01 11:26:41,326 WARNING 'qMonday' => 'q' 'Monday'
# 2021-05-01 11:26:41,983 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:41,984 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:41,984 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/106369.txt ...
# 2021-05-01 11:26:42,281 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:42,282 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:42,282 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/126085.txt ...
# 2021-05-01 11:26:42,317 INFO AnGap
# 2021-05-01 11:26:42,318 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:42,318 INFO AnGap
# 2021-05-01 11:26:42,319 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:42,319 INFO AnGap
# 2021-05-01 11:26:42,320 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:42,320 INFO AnGap
# 2021-05-01 11:26:42,321 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:42,322 INFO AnGap
# 2021-05-01 11:26:42,322 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:42,323 INFO AnGap
# 2021-05-01 11:26:42,323 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:42,324 INFO AnGap
# 2021-05-01 11:26:42,324 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:42,325 INFO AnGap
# 2021-05-01 11:26:42,326 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:42,326 INFO AnGap
# 2021-05-01 11:26:42,327 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:42,327 INFO AnGap
# 2021-05-01 11:26:42,328 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:42,328 INFO AnGap
# 2021-05-01 11:26:42,329 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:42,330 INFO TotBili
# 2021-05-01 11:26:42,330 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:26:42,331 INFO DirBili
# 2021-05-01 11:26:42,331 WARNING 'DirBili' => 'Dir' 'Bili'
# 2021-05-01 11:26:42,331 INFO IndBili
# 2021-05-01 11:26:42,332 WARNING 'IndBili' => 'Ind' 'Bili'
# 2021-05-01 11:26:42,333 INFO NotDone
# 2021-05-01 11:26:42,333 WARNING 'NotDone' => 'Not' 'Done'
# 2021-05-01 11:26:42,339 INFO freeCa
# 2021-05-01 11:26:42,340 WARNING 'freeCa' => 'free' 'Ca'
# 2021-05-01 11:26:42,341 INFO freeCa
# 2021-05-01 11:26:42,341 WARNING 'freeCa' => 'free' 'Ca'
# 2021-05-01 11:26:42,342 INFO freeCa
# 2021-05-01 11:26:42,342 WARNING 'freeCa' => 'free' 'Ca'
# 2021-05-01 11:26:42,343 INFO freeCa
# 2021-05-01 11:26:42,343 WARNING 'freeCa' => 'free' 'Ca'
# 2021-05-01 11:26:42,344 INFO freeCa
# 2021-05-01 11:26:42,344 WARNING 'freeCa' => 'free' 'Ca'
# 2021-05-01 11:26:42,353 INFO QACHSInsulin
# 2021-05-01 11:26:42,353 WARNING 'QACHSInsulin' => 'QACHS' 'Insulin'
# 2021-05-01 11:26:42,356 INFO NameIs
# 2021-05-01 11:26:42,356 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:26:42,378 WARNING ('HIT', 'ADE', (1014, 1017)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:26:42,808 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:42,808 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:42,809 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/112446.txt ...
# 2021-05-01 11:26:42,959 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:42,960 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:42,960 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/113348.txt ...
# 2021-05-01 11:26:42,987 INFO NameIs
# 2021-05-01 11:26:42,988 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:26:42,989 INFO NameIs
# 2021-05-01 11:26:42,989 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:26:43,201 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:43,202 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:43,202 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/106792.txt ...
# 2021-05-01 11:26:43,223 INFO AnGap
# 2021-05-01 11:26:43,224 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:43,225 INFO AnGap
# 2021-05-01 11:26:43,225 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:43,226 INFO AnGap
# 2021-05-01 11:26:43,226 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:43,533 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:43,533 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:43,533 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/174339.txt ...
# 2021-05-01 11:26:43,743 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:43,744 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:43,744 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/102913.txt ...
# 2021-05-01 11:26:43,762 INFO CoreValve
# 2021-05-01 11:26:43,763 WARNING 'CoreValve' => 'Core' 'Valve'
# 2021-05-01 11:26:43,764 INFO CoreValve
# 2021-05-01 11:26:43,765 WARNING 'CoreValve' => 'Core' 'Valve'
# 2021-05-01 11:26:43,771 INFO AnGap
# 2021-05-01 11:26:43,772 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:43,773 INFO AlkPhos
# 2021-05-01 11:26:43,773 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:26:43,774 INFO TotBili
# 2021-05-01 11:26:43,774 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:26:43,776 INFO AnGap
# 2021-05-01 11:26:43,776 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:43,780 INFO CoreValve
# 2021-05-01 11:26:43,781 WARNING 'CoreValve' => 'Core' 'Valve'
# 2021-05-01 11:26:43,782 INFO CoreValve
# 2021-05-01 11:26:43,782 WARNING 'CoreValve' => 'Core' 'Valve'
# 2021-05-01 11:26:43,784 INFO CoreValve
# 2021-05-01 11:26:43,785 WARNING 'CoreValve' => 'Core' 'Valve'
# 2021-05-01 11:26:43,787 INFO CoreValve
# 2021-05-01 11:26:43,787 WARNING 'CoreValve' => 'Core' 'Valve'
# 2021-05-01 11:26:43,787 INFO CoreValve
# 2021-05-01 11:26:43,788 WARNING 'CoreValve' => 'Core' 'Valve'
# 2021-05-01 11:26:43,789 INFO CoreValve
# 2021-05-01 11:26:43,790 WARNING 'CoreValve' => 'Core' 'Valve'
# 2021-05-01 11:26:43,791 INFO CoreValve
# 2021-05-01 11:26:43,792 WARNING 'CoreValve' => 'Core' 'Valve'
# 2021-05-01 11:26:43,797 INFO CoreValve
# 2021-05-01 11:26:43,797 WARNING 'CoreValve' => 'Core' 'Valve'
# 2021-05-01 11:26:44,021 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:44,021 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:44,022 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/105885.txt ...
# 2021-05-01 11:26:44,120 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:44,120 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:44,121 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/147452.txt ...
# 2021-05-01 11:26:44,134 INFO cryoMaze
# 2021-05-01 11:26:44,134 WARNING 'cryoMaze' => 'cryo' 'Maze'
# 2021-05-01 11:26:44,138 INFO AnGap
# 2021-05-01 11:26:44,139 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:44,139 INFO AlkPhos
# 2021-05-01 11:26:44,140 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:26:44,140 INFO TotBili
# 2021-05-01 11:26:44,141 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:26:44,142 INFO LDLmeas
# 2021-05-01 11:26:44,142 WARNING 'LDLmeas' => 'LD' 'Lmeas'
# 2021-05-01 11:26:44,151 INFO CareGroup
# 2021-05-01 11:26:44,152 WARNING 'CareGroup' => 'Care' 'Group'
# last index not match  ('b.i.d', 'Frequency', (4471, 4476))
# 2021-05-01 11:26:44,376 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:44,377 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:44,377 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/115466.txt ...
# 2021-05-01 11:26:44,402 INFO AnGap
# 2021-05-01 11:26:44,403 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:44,404 INFO AnGap
# 2021-05-01 11:26:44,404 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:44,405 INFO AnGap
# 2021-05-01 11:26:44,406 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:44,684 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:44,685 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:44,685 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/101161.txt ...
# 2021-05-01 11:26:44,859 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:44,859 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:44,859 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/105475.txt ...
# 2021-05-01 11:26:45,106 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:45,107 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:45,107 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/104757.txt ...
# 2021-05-01 11:26:45,139 INFO freeCa
# 2021-05-01 11:26:45,140 WARNING 'freeCa' => 'free' 'Ca'
# 2021-05-01 11:26:45,142 INFO AlkPhos
# 2021-05-01 11:26:45,142 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:26:45,143 INFO TotBili
# 2021-05-01 11:26:45,143 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:26:45,144 INFO freeCa
# 2021-05-01 11:26:45,145 WARNING 'freeCa' => 'free' 'Ca'
# 2021-05-01 11:26:45,146 INFO AnGap
# 2021-05-01 11:26:45,146 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:45,189 WARNING ('1', 'Dosage', (3063, 3064)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:26:45,189 WARNING ('1', 'Dosage', (3087, 3088)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:26:45,190 WARNING ('1', 'Dosage', (3107, 3108)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:26:45,190 WARNING ('1', 'Dosage', (3138, 3139)) offset is overlapped with previous entity; current tok not overlap
# first index not match  ('1', 'Dosage', (3063, 3064))
# last index not match  ('1', 'Dosage', (3063, 3064))
# first index not match  ('1', 'Dosage', (3087, 3088))
# last index not match  ('1', 'Dosage', (3087, 3088))
# first index not match  ('1', 'Dosage', (3107, 3108))
# last index not match  ('1', 'Dosage', (3107, 3108))
# first index not match  ('1', 'Dosage', (3138, 3139))
# last index not match  ('1', 'Dosage', (3138, 3139))
# 2021-05-01 11:26:45,621 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:45,621 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:45,622 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/156777.txt ...
# 2021-05-01 11:26:45,641 INFO AnGap
# 2021-05-01 11:26:45,642 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:45,643 INFO AlkPhos
# 2021-05-01 11:26:45,643 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:26:45,643 INFO TotBili
# 2021-05-01 11:26:45,644 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:26:45,762 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:45,763 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:45,763 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/151232.txt ...
# 2021-05-01 11:26:45,802 INFO NameIs
# 2021-05-01 11:26:45,803 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:26:45,803 INFO NameIs
# 2021-05-01 11:26:45,803 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:26:46,023 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:46,023 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:46,023 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/112445.txt ...
# 2021-05-01 11:26:46,058 INFO AnGap
# 2021-05-01 11:26:46,058 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:46,059 INFO TotBili
# 2021-05-01 11:26:46,059 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:26:46,060 INFO NotDone
# 2021-05-01 11:26:46,060 WARNING 'NotDone' => 'Not' 'Done'
# 2021-05-01 11:26:46,061 INFO NotDone
# 2021-05-01 11:26:46,061 WARNING 'NotDone' => 'Not' 'Done'
# 2021-05-01 11:26:46,062 INFO AnGap
# 2021-05-01 11:26:46,063 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:46,662 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:46,663 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:46,663 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/121702.txt ...
# 2021-05-01 11:26:46,820 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:46,821 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:46,821 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/122223.txt ...
# 2021-05-01 11:26:46,846 INFO IIIa
# 2021-05-01 11:26:46,847 WARNING 'IIIa' => 'II' 'Ia'
# 2021-05-01 11:26:47,027 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:47,027 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:47,027 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/113607.txt ...
# 2021-05-01 11:26:47,055 INFO NameIs
# 2021-05-01 11:26:47,056 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:26:47,541 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:47,542 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:47,542 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/114626.txt ...
# 2021-05-01 11:26:47,806 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:47,806 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:47,807 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/107128.txt ...
# 2021-05-01 11:26:47,861 WARNING ('Upper GI bleed', 'Reason', (6842, 6856)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:26:48,221 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:48,221 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:48,222 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/104390.txt ...
# 2021-05-01 11:26:48,370 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:48,371 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:48,371 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/172206.txt ...
# 2021-05-01 11:26:48,385 INFO wAs
# 2021-05-01 11:26:48,386 WARNING 'wAs' => 'w' 'As'
# 2021-05-01 11:26:48,401 INFO NameIs
# 2021-05-01 11:26:48,402 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:26:48,402 INFO NameIs
# 2021-05-01 11:26:48,402 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:26:48,555 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:48,556 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:48,556 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/106961.txt ...
# 2021-05-01 11:26:48,581 INFO AnGap
# 2021-05-01 11:26:48,582 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:48,582 INFO AlkPhos
# 2021-05-01 11:26:48,583 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:26:48,583 INFO TotBili
# 2021-05-01 11:26:48,584 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:26:48,585 INFO AnGap
# 2021-05-01 11:26:48,586 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:48,587 INFO AnGap
# 2021-05-01 11:26:48,587 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:48,588 INFO AnGap
# 2021-05-01 11:26:48,588 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:48,589 INFO AnGap
# 2021-05-01 11:26:48,589 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:48,590 INFO AnGap
# 2021-05-01 11:26:48,590 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:48,591 INFO AlkPhos
# 2021-05-01 11:26:48,591 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:26:48,592 INFO TotBili
# 2021-05-01 11:26:48,592 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:26:48,593 INFO AlkPhos
# 2021-05-01 11:26:48,594 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:26:48,594 INFO TotBili
# 2021-05-01 11:26:48,595 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:26:48,595 INFO AlkPhos
# 2021-05-01 11:26:48,596 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:26:48,596 INFO TotBili
# 2021-05-01 11:26:48,597 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:26:48,597 INFO AlkPhos
# 2021-05-01 11:26:48,598 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:26:48,598 INFO TotBili
# 2021-05-01 11:26:48,599 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:26:48,599 INFO AlkPhos
# 2021-05-01 11:26:48,600 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:26:48,600 INFO TotBili
# 2021-05-01 11:26:48,601 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:26:48,601 INFO AlkPhos
# 2021-05-01 11:26:48,602 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:26:48,602 INFO TotBili
# 2021-05-01 11:26:48,603 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:26:48,604 INFO AnGap
# 2021-05-01 11:26:48,605 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:48,618 INFO NameIs
# 2021-05-01 11:26:48,619 WARNING 'NameIs' => 'Name' 'Is'
# last index not match  ('p.o', 'Route', (9050, 9053))
# last index not match  ('p.o', 'Route', (9106, 9109))
# 2021-05-01 11:26:48,932 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:48,932 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:48,933 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/121663.txt ...
# 2021-05-01 11:26:48,954 INFO AlkPhos
# 2021-05-01 11:26:48,954 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:26:48,955 INFO NotDone
# 2021-05-01 11:26:48,956 WARNING 'NotDone' => 'Not' 'Done'
# 2021-05-01 11:26:49,195 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:49,195 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:49,196 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/102051.txt ...
# 2021-05-01 11:26:49,212 INFO AnGap
# 2021-05-01 11:26:49,213 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:49,213 INFO AlkPhos
# 2021-05-01 11:26:49,214 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:26:49,214 INFO TotBili
# 2021-05-01 11:26:49,215 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:26:49,360 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:49,361 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:49,361 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/139825.txt ...
# 2021-05-01 11:26:49,425 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:49,425 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:49,426 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/122090.txt ...
# 2021-05-01 11:26:49,456 WARNING ('V', 'Route', (3232, 3233)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:26:49,519 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:49,519 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:49,520 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/113265.txt ...
# 2021-05-01 11:26:49,556 INFO AnGap
# 2021-05-01 11:26:49,556 WARNING 'AnGap' => 'An' 'Gap'
# first index not match  ('V', 'Route', (3232, 3233))
# last index not match  ('V', 'Route', (3232, 3233))
# 2021-05-01 11:26:50,313 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:50,314 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:50,314 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/115199.txt ...
# 2021-05-01 11:26:50,343 INFO AnGap
# 2021-05-01 11:26:50,344 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:50,350 INFO NameIs
# 2021-05-01 11:26:50,350 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:26:50,442 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:50,443 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:50,443 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/105605.txt ...
# 2021-05-01 11:26:50,472 INFO AnGap
# 2021-05-01 11:26:50,473 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:50,473 INFO AnGap
# 2021-05-01 11:26:50,474 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:50,475 INFO AnGap
# 2021-05-01 11:26:50,475 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:50,476 INFO AnGap
# 2021-05-01 11:26:50,476 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:50,477 INFO AnGap
# 2021-05-01 11:26:50,477 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:50,478 INFO AnGap
# 2021-05-01 11:26:50,479 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:50,479 INFO AnGap
# 2021-05-01 11:26:50,480 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:50,480 INFO AnGap
# 2021-05-01 11:26:50,481 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:50,481 INFO AnGap
# 2021-05-01 11:26:50,482 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:50,483 INFO AlkPhos
# 2021-05-01 11:26:50,483 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:26:50,483 INFO TotBili
# 2021-05-01 11:26:50,484 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:26:50,484 INFO AlkPhos
# 2021-05-01 11:26:50,485 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:26:50,485 INFO TotBili
# 2021-05-01 11:26:50,486 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:26:50,486 INFO AlkPhos
# 2021-05-01 11:26:50,486 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:26:50,487 INFO TotBili
# 2021-05-01 11:26:50,487 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:26:50,488 INFO AlkPhos
# 2021-05-01 11:26:50,488 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:26:50,489 INFO TotBili
# 2021-05-01 11:26:50,489 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:26:50,492 INFO LDLcalc
# 2021-05-01 11:26:50,493 WARNING 'LDLcalc' => 'LD' 'Lcalc'
# 2021-05-01 11:26:50,826 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:50,827 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:50,827 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/113852.txt ...
# 2021-05-01 11:26:50,840 INFO AnGap
# 2021-05-01 11:26:50,841 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:50,954 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:50,955 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:50,955 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/111274.txt ...
# 2021-05-01 11:26:50,987 INFO AnGap
# 2021-05-01 11:26:50,988 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:50,988 INFO UricAcd
# 2021-05-01 11:26:50,989 WARNING 'UricAcd' => 'Uric' 'Acd'
# 2021-05-01 11:26:51,014 INFO NameIs
# 2021-05-01 11:26:51,015 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:26:51,410 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:51,411 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:51,411 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/123204.txt ...
# 2021-05-01 11:26:51,434 INFO AnGap
# 2021-05-01 11:26:51,435 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:51,435 INFO AlkPhos
# 2021-05-01 11:26:51,436 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:26:51,436 INFO TotBili
# 2021-05-01 11:26:51,437 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:26:51,437 INFO DirBili
# 2021-05-01 11:26:51,437 WARNING 'DirBili' => 'Dir' 'Bili'
# 2021-05-01 11:26:51,438 INFO IndBili
# 2021-05-01 11:26:51,438 WARNING 'IndBili' => 'Ind' 'Bili'
# 2021-05-01 11:26:51,591 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:51,592 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:51,592 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/101099.txt ...
# 2021-05-01 11:26:51,608 INFO AnGap
# 2021-05-01 11:26:51,609 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:51,610 INFO AnGap
# 2021-05-01 11:26:51,610 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:51,871 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:51,872 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:51,872 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/116903.txt ...
# 2021-05-01 11:26:52,072 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:52,072 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:52,073 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/104446.txt ...
# 2021-05-01 11:26:52,102 INFO FeUrea
# 2021-05-01 11:26:52,103 WARNING 'FeUrea' => 'Fe' 'Urea'
# 2021-05-01 11:26:52,131 WARNING ('HYPERKALEMIA', 'Reason', (8979, 8991)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:26:52,606 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:52,607 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:52,607 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/196911.txt ...
# 2021-05-01 11:26:52,880 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:52,881 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:52,881 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/112350.txt ...
# 2021-05-01 11:26:53,116 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:53,116 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:53,117 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/102357.txt ...
# 2021-05-01 11:26:53,146 INFO NameIs
# 2021-05-01 11:26:53,146 WARNING 'NameIs' => 'Name' 'Is'
# first index not match  ('2 days', 'Duration', (6424, 6430))
# last index not match  ('O2', 'Drug', (3123, 3125))
# 2021-05-01 11:26:53,400 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:53,401 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:53,401 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/110753.txt ...
# 2021-05-01 11:26:53,426 INFO AnGap
# 2021-05-01 11:26:53,426 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:53,427 INFO TotProt
# 2021-05-01 11:26:53,427 WARNING 'TotProt' => 'Tot' 'Prot'
# 2021-05-01 11:26:53,429 INFO RheuFac
# 2021-05-01 11:26:53,429 WARNING 'RheuFac' => 'Rheu' 'Fac'
# 2021-05-01 11:26:53,903 INFO sentence boundary detection class initiated.
# 2021-05-01 11:26:53,903 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:26:53,904 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/101110.txt ...
# 2021-05-01 11:26:53,927 INFO AnGap
# 2021-05-01 11:26:53,928 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:53,929 INFO AnGap
# 2021-05-01 11:26:53,929 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:53,930 INFO AnGap
# 2021-05-01 11:26:53,931 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:53,931 INFO AnGap
# 2021-05-01 11:26:53,932 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:26:53,933 INFO AlkPhos
# 2021-05-01 11:26:53,933 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:26:53,934 INFO TotBili
# 2021-05-01 11:26:53,934 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:26:53,935 INFO DirBili
# 2021-05-01 11:26:53,935 WARNING 'DirBili' => 'Dir' 'Bili'
# 2021-05-01 11:26:53,935 INFO IndBili
# 2021-05-01 11:26:53,936 WARNING 'IndBili' => 'Ind' 'Bili'
# 2021-05-01 11:26:53,936 INFO AlkPhos
# 2021-05-01 11:26:53,937 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:26:53,937 INFO TotBili
# 2021-05-01 11:26:53,938 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:26:53,941 INFO freeCa
# 2021-05-01 11:26:53,942 WARNING 'freeCa' => 'free' 'Ca'
# 2021-05-01 11:26:53,942 INFO freeCa
# 2021-05-01 11:26:53,943 WARNING 'freeCa' => 'free' 'Ca'
# 2021-05-01 11:26:53,943 INFO freeCa
# ...
# 2021-05-01 11:31:09,263 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:31:09,264 INFO TotBili
# 2021-05-01 11:31:09,264 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:31:09,265 INFO DirBili
# 2021-05-01 11:31:09,265 WARNING 'DirBili' => 'Dir' 'Bili'
# 2021-05-01 11:31:09,265 INFO IndBili
# 2021-05-01 11:31:09,266 WARNING 'IndBili' => 'Ind' 'Bili'
# 2021-05-01 11:31:09,267 INFO AlkPhos
# 2021-05-01 11:31:09,267 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:31:09,268 INFO TotBili
# 2021-05-01 11:31:09,268 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:31:09,268 INFO AlkPhos
# 2021-05-01 11:31:09,269 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:31:09,269 INFO TotBili
# 2021-05-01 11:31:09,270 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:31:09,270 INFO AnGap
# 2021-05-01 11:31:09,271 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:31:09,271 INFO AnGap
# 2021-05-01 11:31:09,272 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:31:09,272 INFO AnGap
# 2021-05-01 11:31:09,273 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:31:09,275 INFO TotProt
# 2021-05-01 11:31:09,276 WARNING 'TotProt' => 'Tot' 'Prot'
# 2021-05-01 11:31:09,276 INFO TotProt
# 2021-05-01 11:31:09,277 WARNING 'TotProt' => 'Tot' 'Prot'
# 2021-05-01 11:31:09,316 WARNING ('steroids', 'Drug', (14019, 14027)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:31:09,574 INFO sentence boundary detection class initiated.
# 2021-05-01 11:31:09,575 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:31:09,575 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/101786.txt ...
# 2021-05-01 11:31:09,592 INFO AnGap
# 2021-05-01 11:31:09,593 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:31:09,619 WARNING ('shortness of breat', 'Reason', (6561, 6579)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:31:09,866 INFO sentence boundary detection class initiated.
# 2021-05-01 11:31:09,867 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:31:09,867 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/109330.txt ...
# last index not match  ('shortness of breat', 'Reason', (6561, 6579))
# 2021-05-01 11:31:09,887 INFO AnGap
# 2021-05-01 11:31:09,887 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:31:09,903 INFO NameIs
# 2021-05-01 11:31:09,903 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:31:09,904 INFO NameIs
# 2021-05-01 11:31:09,904 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:31:10,098 INFO sentence boundary detection class initiated.
# 2021-05-01 11:31:10,099 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:31:10,099 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/116204.txt ...
# 2021-05-01 11:31:10,124 INFO hypertensionShe
# 2021-05-01 11:31:10,125 WARNING 'hypertensionShe' => 'hypertension' 'She'
# 2021-05-01 11:31:10,148 WARNING ('hypotensive', 'Reason', (8810, 8821)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:31:10,615 INFO sentence boundary detection class initiated.
# 2021-05-01 11:31:10,615 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:31:10,616 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/110891.txt ...
# 2021-05-01 11:31:10,632 INFO AnGap
# 2021-05-01 11:31:10,633 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:31:10,640 INFO NameIs
# 2021-05-01 11:31:10,641 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:31:10,642 INFO NameIs
# 2021-05-01 11:31:10,642 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:31:10,643 INFO NameIs
# 2021-05-01 11:31:10,643 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:31:10,659 WARNING ('2u', 'Dosage', (5293, 5295)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:31:10,660 ERROR ['uFFP', (5294, 5298), (5429, 5433), (73, 5)]	('FFP', 'Drug', (5295, 5298)) not matched by their offsets.
# 2021-05-01 11:31:10,660 WARNING ('2u', 'Dosage', (5351, 5353)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:31:10,660 ERROR ['uPRBC', (5352, 5357), (5485, 5490), (74, 3)]	('PRBC', 'Drug', (5353, 5357)) not matched by their offsets.
# 2021-05-01 11:31:10,870 INFO sentence boundary detection class initiated.
# 2021-05-01 11:31:10,871 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:31:10,871 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/113963.txt ...
# 2021-05-01 11:31:10,898 INFO AnGap
# 2021-05-01 11:31:10,899 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:31:10,900 INFO NotDone
# 2021-05-01 11:31:10,900 WARNING 'NotDone' => 'Not' 'Done'
# 2021-05-01 11:31:10,902 INFO AnGap
# 2021-05-01 11:31:10,903 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:31:10,917 INFO NameIs
# last index not match  ('2u', 'Dosage', (5293, 5295))
# first index not match  ('FFP', 'Drug', (5295, 5298))
# last index not match  ('FFP', 'Drug', (5295, 5298))
# last index not match  ('2u', 'Dosage', (5351, 5353))
# first index not match  ('PRBC', 'Drug', (5353, 5357))
# last index not match  ('PRBC', 'Drug', (5353, 5357))
# 2021-05-01 11:31:10,917 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:31:10,952 WARNING ('lasix', 'Drug', (15225, 15230)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:31:11,755 INFO sentence boundary detection class initiated.
# 2021-05-01 11:31:11,756 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:31:11,761 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/107902.txt ...
# 2021-05-01 11:31:11,886 INFO sentence boundary detection class initiated.
# 2021-05-01 11:31:11,887 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:31:11,887 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/106349.txt ...
# 2021-05-01 11:31:11,916 INFO AnGap
# 2021-05-01 11:31:11,917 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:31:11,918 INFO AlkPhos
# 2021-05-01 11:31:11,918 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:31:11,918 INFO TotBili
# 2021-05-01 11:31:11,919 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:31:11,920 INFO AnGap
# 2021-05-01 11:31:11,921 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:31:11,922 INFO AlkPhos
# 2021-05-01 11:31:11,922 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:31:11,922 INFO TotBili
# 2021-05-01 11:31:11,923 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:31:11,923 INFO UricAcd
# 2021-05-01 11:31:11,924 WARNING 'UricAcd' => 'Uric' 'Acd'
# 2021-05-01 11:31:11,932 INFO OxyContin
# 2021-05-01 11:31:11,932 WARNING 'OxyContin' => 'Oxy' 'Contin'
# 2021-05-01 11:31:11,933 INFO OxyContin
# 2021-05-01 11:31:11,933 WARNING 'OxyContin' => 'Oxy' 'Contin'
# 2021-05-01 11:31:11,935 INFO AndroGel
# 2021-05-01 11:31:11,935 WARNING 'AndroGel' => 'Andro' 'Gel'
# last index not match  ('p.o', 'Route', (5493, 5496))
# last index not match  ('p.o', 'Route', (5555, 5558))
# last index not match  ('p.o', 'Route', (5625, 5628))
# last index not match  ('p.o', 'Route', (6209, 6212))
# 2021-05-01 11:31:12,646 INFO sentence boundary detection class initiated.
# 2021-05-01 11:31:12,647 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:31:12,647 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/198207.txt ...
# 2021-05-01 11:31:12,836 INFO sentence boundary detection class initiated.
# 2021-05-01 11:31:12,837 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:31:12,837 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/113222.txt ...
# 2021-05-01 11:31:12,862 INFO AnGap
# 2021-05-01 11:31:12,863 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:31:12,875 INFO NameIs
# 2021-05-01 11:31:12,876 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:31:12,877 INFO NameIs
# 2021-05-01 11:31:12,877 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:31:12,878 INFO NameIs
# 2021-05-01 11:31:12,878 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:31:12,900 WARNING ('pressure dropped', 'Reason', (1547, 1563)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:31:12,902 WARNING ('angioedema', 'Reason', (7153, 7163)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:31:13,207 INFO sentence boundary detection class initiated.
# 2021-05-01 11:31:13,207 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:31:13,208 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/124465.txt ...
# 2021-05-01 11:31:13,331 INFO sentence boundary detection class initiated.
# 2021-05-01 11:31:13,331 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:31:13,331 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/139178.txt ...
# 2021-05-01 11:31:13,352 INFO AnGap
# 2021-05-01 11:31:13,352 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:31:13,353 INFO AlkPhos
# 2021-05-01 11:31:13,353 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:31:13,354 INFO TotBili
# 2021-05-01 11:31:13,354 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:31:13,355 INFO AlkPhos
# 2021-05-01 11:31:13,355 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:31:13,356 INFO TotBili
# 2021-05-01 11:31:13,356 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:31:13,357 INFO TotProt
# 2021-05-01 11:31:13,357 WARNING 'TotProt' => 'Tot' 'Prot'
# 2021-05-01 11:31:13,560 INFO sentence boundary detection class initiated.
# 2021-05-01 11:31:13,560 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:31:13,561 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/106015.txt ...
# 2021-05-01 11:31:13,588 INFO NameIs
# 2021-05-01 11:31:13,589 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:31:13,589 INFO NameIs
# 2021-05-01 11:31:13,590 WARNING 'NameIs' => 'Name' 'Is'
# 2021-05-01 11:31:13,599 INFO AnGap
# 2021-05-01 11:31:13,599 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:31:13,651 WARNING ('Diarrhea', 'Reason', (15355, 15363)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:31:14,507 INFO sentence boundary detection class initiated.
# 2021-05-01 11:31:14,508 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:31:14,508 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/127018.txt ...
# 2021-05-01 11:31:14,527 INFO AnGap
# 2021-05-01 11:31:14,528 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:31:14,528 INFO AnGap
# 2021-05-01 11:31:14,529 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:31:14,529 INFO AlkPhos
# 2021-05-01 11:31:14,530 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:31:14,530 INFO TotBili
# 2021-05-01 11:31:14,531 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:31:14,842 INFO sentence boundary detection class initiated.
# 2021-05-01 11:31:14,843 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:31:14,843 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/108950.txt ...
# 2021-05-01 11:31:14,867 INFO AnGap
# 2021-05-01 11:31:14,868 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:31:14,868 INFO AnGap
# 2021-05-01 11:31:14,869 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:31:14,870 INFO AnGap
# 2021-05-01 11:31:14,870 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:31:14,871 INFO NotDone
# 2021-05-01 11:31:14,872 WARNING 'NotDone' => 'Not' 'Done'
# 2021-05-01 11:31:14,872 INFO NotDone
# 2021-05-01 11:31:14,873 WARNING 'NotDone' => 'Not' 'Done'
# 2021-05-01 11:31:14,876 INFO AnGap
# 2021-05-01 11:31:14,876 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:31:14,877 INFO TotBili
# 2021-05-01 11:31:14,877 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:31:14,878 INFO DirBili
# 2021-05-01 11:31:14,878 WARNING 'DirBili' => 'Dir' 'Bili'
# 2021-05-01 11:31:14,878 INFO IndBili
# 2021-05-01 11:31:14,879 WARNING 'IndBili' => 'Ind' 'Bili'
# 2021-05-01 11:31:15,233 INFO sentence boundary detection class initiated.
# 2021-05-01 11:31:15,234 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:31:15,234 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/149071.txt ...
# 2021-05-01 11:31:15,266 INFO TotProt
# 2021-05-01 11:31:15,267 WARNING 'TotProt' => 'Tot' 'Prot'
# 2021-05-01 11:31:15,268 INFO AnGap
# 2021-05-01 11:31:15,269 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:31:15,693 INFO sentence boundary detection class initiated.
# 2021-05-01 11:31:15,694 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:31:15,694 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/116011.txt ...
# 2021-05-01 11:31:15,749 WARNING ('1', 'Dosage', (1583, 1584)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:31:15,749 WARNING ('1', 'Dosage', (2128, 2129)) offset is overlapped with previous entity; current tok not overlap
# 2021-05-01 11:31:15,751 WARNING ('3', 'Dosage', (8340, 8341)) offset is overlapped with previous entity; current tok not overlap
# first index not match  ('1', 'Dosage', (1583, 1584))
# last index not match  ('1', 'Dosage', (1583, 1584))
# first index not match  ('1', 'Dosage', (2128, 2129))
# last index not match  ('1', 'Dosage', (2128, 2129))
# first index not match  ('3', 'Dosage', (8340, 8341))
# last index not match  ('3', 'Dosage', (8340, 8341))
# 2021-05-01 11:31:16,174 INFO sentence boundary detection class initiated.
# 2021-05-01 11:31:16,175 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:31:16,175 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/104549.txt ...
# 2021-05-01 11:31:16,212 INFO AnGap
# 2021-05-01 11:31:16,212 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:31:16,216 INFO AnGap
# 2021-05-01 11:31:16,217 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:31:16,218 INFO AnGap
# 2021-05-01 11:31:16,218 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:31:16,219 INFO AnGap
# 2021-05-01 11:31:16,219 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:31:16,220 INFO AnGap
# 2021-05-01 11:31:16,220 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:31:16,221 INFO AnGap
# 2021-05-01 11:31:16,221 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:31:16,222 INFO AlkPhos
# 2021-05-01 11:31:16,222 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:31:16,223 INFO TotBili
# 2021-05-01 11:31:16,223 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:31:16,224 INFO AlkPhos
# 2021-05-01 11:31:16,224 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:31:16,225 INFO TotBili
# 2021-05-01 11:31:16,225 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:31:17,050 INFO sentence boundary detection class initiated.
# 2021-05-01 11:31:17,051 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:31:17,051 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/164726.txt ...
# 2021-05-01 11:31:17,065 INFO AnGap
# 2021-05-01 11:31:17,066 WARNING 'AnGap' => 'An' 'Gap'
# 2021-05-01 11:31:17,066 INFO AlkPhos
# 2021-05-01 11:31:17,067 WARNING 'AlkPhos' => 'Alk' 'Phos'
# 2021-05-01 11:31:17,067 INFO TotBili
# 2021-05-01 11:31:17,068 WARNING 'TotBili' => 'Tot' 'Bili'
# 2021-05-01 11:31:17,166 INFO sentence boundary detection class initiated.
# 2021-05-01 11:31:17,167 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:31:17,167 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/104788.txt ...
# 2021-05-01 11:31:17,306 INFO sentence boundary detection class initiated.
# 2021-05-01 11:31:17,306 INFO word level tokenization with replace_number set to False
# 2021-05-01 11:31:17,307 INFO current processing /Users/alexgre/workspace/data/2018_n2c2_ade/gold_standard_test/100511.txt ...
# 2021-05-01 11:31:17,323 INFO OxyContin
# 2021-05-01 11:31:17,323 WARNING 'OxyContin' => 'Oxy' 'Contin'
# 2021-05-01 11:31:17,338 WARNING ('in', 'Reason', (4691, 4693)) offset is overlapped with previous entity; current tok not overlap
# first index not match  ('in', 'Reason', (4691, 4693))
# last index not match  ('in', 'Reason', (4691, 4693))

# %%
all_in_unique(dpos, dneg, dn="2018n2c2_gs", do_train=False)

# %% [markdown]
# ## umass

# %%
umass_valid = {
 'adverse', 'do', 'du', 'fr', 'reason', 'severity_type', 'Not-Rel', 'manner/route'
}

umass_valid_comb_en = {
    ('Drug', 'Dose'), ('Drug', 'Duration'), ('Drug', 'Frequency'), ('Drug', 'Route'),
    ('Drug', 'ADE'), ('Drug', 'Indication'), ('SSLIF', 'Severity'), ('ADE', 'Severity'),
    ('Indication', 'Severity')
}

# %%
entp2rel = {
    ('Drug', 'Dose'): 'do', 
    ('Drug', 'Duration'): 'du', 
    ('Drug', 'Frequency'): 'fr', 
    ('Drug', 'Route'): 'manner/route',
    ('Drug', 'ADE'): 'adverse', 
    ('Drug', 'Indication'): 'reason', 
    ('SSLIF', 'Severity'): 'severity_type', 
    ('ADE', 'Severity'): 'severity_type',
    ('Indication', 'Severity'): 'severity_type'
}

entp2rel, entp2rel[('Drug', 'Indication')]

# %%
pkl_save(entp2rel, "../data/2018umass_relation_processed/binary/2018umass_mapping.pkl")

# %%
umass_training = "/Users/alexgre/workspace/data/2018_umass_ade/training/brat/"
umass_test = "/Users/alexgre/workspace/data/2018_umass_ade/test/brat/"
umass_entity_only = "/Users/alexgre/workspace/data/2018_umass_ade/test/brat_only_entity/"

# %%
extract_only_entity(umass_test, umass_entity_only)

# %%
total = []
n = []
for fn in Path(umass_training).glob("*.ann"):
    ners, rels = read_brat(fn)
    total.extend(rels)
    n.extend(ners)
ur = set([e[1] for e in total])
un = set([e[1] for e in n])
ur, un, len(total), len(n)

# %% [markdown]
# ### training

# %%
dpos, dneg = create_training_samples(umass_training, umass_valid, umass_valid_comb_en)

# %%
"""
0 19594
1 2270
2 667
3 255
4 130

1 34698
4 21366
3 21857
2 25937
0 46510
"""

for k, v in dpos.items():
    print(k, len(v))

print()
    
for k, v in dneg.items():
    print(k, len(v))

# %%
dpos[0][:3], dneg[0][:3]

# %%
all_in_one(dpos, dneg, dn="2018umass", do_train=True)
partial_unique(dpos, dneg, dn="2018umass", do_train=True)
all_in_unique(dpos, dneg, dn="2018umass", do_train=True)

# %% [markdown]
# ### test

# %%
preds = create_test_samples(umass_test, umass_valid, umass_valid_comb_en)

# %%
rel_mappings

# %%
"""
0 3648
1 304
2 114
3 56
4 9
0 5200
4 1505
2 1653
1 2401
3 1524
"""

for k, v in preds.items():
    print(k, len(v))

# %%
preds[0][:2]

# %%
all_in_one(preds, dn="2018umass", do_train=False)
partial_unique(preds, dn="2018umass", do_train=False)
all_in_unique(preds, dn="2018umass", do_train=False)

# %% [markdown]
# ## DDI

# %%
ddi_training = "../data/DDICorpusBrat/Train/combine/"
ddi_test = "../data/DDICorpusBrat/Test/combine/"
ddi_entity_only = "../data/DDICorpusBrat/Test/ddi_entity_only/"
Path(ddi_entity_only).mkdir(parents=True, exist_ok=True)

# %%
extract_only_entity(ddi_test, ddi_entity_only)

# %%
total = []
n = []
for fn in Path(ddi_training).glob("*.ann"):
    ners, rels = read_brat(fn)
    total.extend(rels)
    n.extend(ners)
ur = set([e[1] for e in total])
un = set([e[1] for e in n])
ur, un, len(total), len(n)

# %%
total = []
n = []
for fn in Path(ddi_test).glob("*.ann"):
    ners, rels = read_brat(fn)
    total.extend(rels)
    n.extend(ners)
ur = set([e[1] for e in total])
un = set([e[1] for e in n])
ur, un, len(total), len(n)

# %%
ddi_valid_comb_en = {
    ('DRUG', 'DRUG')
}

# all four relations are DRUG-DRUG, so only mul mode

# %%
cnt = []

def pp(ddd):
    for k, v in ddd.items():
        cnt.append((k, len(v)))

# %%
CUTOFF=0
dpos, dneg = create_training_samples(ddi_training, None, ddi_valid_comb_en)
pp(dpos)
pp(dneg)
all_in_one(dpos, dneg, dn="2018ddi", do_train=True)
#     partial_unique(dpos, dneg, dn="ddi", do_train=True)
all_in_unique(dpos, dneg, dn="2018ddi", do_train=True)

preds = create_test_samples(ddi_test, None, ddi_valid_comb_en)
pp(preds)
all_in_one(preds, dn="2018ddi", do_train=False)
#     partial_unique(preds, dn="ddi", do_train=False)
all_in_unique(preds, dn="2018ddi", do_train=False)

# %%
c = 0
exs = dpos[0] + dneg[0]
for each in exs:
    if len(each[2].split(" ")) > 200:
        print(each)
        c += 1

# %%
c

# %%
cnt

# %%
from transformers import BertTokenizer
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

# %%
import sys
sys.path.append("../")
sys.path.append("../src")
from src.data_utils import RelationDataFormatSepProcessor

# %%
data_processor = RelationDataFormatSepProcessor(max_seq_len=512)

# %%
data_processor.set_data_dir("../data/2018umass_relation_processed/new_version/2018umass_aiu_th4/cutoff_0/")
data_processor.set_tokenizer(tokenizer)
data_processor.set_num_core(8)

# %%
data = data_processor.get_train_examples()

# %%
len(data)

# %%
"""
single: 24m6s
multi: 12m30s
new_mul: 10m
"""

# %%
from copy import deepcopy

# %%
d1 = deepcopy(data)

# %%
pkl_save(d1, "temp.pkl")

# %%
d1 = pkl_load("temp.pkl")

# %%
len(d1), len(data)

# %%
d2 = []
for each in data:
    d2.extend(each)
len(d2)

# %%
d2 = data

# %%
assert len(d2) == len(d1)

# %%
for s1, s2 in zip(d1, d2):
    assert s1.label == s2.label and s1.text_a == s2.text_a and s1.text_b == s2.text_b, "{}\n{}".format(s1, s2)
